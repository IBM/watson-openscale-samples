# %% [markdown]
# # Evaluate Content Generation using langchain and watsonx.governance
#
# This notebook demonstrates the working flow of Content Generation using langchain and watsonx.ai, evaluation of the application using watsonx.governance callback handler.
#
# ## Learning goals
#
# - Read data
# - Initialize foundation model
# - Generate the responses
# - Configure and compute metrics
#
#
# **Note:** Search for `<EDIT THIS>` and provide the inputs.
#
# **Please run the notebook in an environment with memory greater than 4GB**
#
# ## Contents
#
# - [Step 1 - Setup](#setup)
# - [Step 2 - Read and store data](#data)
# - [Step 3 - Initialize a foundation model using `watsonx.ai`](#model)
# - [Step 4 - Create the prompt and inputs for the prompt template](#predict)
# - [Step 5 - Configure the `watsonx.governance` metrics](#config)
# - [Step 6 - Run the LLMChain to generate response and compute the watsonx.governance metrics using callback](#compute)
# - [Step 7 - Display the results](#results)

# %% [markdown]
# ## Step 1 - Setup <a id="setup"></a>

# %% [markdown]
# ### Install the necessary libraries

# %%
# !pip install wget 
# !pip install nltk
# !pip install -U chromadb
# !pip install -qU langchain-ibm
# !pip install -U ibm-watsonx-ai
# !pip install -U ibm-watson-openscale
# !pip install ibm-metrics-plugin~=5.0.3.0
# !pip install nest_asyncio unitxt torch==2.1.0 
# !pip install textstat pydantic-settings sentence-transformers
# !pip install -U langchain langchain-core langchain-community

import warnings
warnings.filterwarnings("ignore")

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/wsuser/nltk_data...
# True

# %% [markdown]
# **Note**: you may need to restart the kernel to use updated libraries.

# %% [markdown]
# ### Configure your cloud credentials with IBM's APIClient object

# %%
from ibm_watsonx_ai import APIClient

api_client = APIClient(credentials = {
                                "url" : "<EDIT THIS>",
                                "apikey" : "<EDIT THIS>",
                                "project_id" : "<EDIT THIS>",
                            })

# %% [markdown]
# ## Step 2 - Read and store data <a id="data"></a>

# %% [markdown]
# ### Read the data
#
# Download the sample "LLM Content Generation" file.

# %%
import wget
import os

# !wget "https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/IBM%20Cloud/WML/assets/data/watsonx/llm_content_generation.csv"
# Out:
# --2024-11-19 09:17:52--  https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/IBM%20Cloud/WML/assets/data/watsonx/llm_content_generation.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11794 (12K) [text/plain]
# Saving to: ‘llm_content_generation.csv’
#
# llm_content_generat 100%[===================>]  11.52K  --.-KB/s    in 0s
#
# 2024-11-19 09:17:52 (29.9 MB/s) - ‘llm_content_generation.csv’ saved [11794/11794]
# HTTP request sent, awaiting response...
# 200 OK
# Length: 42771 (42K) [application/octet-stream]
# Saving to: ‘llm_content.csv.3’
#
# llm_content.csv.3   100%[===================>]  41.77K  --.-KB/s    in 0.003s
#
# 2024-11-18 15:49:48 (12.0 MB/s) - ‘llm_content.csv.3’ saved [42771/42771]

# %%
import pandas as pd

data = pd.read_csv("llm_content_generation.csv",encoding="latin-1")
data
# Out:
#                                              question  \
# 0          What are the benefits of regular exercise?
# 1              What is the process of photosynthesis?
# 2          What are the key features of a smartphone?
# 3                    How does the immune system work?
# 4                      What is the capital of France?
# 5                             What is climate change?
# 6                      How does the water cycle work?
# 7          What are the main principles of democracy?
# 8                      How do plants photosynthesize?
# 9   What are the key components of a computer system?
# 10  What is the concept of supply and demand in ec...
# 11    What is the purpose of the United Nations (UN)?
# 12                          How do earthquakes occur?
# 13                  What is the structure of an atom?
# 14                     What is the greenhouse effect?
# 15                              How do vaccines work?
# 16          What are the main functions of the liver?
# 17   What is the concept of time dilation in physics?
# 18    What is the purpose of the European Union (EU)?
# 19                            How does a camera work?
# 20         What is the role of mitochondria in cells?
# 21  What is the concept of natural selection in ev...
# 22                          What is renewable energy?
#
#                                        generated_text  \
# 0   Regular exercise has numerous benefits, includ...
# 1   Photosynthesis is the process by which plants ...
# 2   A smartphone is a mobile device that typically...
# 3   The immune system is a complex network of cell...
# 4   The capital of France is Paris, which is known...
# 5   Climate change refers to long-term alterations...
# 6   The water cycle, also known as the hydrologic ...
# 7   Democracy is a system of government where the ...
# 8   Plants photosynthesize by using sunlight, carb...
# 9   A computer system consists of several key comp...
# 10  Supply and demand is a fundamental concept in ...
# 11  The United Nations is an international organiz...
# 12  Earthquakes occur when there is a sudden relea...
# 13  An atom consists of three main subatomic parti...
# 14  The greenhouse effect is a natural process tha...
# 15  Vaccines work by introducing a weakened or ina...
# 16  The liver has several vital functions in the b...
# 17  Time dilation is a phenomenon predicted by Alb...
# 18  The European Union is a political and economic...
# 19  Cameras capture images by allowing light to pa...
# 20  Mitochondria are often called the 'powerhouses...
# 21  Natural selection is a key mechanism of evolut...
# 22  Renewable energy is energy that is derived fro...
#
#                                        reference_text
# 0   Regular exercise has numerous benefits, includ...
# 1   Photosynthesis is the process by which plants ...
# 2   A smartphone is a mobile device that typically...
# 3   The immune system is a complex network of cell...
# 4   The capital of France is Paris, which is known...
# 5   Climate change refers to long-term alterations...
# 6   The water cycle, also known as the hydrologic ...
# 7   Democracy is a system of government where the ...
# 8   Plants photosynthesize by using sunlight, carb...
# 9   A computer system consists of several key comp...
# 10  Supply and demand is a fundamental concept in ...
# 11  The United Nations is an international organiz...
# 12  Earthquakes occur when there is a sudden relea...
# 13  An atom consists of three main subatomic parti...
# 14  The greenhouse effect is a natural process tha...
# 15  Vaccines work by introducing a weakened or ina...
# 16  The liver has several vital functions in the b...
# 17  Time dilation is a phenomenon predicted by Alb...
# 18  The European Union is a political and economic...
# 19  Cameras capture images by allowing light to pa...
# 20  Mitochondria are often called the 'powerhouses...
# 21  Natural selection is a key mechanism of evolut...
# 22  Renewable energy is energy that is derived fro...

# %% [markdown]
# ## Step 3 - Initialize a foundation model using `watsonx.ai`
# <a id="model"></a>

# %% [markdown]
# IBM watsonx foundation models are among the <a href="https://python.langchain.com/docs/integrations/llms/watsonxllm" target="_blank" rel="noopener no referrer">list of LLM models supported by Langchain</a>. This example shows how to communicate with <a href="https://newsroom.ibm.com/2023-09-28-IBM-Announces-Availability-of-watsonx-Granite-Model-Series,-Client-Protections-for-IBM-watsonx-Models" target="_blank" rel="noopener no referrer">the Granite Model Series</a> using <a href="https://python.langchain.com/docs/get_started/introduction" target="_blank" rel="noopener no referrer">Langchain</a>.

# %% [markdown]
# ### Define the model parameters
# Provide a set of model parameters that will influence the result:

# %%
parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 100,
    "min_new_tokens": 1,
    "temperature": 0.5,
    "top_k": 50,
    "top_p": 1,
}

# %% [markdown]
# ### Create watsonx model with IBM's APIClient object into the WatsonxLLM class
# Initialize the model from watsonx.ai with required parameters, and using `ibm/granite-13b-chat-v2`.

# %%
from langchain_ibm import WatsonxLLM

watsonx_llm = WatsonxLLM(
    model_id = "ibm/granite-13b-chat-v2",
    watsonx_client = api_client,
    params = parameters,
    project_id = "<EDIT THIS>"
)

# %% [markdown]
# ## Step 4 - Create the prompt and inputs for the prompt template
# <a id="predict"></a>

# %% [markdown]
# ### Construct a dataframe with question, generated text and reference text to be used for metrics computation
# <a id="predict"><a>

# %%
df_input = pd.DataFrame(data, columns=["question", "generated_text", "reference_text"])

sources = df_input.to_dict(orient='records')

# %% [markdown]
# ### Create the prompt template and prompt variable

# %%
from langchain import PromptTemplate

generation_prompt_text = """
Generate high-quality content based on the following question. Use the reference content to guide your generation, ensuring it aligns with the question's context and intent.

Question: {question}

Reference Content: {reference_text}

Generated Content:
"""

generation_prompt = PromptTemplate(
    input_variables=["question", "reference_text"],
    template=generation_prompt_text
)

# %% [markdown]
# ## Step 5 - Configure the `watsonx.governance` metrics
# <a id="config"></a>
#
# Configure the required metrics

# %%
from ibm_metrics_plugin.metrics.llm.utils.constants import LLMTextMetricGroup, LLMGenerationMetrics

config_json = {
            "configuration": {
                "record_level": True,
                LLMTextMetricGroup.GENERATION.value: {
                LLMGenerationMetrics.ROUGE_SCORE.value: {},
                LLMGenerationMetrics.METEOR.value: {},
                LLMGenerationMetrics.NORMALIZED_RECALL.value: {},
                LLMGenerationMetrics.NORMALIZED_PRECISION.value: {},
                LLMGenerationMetrics.NORMALIZED_F1_SCORE.value: {},
                LLMGenerationMetrics.BLEU.value: {},
                LLMGenerationMetrics.FLESCH.value: {}
            }
        }
    }

# %% [markdown]
# ### Create watsonx.governance client

# %%
CLOUD_API_KEY = "<EDIT THIS>"

from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

from ibm_watson_openscale import *
from ibm_watson_openscale.supporting_classes.enums import *
from ibm_watson_openscale.supporting_classes import *

authenticator = IAMAuthenticator(apikey=CLOUD_API_KEY, url="https://iam.cloud.ibm.com")
client = APIClient(authenticator=authenticator, service_url="https://aiopenscale.cloud.ibm.com")

print(client.version)
# Out:
# 3.0.41

# %% [markdown]
# ### Step 6 - Run the LLMChain to generate response and compute the watsonx.governance metrics using callback

# %% [markdown]
# #### Intialize LLMChain

# %%
from langchain.chains import LLMChain
generation_chain = LLMChain(llm=watsonx_llm, prompt=generation_prompt)

# %% [markdown]
# #### WatsonxGovCallbackHandler parameters
# | Parameter | Description | Type | Default Value  |
# |:-|:-|:-|:-|
# | configuration* | Configuration of metrics to be evaluated | dictionary |  |
# | watsonxgov_client* | watsonx client objects |  |  |
# | source | The context from which the model answers the question | dictionary |  |
# | reference | The reference for the response generated for the model | dictionary |  |
# | record_id | record id for the record getting evaluated | string |  |
# | debug | flag variable to handle the debugs during the execution | boolean | false |

# %%
from ibm_watson_openscale.callbacks.langchain import WatsonxGovCallbackHandler

answers=[]
record_level_metrics=[]

for input_row in sources:
    question = input_row["question"]
    reference_text = input_row["reference_text"]
    handler=WatsonxGovCallbackHandler(configuration=config_json, watsonxgov_client=client, source=input_row, reference={"reference_text": reference_text})
    result=generation_chain.run({"question": question, "reference_text": reference_text}, callbacks=[handler])
    answers.append(result)
    record_level_metrics.append(handler.computed_metrics)
# Out:
# Evaluating for record eaf3f38b-6f04-4278-8428-b3ffb0c89996
# Evaluating for record 508f7543-9722-42e2-9ca7-965a048056a5
# Evaluating for record 7182b7f7-ab07-408e-abb0-6a9a2febb8ce
# Evaluating for record 3c2d491e-7be1-4521-a626-a94edff93e2d
# Evaluating for record 46c4ffde-d2cc-4f8e-9981-3da53567afac
# Evaluating for record 9a6d49e2-0b78-4704-ac51-aa31adb9b390
# Evaluating for record 39a174f6-4afa-4764-9394-c2e4265dcbfd
# Evaluating for record b2d22562-53e4-4ee0-92ec-eee9d2962a56
# Evaluating for record 86cc8033-e750-4ce8-9bce-e68921a3540e
# Evaluating for record 9e605947-61e9-4d89-a997-0a56c2364250
# Evaluating for record 6495f275-3df8-4b61-9626-5c755712d78b
# Evaluating for record 4f1cf1a6-b561-4e99-a5a9-ac2e44a4720e
# Evaluating for record 7639b7f4-10b1-4b1e-ab16-0e53688668df
# Evaluating for record 9536f3a2-efd3-41ec-adab-c800496c91d8
# Evaluating for record 423e6f62-117b-46c9-8bd5-f6381b0ee917
# Evaluating for record 77c823e5-1ce1-48bc-9e20-bc6311263fc5
# Evaluating for record 827bc0ca-2e57-4ac8-be10-047df15436d5
# Evaluating for record 13c73bb5-27b9-44f5-b173-fd5ef868859b
# Evaluating for record e91ccd36-43af-4adf-b826-8fe67ddee70d
# Evaluating for record 6a06094a-ee29-473e-91d3-6f5c22c871f2
# Evaluating for record 3df53be8-53de-4fae-925a-5a726990a9c5
# Evaluating for record f9a8efdf-8ef0-4986-b2ab-448511fa5a9c
# Evaluating for record 1297a4e8-7027-4fc1-ab3b-90d5653e9755

# %% [markdown]
# #### Run this cell to get the combined metrics results

# %%
import json
metric_result = WatsonxGovCallbackHandler.aggregate_result(record_level_metrics)
print(json.dumps(metric_result,indent=2))
# Out:
# {
#   "flesch": {
#     "record_level_metrics": [
#       {
#         "record_id": "eaf3f38b-6f04-4278-8428-b3ffb0c89996",
#         "flesch_reading_ease": 35.27,
#         "flesch_kincaid_grade": 13.1
#       },
#       {
#         "record_id": "508f7543-9722-42e2-9ca7-965a048056a5",
#         "flesch_reading_ease": 40.55,
#         "flesch_kincaid_grade": 11.0
#       },
#       {
#         "record_id": "7182b7f7-ab07-408e-abb0-6a9a2febb8ce",
#         "flesch_reading_ease": 44.95,
#         "flesch_kincaid_grade": 11.4
#       },
#       {
#         "record_id": "3c2d491e-7be1-4521-a626-a94edff93e2d",
#         "flesch_reading_ease": 59.33,
#         "flesch_kincaid_grade": 10.0
#       },
#       {
#         "record_id": "46c4ffde-d2cc-4f8e-9981-3da53567afac",
#         "rouge2_recall": 0.625,
#         "rougeL_recall": 0.7805,
#         "rougeLsum_recall": 0.8293
#       },
#       {
#         "record_id": "f9a8efdf-8ef0-4986-b2ab-448511fa5a9c",
#         "rouge1": 0.5417,
#         "rouge2": 0.3239,
#         "rougeL": 0.375,
#         "rougeLsum": 0.5,
#         "rouge1_recall": 0.75,
#         "rouge2_recall": 0.451,
#         "rougeL_recall": 0.5192,
#         "rougeLsum_recall": 0.6923
#       },
#       {
#         "record_id": "1297a4e8-7027-4fc1-ab3b-90d5653e9755",
#         "rouge1": 0.3077,
#         "rouge2": 0.0522,
#         "rougeL": 0.2393,
#         "rougeLsum": 0.2564,
#         "rouge1_recall": 0.4615,
#         "rouge2_recall": 0.0789,
#         "rougeL_recall": 0.359,
#         "rougeLsum_recall": 0.3846
#       }
#     ],
#     "rouge1": {
#       "metric_value": 0.4752782608695653,
#       "mean": 0.4752782608695653,
#       "min": 0.2909,
#       "max": 0.6897,
#       "std": 0.11001259989703842
#     },
#     "rouge2": {
#       "metric_value": 0.2502130434782609,
#       "mean": 0.2502130434782609,
#       "min": 0.0522,
#       "max": 0.5175,
#       "std": 0.12182667054448558
#     },
#     "rougeL": {
#       "metric_value": 0.3679478260869566,
#       "mean": 0.3679478260869566,
#       "min": 0.1636,
#       "max": 0.5931,
#       "std": 0.10506111624881974
#     },
#     "rougeLsum": {
#       "metric_value": 0.4416956521739131,
#       "mean": 0.4416956521739131,
#       "min": 0.2364,
#       "max": 0.6621,
#       "std": 0.11102391625724797
#     },
#     "rouge1_recall": {
#       "metric_value": 0.689808695652174,
#       "mean": 0.689808695652174,
#       "min": 0.4324,
#       "max": 0.8929,
#       "std": 0.13558113859153467
#     },
#     "rouge2_recall": {
#       "metric_value": 0.36335652173913047,
#       "mean": 0.36335652173913047,
#       "min": 0.0789,
#       "max": 0.6727,
#       "std": 0.16606408879677056
#     },
#     "rougeL_recall": {
#       "metric_value": 0.5339260869565217,
#       "mean": 0.5339260869565217,
#       "min": 0.2432,
#       "max": 0.7805,
#       "std": 0.13654730098550913
#     },
#     "rougeLsum_recall": {
#       "metric_value": 0.6420434782608697,
#       "mean": 0.6420434782608697,
#       "min": 0.3514,
#       "max": 0.8571,
#       "std": 0.14543939967974998
#     }
#   }
# }

# %% [markdown]
# ## Step 7 - Display the results <a id="results"></a>

# %% [markdown]
# ### Metric results for all the records

# %%
# Display results
results_df = data.copy()
results_df['answer'] = answers
for k, v in metric_result.items():
    for rm in v.get("record_level_metrics"):
        for m, mv in rm.items():
            if m != "record_id":
                results_df[m] = [r.get(m) for r in v.get("record_level_metrics")]
results_df
# Out:
#                                              question  \
# 0          What are the benefits of regular exercise?
# 1              What is the process of photosynthesis?
# 2          What are the key features of a smartphone?
# 3                    How does the immune system work?
# 4                      What is the capital of France?
# 5                             What is climate change?
# 6                      How does the water cycle work?
# 7          What are the main principles of democracy?
# 8                      How do plants photosynthesize?
# 9   What are the key components of a computer system?
# 10  What is the concept of supply and demand in ec...
# 11    What is the purpose of the United Nations (UN)?
# 12                          How do earthquakes occur?
# 13                  What is the structure of an atom?
# 14                     What is the greenhouse effect?
# 15                              How do vaccines work?
# 16          What are the main functions of the liver?
# 17   What is the concept of time dilation in physics?
# 18    What is the purpose of the European Union (EU)?
# 19                            How does a camera work?
# 20         What is the role of mitochondria in cells?
# 21  What is the concept of natural selection in ev...
# 22                          What is renewable energy?
#
#                                        generated_text  \
# 0   Regular exercise has numerous benefits, includ...
# 1   Photosynthesis is the process by which plants ...
# 2   A smartphone is a mobile device that typically...
# 3   The immune system is a complex network of cell...
# 4   The capital of France is Paris, which is known...
# 5   Climate change refers to long-term alterations...
# 6   The water cycle, also known as the hydrologic ...
# 7   Democracy is a system of government where the ...
# 8   Plants photosynthesize by using sunlight, carb...
# 9   A computer system consists of several key comp...
# 10  Supply and demand is a fundamental concept in ...
# 11  The United Nations is an international organiz...
# 12  Earthquakes occur when there is a sudden relea...
# 13  An atom consists of three main subatomic parti...
# 14  The greenhouse effect is a natural process tha...
# 15  Vaccines work by introducing a weakened or ina...
# 16  The liver has several vital functions in the b...
# 17  Time dilation is a phenomenon predicted by Alb...
# 18  The European Union is a political and economic...
# 19  Cameras capture images by allowing light to pa...
# 20  Mitochondria are often called the 'powerhouses...
# 21  Natural selection is a key mechanism of evolut...
# 22  Renewable energy is energy that is derived fro...
#
#                                        reference_text  \
# 0   Regular exercise has numerous benefits, includ...
# 1   Photosynthesis is the process by which plants ...
# 2   A smartphone is a mobile device that typically...
# 3   The immune system is a complex network of cell...
# 4   The capital of France is Paris, which is known...
# 5   Climate change refers to long-term alterations...
# 6   The water cycle, also known as the hydrologic ...
# 7   Democracy is a system of government where the ...
# 8   Plants photosynthesize by using sunlight, carb...
# 9   A computer system consists of several key comp...
# 10  Supply and demand is a fundamental concept in ...
# 11  The United Nations is an international organiz...
# 12  Earthquakes occur when there is a sudden relea...
# 13  An atom consists of three main subatomic parti...
# 14  The greenhouse effect is a natural process tha...
# 15  Vaccines work by introducing a weakened or ina...
# 16  The liver has several vital functions in the b...
# 17  Time dilation is a phenomenon predicted by Alb...
# 18  The European Union is a political and economic...
# 19  Cameras capture images by allowing light to pa...
# 20  Mitochondria are often called the 'powerhouses...
# 21  Natural selection is a key mechanism of evolut...
# 22  Renewable energy is energy that is derived fro...
#
#                                                answer  flesch_reading_ease  \
# 0   \n1. Improved cardiovascular health: Regular e...                35.27
# 1   \nPhotosynthesis is a vital process carried ou...                40.55
# 2   \n1. Touchscreen: A smartphone's primary inter...                44.95
# 3   \nThe immune system is a complex network of ce...                59.33
# 4   Paris is indeed the capital city of France, a ...                36.63
# 5   Climate change is a long-term shift in tempera...                41.70
# 6   \nThe water cycle, also known as the hydrologi...                45.46
# 7   \nDemocracy is a form of government in which p...                24.98
# 8   \nPlants photosynthesize through a process tha...                51.89
# 9   \n1. Central Processing Unit (CPU): Often refe...                45.25
# 10  \nSupply and demand is a crucial concept in ec...                50.67
# 11  The United Nations (UN) is an international or...                24.27
# 12  \nEarthquakes are the result of sudden energy ...                72.16
# 13  \nAn atom is a fundamental unit of matter, and...                55.44
# 14  The greenhouse effect is a natural phenomenon ...                46.78
# 15  \nVaccines function by tricking the immune sys...                38.11
# 16  \nThe liver is a crucial organ with several es...                46.17
# 17  \nTime dilation is a concept from the theory o...                54.02
# 18  The European Union, often referred to as the E...                37.50
# 19  \nA camera works by capturing light and conver...                56.96
# 20  \nMitochondria are vital organelles found in t...                26.30
# 21  \nNatural selection is a fundamental concept i...                52.80
# 22  \nRenewable energy, also known as clean energy...                38.72
#
#     flesch_kincaid_grade      bleu  \
# 0                   13.1  0.069222
# 1                   11.0  0.145045
# 2                   11.4  0.000000
# 3                   10.0  0.209733
# 4                   14.6  0.000000
# 5                   12.7  0.079510
# 6                   11.2  0.180496
# 7                   14.9  0.099147
# 8                   10.8  0.104342
# 9                   11.3  0.000000
# 10                  11.3  0.317129
# 11                  15.2  0.195019
# 12                   7.2  0.286151
# 13                   9.5  0.164104
# 14                  10.7  0.189236
# 15                  12.0  0.184175
# 16                  10.9  0.000000
# 17                  10.0  0.366092
# 18                  12.2  0.237465
# 19                   8.9  0.131777
# 20                  14.4  0.263859
# 21                  10.5  0.193981
# 22                  11.7  0.069890
#
#                                            precisions  brevity_penalty  \
# 0   [0.24444444444444444, 0.0898876404494382, 0.04...              1.0
# 1   [0.35, 0.189873417721519, 0.10256410256410256,...              1.0
# 2   [0.2111111111111111, 0.0449438202247191, 0.011...              1.0
# 3   [0.3473684210526316, 0.2127659574468085, 0.172...              1.0
# 4   [0.3582089552238806, 0.12121212121212122, 0.03...              1.0
# 5   [0.4148936170212766, 0.16129032258064516, 0.05...              1.0
# 6   [0.375, 0.1724137931034483, 0.1395348837209302...              1.0
# 7   [0.32608695652173914, 0.0989010989010989, 0.06...              1.0
# 8   [0.2823529411764706, 0.11904761904761904, 0.07...              1.0
# 9   [0.22340425531914893, 0.043010752688172046, 0....              1.0
# 10  [0.4842105263157895, 0.3404255319148936, 0.268...              1.0
# 11  [0.3877551020408163, 0.2268041237113402, 0.156...              1.0
# 12  [0.47126436781609193, 0.3023255813953488, 0.24...              1.0
# 13  [0.3548387096774194, 0.21739130434782608, 0.12...              1.0
# 14  [0.3804347826086957, 0.23076923076923078, 0.14...              1.0
# 15  [0.4444444444444444, 0.23595505617977527, 0.13...              1.0
# 16  [0.23469387755102042, 0.061855670103092786, 0....              1.0
# 17  [0.5368421052631579, 0.4148936170212766, 0.322...              1.0
# 18  [0.45454545454545453, 0.2857142857142857, 0.19...              1.0
# 19  [0.37894736842105264, 0.1702127659574468, 0.08...              1.0
# 20  [0.3978494623655914, 0.29347826086956524, 0.21...              1.0
# 21  [0.41414141414141414, 0.24489795918367346, 0.1...              1.0
# 22  [0.2717391304347826, 0.08791208791208792, 0.04...              1.0
#
#     length_ratio  ...  normalized_precision  normalized_recall  rouge1  \
# 0       2.727273  ...              0.263889           0.703704  0.3846
# 1       2.424242  ...              0.389831           0.821429  0.5049
# 2       2.093023  ...              0.194030           0.406250  0.2936
# 3       2.209302  ...              0.315068           0.696970  0.4538
# 4       1.914286  ...              0.422222           0.655172  0.5238
# 5       1.843137  ...              0.405063           0.744186  0.5303
# 6       1.760000  ...              0.366667           0.578947  0.5128
# 7       1.916667  ...              0.250000           0.527778  0.3840
# 8       1.931818  ...              0.223881           0.428571  0.3167
# 9       2.043478  ...              0.196721           0.352941  0.2909
# 10      1.696429  ...              0.507246           0.813953  0.6212
# 11      1.960000  ...              0.354430           0.700000  0.4806
# 12      1.812500  ...              0.441176           0.810811  0.5938
# 13      2.021739  ...              0.347826           0.666667  0.4576
# 14      1.672727  ...              0.366197           0.577778  0.4812
# 15      1.764706  ...              0.376812           0.702703  0.5625
# 16      2.512821  ...              0.213333           0.516129  0.3390
# 17      1.610169  ...              0.518987           0.836735  0.6897
# 18      1.867925  ...              0.415584           0.800000  0.5581
# 19      1.826923  ...              0.397260           0.674419  0.5147
# 20      2.021739  ...              0.430556           0.837838  0.5882
# 21      1.767857  ...              0.426829           0.729167  0.5417
# 22      2.000000  ...              0.232877           0.447368  0.3077
#
#     rouge2  rougeL  rougeLsum  rouge1_recall  rouge2_recall  rougeL_recall  \
# 0   0.2157  0.2692     0.3846         0.7143         0.4074         0.5000
# 1   0.2772  0.3883     0.5049         0.8387         0.4667         0.6452
# 2   0.0748  0.2385     0.2752         0.4324         0.1111         0.3514
# 3   0.2564  0.3697     0.4202         0.7297         0.4167         0.5946
# 4   0.2439  0.3333     0.4762         0.6875         0.3226         0.4375
# 5   0.2000  0.3788     0.4848         0.7609         0.2889         0.5435
# 6   0.2261  0.3590     0.4103         0.6522         0.2889         0.4565
# 7   0.1301  0.2880     0.3840         0.5854         0.2000         0.4390
# 8   0.1356  0.2667     0.2667         0.4750         0.2051         0.4000
# 9   0.0741  0.1636     0.2364         0.4324         0.1111         0.2432
# 10  0.4000  0.5152     0.5758         0.8200         0.5306         0.6800
# 11  0.2835  0.4186     0.4651         0.7209         0.4286         0.6279
# 12  0.3651  0.4688     0.5469         0.8444         0.5227         0.6667
# 13  0.2414  0.4068     0.4237         0.6923         0.3684         0.6154
# 14  0.2901  0.4211     0.4812         0.6531         0.3958         0.5714
# 15  0.3333  0.3906     0.5156         0.7826         0.4667         0.5435
# 16  0.0690  0.2373     0.3051         0.5714         0.1176         0.4000
# 17  0.5175  0.5931     0.6621         0.8929         0.6727         0.7679
# 18  0.3937  0.4806     0.5271         0.8000         0.5682         0.6889
# 19  0.2239  0.3235     0.4853         0.7143         0.3125         0.4490
# 20  0.4274  0.5378     0.5714         0.8537         0.6250         0.7805
# 21  0.3239  0.3750     0.5000         0.7500         0.4510         0.5192
# 22  0.0522  0.2393     0.2564         0.4615         0.0789         0.3590
#
#     rougeLsum_recall
# 0             0.7143
# 1             0.8387
# 2             0.4054
# 3             0.6757
# 4             0.6250
# 5             0.6957
# 6             0.5217
# 7             0.5854
# 8             0.4000
# 9             0.3514
# 10            0.7600
# 11            0.6977
# 12            0.7778
# 13            0.6410
# 14            0.6531
# 15            0.7174
# 16            0.5143
# 17            0.8571
# 18            0.7556
# 19            0.6735
# 20            0.8293
# 21            0.6923
# 22            0.3846
#
# [23 rows x 24 columns]
