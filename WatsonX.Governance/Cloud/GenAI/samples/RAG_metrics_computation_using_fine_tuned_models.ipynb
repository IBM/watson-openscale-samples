# %% [markdown]
# # Retrieval and Answer Quality Metrics computation using fine tuned models in IBM watsonx.governance for RAG task
#
# This notebook demonstrates the computation of reference-free Answer Quality metrics, such as **Faithfulness**, **Answer relevance** and Retrieval Quality Metrics such as **Context Relevance**, **Retrieval Precision**, **Average Precision**, **Reciprocal Rank**, **Hit Rate** and **Normalized Discounted Cumulative Gain** using fine tuned models.
#
# To compute the above metrics using the IBM fine tuned models, you must create a custom evaluator specific for each metric and provide it in the monitor configuration. A custom evaluator is a python function created using runtime-24.1 base and deployed in a space which runs the models and compute the metrics.

# %% [markdown]
# ## Learning goals
#
# - Create custom evaluators to run the fine tuned models and compute Retrieval and Answer Quality metrics

# %% [markdown]
# ## Prerequisites
#
# - IBM Cloud credentials
# - A `.csv` file containing test data to be evaluated
# - Space ID in which you want to create python function deployments

# %% [markdown]
# ## Contents
#
# - [Step 1 - Setup](#setup)
# - [Step 2 - Read data](#data)
# - [Step 3 - Custom evaluators creation](#evaluator)
# - [Step 4 - Configure retrieval and answer quality metrics](#config)
# - [Step 5 - Compute the retrieval and answer quality metrics](#compute)
# - [Step 6 - Display the results](#results)

# %% [markdown]
# ## Step 1 - Setup <a id="setup"></a>

# %% [markdown]
# ### Install necessary libraries

# %%
# !pip install ibm-watson-openscale>=3.0.43
# !pip install ibm-metrics-plugin~=3.0.11
# !pip install ibm-watsonx-ai==1.1.11
# Out:
# Requirement already satisfied: ibm-metrics-plugin~=3.0.11 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (3.0.12)
# Requirement already satisfied: ibm-wos-utils~=3.0.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (3.0.6)
# Requirement already satisfied: shap~=0.45.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (0.45.1)
# Requirement already satisfied: pyparsing~=3.1.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (3.1.4)
# Requirement already satisfied: spark-nlp~=5.3.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (5.3.3)
# Requirement already satisfied: service-locator==0.1.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (0.1.3)
# Requirement already satisfied: h5py~=3.11.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (3.11.0)
# Requirement already satisfied: marshmallow~=3.21.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (3.21.3)
# Requirement already satisfied: toolz<0.13,>=0.12.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (0.12.1)
# Requirement already satisfied: transformers~=4.39.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-metrics-plugin~=3.0.11) (4.39.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from h5py~=3.11.0->ibm-metrics-plugin~=3.0.11) (1.26.4)
# Requirement already satisfied: scipy~=1.11.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.11.4)
# Requirement already satisfied: pandas~=2.1.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2.1.4)
# Requirement already satisfied: scikit-learn==1.5.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.5.1)
# Requirement already satisfied: scikit-image==0.22.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (0.22.0)
# Requirement already satisfied: imageio==2.27.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2.27.0)
# Requirement already satisfied: requests<3.0,>=2.31.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2.32.2)
# Requirement already satisfied: tqdm~=4.66.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (4.66.4)
# Requirement already satisfied: jenkspy~=0.4.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (0.4.1)
# Requirement already satisfied: more-itertools~=10.2.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (10.2.0)
# Requirement already satisfied: retrying==1.3.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.3.4)
# Requirement already satisfied: boto3~=1.29.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.29.1)
# Requirement already satisfied: PyJWT==2.4.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2.4.0)
# Requirement already satisfied: cachetools~=5.3.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (5.3.3)
# Requirement already satisfied: aiohttp~=3.10.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (3.10.5)
# Requirement already satisfied: urllib3~=1.26.19 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.26.19)
# Requirement already satisfied: pillow>=8.3.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from imageio==2.27.0->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (10.3.0)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from retrying==1.3.4->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.16.0)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-image==0.22.0->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (3.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-image==0.22.0->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2023.4.12)
# Requirement already satisfied: packaging>=21 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-image==0.22.0->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-image==0.22.0->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (0.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-learn==1.5.1->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from scikit-learn==1.5.1->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (3.5.0)
# Requirement already satisfied: slicer==0.0.8 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from shap~=0.45.0->ibm-metrics-plugin~=3.0.11) (0.0.8)
# Requirement already satisfied: numba in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from shap~=0.45.0->ibm-metrics-plugin~=3.0.11) (0.59.1)
# Requirement already satisfied: cloudpickle in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from shap~=0.45.0->ibm-metrics-plugin~=3.0.11) (2.2.1)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from transformers~=4.39.3->ibm-metrics-plugin~=3.0.11) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from transformers~=4.39.3->ibm-metrics-plugin~=3.0.11) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from transformers~=4.39.3->ibm-metrics-plugin~=3.0.11) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from transformers~=4.39.3->ibm-metrics-plugin~=3.0.11) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from transformers~=4.39.3->ibm-metrics-plugin~=3.0.11) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from transformers~=4.39.3->ibm-metrics-plugin~=3.0.11) (0.4.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp~=3.10.2->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp~=3.10.2->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp~=3.10.2->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp~=3.10.2->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp~=3.10.2->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp~=3.10.2->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.9.3)
# Requirement already satisfied: botocore<1.33.0,>=1.32.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from boto3~=1.29.1->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.32.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from boto3~=1.29.1->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from boto3~=1.29.1->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers~=4.39.3->ibm-metrics-plugin~=3.0.11) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers~=4.39.3->ibm-metrics-plugin~=3.0.11) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas~=2.1.4->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas~=2.1.4->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas~=2.1.4->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0,>=2.31.0->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0,>=2.31.0->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0,>=2.31.0->ibm-wos-utils~=3.0.4->ibm-metrics-plugin~=3.0.11) (2024.8.30)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from numba->shap~=0.45.0->ibm-metrics-plugin~=3.0.11) (0.42.0)
# Requirement already satisfied: ibm-watsonx-ai==1.1.11 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (1.1.11)
# Requirement already satisfied: requests in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (2.32.2)
# Requirement already satisfied: httpx in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (0.26.0)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (1.26.19)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (2.1.4)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (2024.8.30)
# Requirement already satisfied: lomond in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (0.3.3)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (0.8.10)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (23.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (2.13.4)
# Requirement already satisfied: importlib-metadata in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watsonx-ai==1.1.11) (7.0.1)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.11) (2.13.4)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.4 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.11) (2.13.4)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.11) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cos-sdk-core==2.13.4->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.11) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.11) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.11) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.11) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->ibm-watsonx-ai==1.1.11) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests->ibm-watsonx-ai==1.1.11) (3.7)
# Requirement already satisfied: anyio in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from httpx->ibm-watsonx-ai==1.1.11) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from httpx->ibm-watsonx-ai==1.1.11) (1.0.2)
# Requirement already satisfied: sniffio in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from httpx->ibm-watsonx-ai==1.1.11) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from httpcore==1.*->httpx->ibm-watsonx-ai==1.1.11) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from importlib-metadata->ibm-watsonx-ai==1.1.11) (3.20.2)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from lomond->ibm-watsonx-ai==1.1.11) (1.16.0)
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: ibm-watson-openscale==3.0.41.12 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (3.0.41.12)
# Requirement already satisfied: requests<3.0,>=2.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-openscale==3.0.41.12) (2.32.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-openscale==3.0.41.12) (2.8.2)
# Requirement already satisfied: ibm-cloud-sdk-core<=3.19.2,>=3.16.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-openscale==3.0.41.12) (3.16.7)
# Requirement already satisfied: pandas<=2.1.9,>=1.4.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-watson-openscale==3.0.41.12) (2.1.4)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cloud-sdk-core<=3.19.2,>=3.16.5->ibm-watson-openscale==3.0.41.12) (1.26.19)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from ibm-cloud-sdk-core<=3.19.2,>=3.16.5->ibm-watson-openscale==3.0.41.12) (2.4.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<=2.1.9,>=1.4.3->ibm-watson-openscale==3.0.41.12) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<=2.1.9,>=1.4.3->ibm-watson-openscale==3.0.41.12) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas<=2.1.9,>=1.4.3->ibm-watson-openscale==3.0.41.12) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from python-dateutil>=2.5.3->ibm-watson-openscale==3.0.41.12) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0,>=2.0->ibm-watson-openscale==3.0.41.12) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0,>=2.0->ibm-watson-openscale==3.0.41.12) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests<3.0,>=2.0->ibm-watson-openscale==3.0.41.12) (2024.8.30)

# %% [markdown]
# **Note**: you may need to restart the kernel to use updated libraries.

# %% [markdown]
# ### Configure your credentials

# %%
# Cloud credentials
IAM_URL = "https://iam.cloud.ibm.com"
CLOUD_API_KEY = "<EDIT THIS>"  # YOUR_CLOUD_API_KEY
SERVICE_URL = "https://aiopenscale.cloud.ibm.com"

WX_AI_CREDENTIALS = {
    "url": "https://us-south.ml.cloud.ibm.com",
    "apikey": CLOUD_API_KEY,
}

# %% [markdown]
# ### Verify client version

# %%
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

from ibm_watson_openscale import *
from ibm_watson_openscale.supporting_classes.enums import *
from ibm_watson_openscale.supporting_classes import *

service_instance_id = None  # Update this to refer to a particular service instance
authenticator = IAMAuthenticator(apikey=CLOUD_API_KEY, url=IAM_URL)
wos_client = APIClient(
    authenticator=authenticator,
    service_url=SERVICE_URL,
    service_instance_id=service_instance_id,
)
print(wos_client.version)
# Out:
# 3.0.41.12

# %%
from ibm_watsonx_ai import APIClient

watsonx_ai_client = APIClient(WX_AI_CREDENTIALS)
print(watsonx_ai_client.version)
# Out:
# 1.1.11

# %% [markdown]
# ## Step 2 - Read data<a id="data"></a>

# %%
# Download rag data
# !rm rag_state_union.csv
# !wget https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/IBM%20Cloud/WML/assets/data/watsonx/rag_state_union.csv
# Out:
# --2024-12-17 11:06:34--  https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/IBM%20Cloud/WML/assets/data/watsonx/rag_state_union.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20259 (20K) [text/plain]
# Saving to: ‘rag_state_union.csv’
#
# rag_state_union.csv 100%[===================>]  19.78K  --.-KB/s    in 0.001s
#
# 2024-12-17 11:06:34 (19.4 MB/s) - ‘rag_state_union.csv’ saved [20259/20259]

# %%
import pandas as pd
import json

data = pd.read_csv("rag_state_union.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   context1  5 non-null      object
#  1   context2  5 non-null      object
#  2   context3  5 non-null      object
#  3   context4  5 non-null      object
#  4   question  5 non-null      object
#  5   answer    5 non-null      object
# dtypes: object(6)
# memory usage: 372.0+ bytes

# %%
# Edit below values based on the input data
context_columns = ["context1", "context2", "context3", "context4"]
question_column = "question"
answer_column = "answer"

# %% [markdown]
# ## Step 3 - Custom evaluators creation <a id="evaluator"></a>

# %% [markdown]
# The custom evaluators are created by as a python function which is deployed in a custom runtime environment built on `RT24.1`.

# %% [markdown]
# #### Evaluator parameters
# | Parameter | Description | Default Value | Possible Value(s) |
# |:-|:-|:-|:-|
# | `metric_type` | The name of the metric for which evaluator is created. |  | `retrieval_quality`, `faithfulness`, `answer_relevance` |
# | `wx_ai_credentials` | Watsonx AI credentials. |  |  |
# | `space_id` | ID of the space in which you want to create python function deployment. |  |  |
# | `context_columns` [Optional]| The list of context column names in the input data frame. |  |  |
# | `question_column` | The name of the question column in the input data frame. |  |  |
# | `hardware_spec` [Optional]| Hardware specifications for deploying the python function. The metrics computation performance can be improved by providing larger hardware specification. | `M` | `M`, `L`, `XL` |
# | `metric_parameters` [Optional]| Additional parameter specific to each metric.  |  |  |
# | `func_name` [Optional]| The name of python function. | `<metric_type>`_with_nlp |  |
# | `create_integrated_system` [Optional]| Flag for restricting creation of associated integrated system. | `True` | `True` or `False` |
#
# ##### Faithfulness parameters
# | Parameter | Description | Default Value | Possible Value(s) |
# |:-|:-|:-|:-|
# | attributions_count [Optional]| Source attributions are computed for each sentence in the generated answer. Source attribution for a sentence is the set of sentences in the context which contributed to the LLM generating that sentence in the answer.  The attributions_count parameter specifies the number of sentences in the context which need to be identified for attributions.  E.g., if the value is set to 2, then we will find the top 2 sentences from the context as source attributions. | `3` |  |
# | ngrams [Optional]| The number of sentences to be grouped from the context when computing faithfulness score. These grouped sentences will be shown in the attributions. Having a very high value of ngrams might lead to having lower faithfulness scores due to dispersion of data and inclusion of unrelated sentences in the attributions. Having a very low value might lead to increase in metric computation time and attributions not capturing the all the aspects of the answer. | `2` |  |
#
# #### Context relevance parameters
# | Parameter | Description | Default Value | Possible Value(s) |
# |:-|:-|:-|:-|
# | ngrams [Optional]| The number of sentences to be grouped from the context when computing context relevance score. Having a very high value of ngrams might lead to having lower context relevance scores due to dispersion of data and inclusion of unrelated sentences. | `5` |  |

# %%
space_id = "<EDIT_THIS>"  # space in which python function should be deployed

# %% [markdown]
# ### Evaluator creation for retrieval quality

# %%
rq_evaluator_dtls = wos_client.llm_metrics.evaluators.add(
    metric_type="retrieval_quality",
    wx_ai_credentials=WX_AI_CREDENTIALS,
    space_id=space_id,
    question_column=question_column,
    context_columns=context_columns,
    hardware_spec="M",
    metric_parameters={
        # The metrics computed for retrieval quality are context_relevance, retrieval_precision, average_precision, reciprocal_rank, hit_rate, normalized_discounted_cumulative_gain
        # "context_relevance": {
        #     "ngrams": 5
        # },
    },
    func_name="retrieval_quality_with_nlp",
    create_integrated_system=False,
)
print(json.dumps(rq_evaluator_dtls, indent=2))
rq_func_deployment_uid = rq_evaluator_dtls["deployment_uid"]
# Out:
# ######################################################################################
#
# Synchronous deployment creation for id: '4fa7fac2-6cf3-4058-be02-26f91d6bb21c' started
#
# ######################################################################################
#
#
# initializing
# Note: online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead.
# ............
# ready
#
#
# -----------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_id='7710830f-0c7d-4cba-ab87-cd273d066ec2'
# -----------------------------------------------------------------------------------------------
#
#
# {
#   "deployment_uid": "7710830f-0c7d-4cba-ab87-cd273d066ec2",
#   "scoring_url": "https://us-south.ml.cloud.ibm.com/ml/v4/deployments/7710830f-0c7d-4cba-ab87-cd273d066ec2/predictions?version=2021-05-01"
# }

# %% [markdown]
# ### Evaluator creation for faithfulness

# %%
faith_evaluator_dtls = wos_client.llm_metrics.evaluators.add(
    metric_type="faithfulness",
    wx_ai_credentials=WX_AI_CREDENTIALS,
    space_id=space_id,
    question_column=question_column,
    context_columns=context_columns,
    hardware_spec="XL",
    metric_parameters={
        # "attributions_count": 3,
        # "ngrams": 2
    },
    func_name="faithfulness_with_nlp",
    create_integrated_system=False,
)
print(json.dumps(faith_evaluator_dtls, indent=2))
faith_func_deployment_uid = faith_evaluator_dtls["deployment_uid"]
# Out:
# ######################################################################################
#
# Synchronous deployment creation for id: 'ebbf53bf-4d2f-4f4a-82e3-708d249d2019' started
#
# ######################################################################################
#
#
# initializing
# Note: online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead.
# ............
# ready
#
#
# -----------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_id='0702d244-7964-4eb1-829d-88142a0b25ec'
# -----------------------------------------------------------------------------------------------
#
#
# {
#   "deployment_uid": "0702d244-7964-4eb1-829d-88142a0b25ec",
#   "scoring_url": "https://us-south.ml.cloud.ibm.com/ml/v4/deployments/0702d244-7964-4eb1-829d-88142a0b25ec/predictions?version=2021-05-01"
# }

# %% [markdown]
# ### Evaluator creation for answer relevance

# %%
ar_evaluator_dtls = wos_client.llm_metrics.evaluators.add(
    metric_type="answer_relevance",
    wx_ai_credentials=WX_AI_CREDENTIALS,
    space_id=space_id,
    question_column=question_column,
    hardware_spec="M",
    metric_parameters={
    },
    func_name="answer_relevance_with_nlp",
    create_integrated_system=False,
)
print(json.dumps(ar_evaluator_dtls, indent=2))
ar_func_deployment_uid = ar_evaluator_dtls["deployment_uid"]
# Out:
# ######################################################################################
#
# Synchronous deployment creation for id: '34302bd4-f278-43c4-bc98-0bb631060121' started
#
# ######################################################################################
#
#
# initializing
# Note: online_url and serving_urls are deprecated and will be removed in a future release. Use inference instead.
# ...........
# ready
#
#
# -----------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_id='c467860b-340e-443a-8941-4930dd6350fd'
# -----------------------------------------------------------------------------------------------
#
#
# {
#   "deployment_uid": "c467860b-340e-443a-8941-4930dd6350fd",
#   "scoring_url": "https://us-south.ml.cloud.ibm.com/ml/v4/deployments/c467860b-340e-443a-8941-4930dd6350fd/predictions?version=2021-05-01"
# }

# %% [markdown]
# ## Step 4 - Configure retrieval and answer quality metrics
# <a id="config"></a>

# %%
from ibm_metrics_plugin.metrics.llm.config.entities import (
    LLMTaskType,
    LLMMetricType,
)

# %% [markdown]
# ### Scoring function for retrieval quality

# %%
def rq_scoring_fn(input_data):
    results = []

    data = input_data.values.tolist()
    scoring_payload = {
        "input_data": [{"fields": input_data.columns.tolist(), "values": data}]
    }
    watsonx_ai_client.set.default_space(space_id)
    deployment_response = watsonx_ai_client.deployments.score(
        rq_func_deployment_uid, scoring_payload
    )
    results = deployment_response["predictions"][0]["values"]
    return pd.DataFrame({"record_level_metrics": results})

# %% [markdown]
# ### Scoring function for faithfulness

# %%
def faith_scoring_fn(input_data):
    results = []

    data = input_data.values.tolist()
    scoring_payload = {
        "input_data": [{"fields": input_data.columns.tolist(), "values": data}]
    }
    watsonx_ai_client.set.default_space(space_id)
    deployment_response = watsonx_ai_client.deployments.score(
        faith_func_deployment_uid, scoring_payload
    )
    results = deployment_response["predictions"][0]["values"]
    return pd.DataFrame({"record_level_metrics": results})

# %% [markdown]
# ### Scoring function for answer relevance

# %%
def ar_scoring_fn(input_data):
    results = []

    data = input_data.values.tolist()
    scoring_payload = {
        "input_data": [{"fields": input_data.columns.tolist(), "values": data}]
    }
    watsonx_ai_client.set.default_space(space_id)
    deployment_response = watsonx_ai_client.deployments.score(
        ar_func_deployment_uid, scoring_payload
    )
    results = deployment_response["predictions"][0]["values"]
    return pd.DataFrame({"record_level_metrics": results})

# %% [markdown]
# ### Configure metrics parameters

# %% [markdown]
# #### Common parameters
#
# | Parameter | Description | Default Value | Possible Value(s) |
# |:-|:-|:-|:-|
# | context_columns | The list of context column names in the input data frame. |  |  |
# | question_column | the name of the question column in the input data frame. |  |  |
# | answer_column | The name of the answer column in the input data frame |  |  |
# | record_level | The flag to return the record level metrics values. Set the flag under configuration to generate record level metrics for all the metrics. Set the flag under specific metric to generate record level metrics for that metric alone. | `False` | `True`, `False` |

# %% [markdown]
# ##### Faithfulness, Retrieval quality and Answer relevance parameters
#
# | Parameter | Description | Default Value | Possible Value(s) |
# |:-|:-|:-|:-|
# | sample_size [Optional]| The metrics are computed for a maximum of 50 LLM responses.  If you wish to compute it for a smaller number of responses, set the sample_size value to a lower number. If the number of records in the input data frame are more than the sample size, a uniform random sample will taken for computation. | `50` | Integer between 0 to 50. Max value supported is 50 |

# %%
metric_config = {
    "configuration": {
        "record_level": True,
        "context_columns": context_columns,
        "question_column": question_column,
        LLMTaskType.RAG.value: {
            LLMMetricType.RETRIEVAL_QUALITY.value: {
                "scoring_fn": rq_scoring_fn,
                "is_watson_nlp_fn": True,
                # "sample_size": 2,
            },
            LLMMetricType.FAITHFULNESS.value: {
                "scoring_fn": faith_scoring_fn,
                "is_watson_nlp_fn": True,
                # "sample_size": 2,
            },
            LLMMetricType.ANSWER_RELEVANCE.value: {
                "scoring_fn": ar_scoring_fn,
                "is_watson_nlp_fn": True,
                # "sample_size": 2,
            },
        },
    },
    # Uncomment this to activate sampling logic 
    # "total_records": len(data),
}

# %% [markdown]
# ### Create the input and output data frames and send them as input to compute metrics

# %%
from copy import deepcopy

input_columns = deepcopy(context_columns)
input_columns.append(question_column)
df_input = data[input_columns].copy()
df_output = data[[answer_column]].copy()

# %% [markdown]
# ## Step 5 - Compute the retrieval and answer quality metrics <a id="compute"></a>

# %%
metrics_result = wos_client.llm_metrics.compute_metrics(
    metric_config, sources=df_input, predictions=df_output
)

print(json.dumps(metrics_result, indent=2))
# Out:
# {
#   "faithfulness": {
#     "metric_value": 0.7072,
#     "mean": 0.7072,
#     "min": 0.0138,
#     "max": 0.9951,
#     "total_records": 5,
#     "record_level_metrics": [
#       {
#         "record_id": "fb035ee8-6ebf-4d3f-b252-eca2ff63fbc4",
#         "faithfulness": 0.5906,
#         "faithfulness_attributions": [
#           {
#             "output_text": "ARPA-H is the Advanced Research Projects Agency for Health, which is an agency that aims to drive breakthroughs in cancer, Alzheimer's, diabetes, and more.",
#             "faithfulness_score": 0.2397,
#             "attributions": [
#               {
#                 "faithfulness_scores": [
#                   0.2397,
#                   0.2165
#                 ],
#                 "feature_name": "context1",
#                 "feature_values": [
#                   "It\u2019s based on DARPA\u2014the Defense Department project that led to the Internet, GPS, and so much more.  ARPA-H will have a singular purpose\u2014to drive breakthroughs in cancer, Alzheimer\u2019s, diabetes, and more.",
#                   "ARPA-H will have a singular purpose\u2014to drive breakthroughs in cancer, Alzheimer\u2019s, diabetes, and more. A unity agenda for the nation."
#                 ]
#               },
#               {
#                 "faithfulness_scores": [
#                   0.0027
#                 ],
#                 "feature_name": "context4",
#                 "feature_values": [
#                   "Through her pain she found purpose to demand we do better. Tonight, Danielle\u2014we are."
#                 ]
#               }
#             ]
#           },
#           {
#             "output_text": "It was proposed by the U.S. President to supercharge the Cancer Moonshot and cut the cancer death rate by at least 50% over the next 25 years.",
#             "faithfulness_score": 0.9414,
#             "attributions": [
#               {
#                 "faithfulness_scores": [
#                   0.9414,
#                   0.0018
#                 ],
#                 "feature_name": "context1",
#                 "feature_values": [
#                   "Last month, I announced our plan to supercharge  the Cancer Moonshot that President Obama asked me to lead six years ago. Our goal is to cut the cancer death rate by at least 50% over the next 25 years, turn more cancers from death sentences into treatable diseases.",
#                   "My fellow Americans\u2014tonight , we have gathered in a sacred space\u2014the citadel of our democracy. In this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things."
#                 ]
#               },
#               {
#                 "faithfulness_scores": [
#                   0.0034
#                 ],
#                 "feature_name": "context4",
#                 "feature_values": [
#                   "Through her pain she found purpose to demand we do better. Tonight, Danielle\u2014we are."
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "record_id": "87f342b5-64f4-4f88-8318-c602c7d7d0b4",
#         "faithfulness": 0.9452,
#         "faithfulness_attributions": [
#           {
#             "output_text": "Ford is investing $11 billion to build electric vehicles, creating 11,000 jobs across the country.",
#             "faithfulness_score": 0.9947,
#             "attributions": [
#               {
#                 "faithfulness_scores": [
#                   0.9947,
#                   0.9941,
#                   0.0019
#                 ],
#                 "feature_name": "context1",
#                 "feature_values": [
#                   "Ford is investing $11 billion to build electric vehicles, creating 11,000 jobs across the country. GM is making the largest investment in its history\u2014$7 billion to build electric vehicles, creating 4,000 jobs in Michigan.",
#                   "That\u2019s what is happening. Ford is investing $11 billion to build electric vehicles, creating 11,000 jobs across the country.",
#                   "And Intel is not alone. There\u2019s something happening in America."
#                 ]
#               }
#             ]
#           },
#           {
#             "output_text": "GM is making the largest investment in its history\u2014$7 billion to build electric vehicles, creating 4,000 jobs in Michigan.So, the total investment of Ford and GM to build electric vehicles is $11 billion + $7 billion = $18 billion.",
#             "faithfulness_score": 0.8957,
#             "attributions": [
#               {
#                 "faithfulness_scores": [
#                   0.8957,
#                   0.0027,
#                   0.0018
#                 ],
#                 "feature_name": "context1",
#                 "feature_values": [
#                   "Ford is investing $11 billion to build electric vehicles, creating 11,000 jobs across the country. GM is making the largest investment in its history\u2014$7 billion to build electric vehicles, creating 4,000 jobs in Michigan.",
#                   "GM is making the largest investment in its history\u2014$7 billion to build electric vehicles, creating 4,000 jobs in Michigan. All told, we created 369,000 new manufacturing jobs in America just last year.",
#                   "That\u2019s what is happening. Ford is investing $11 billion to build electric vehicles, creating 11,000 jobs across the country."
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "record_id": "55405382-f7ef-4eec-8e98-641cc6b406b9",
#         "faithfulness": 0.9951,
#         "faithfulness_attributions": [
#           {
#             "output_text": "The proposed tax rate for corporations is a 15% minimum tax rate.",
#             "faithfulness_score": 0.9951,
#             "attributions": [
#               {
#                 "faithfulness_scores": [
#                   0.9951,
#                   0.995
#                 ],
#                 "feature_name": "context1",
#                 "feature_values": [
#                   "That\u2019s why I\u2019ve proposed a 15% minimum tax rate for corporations.",
#                   "That\u2019s simply not fair. That\u2019s why I\u2019ve proposed a 15% minimum tax rate for corporations."
#                 ]
#               },
#               {
#                 "faithfulness_scores": [
#                   0.9951
#                 ],
#                 "feature_name": "context2",
#                 "feature_values": [
#                   "We got more than 130 countries to agree on a global minimum tax rate so companies can\u2019t get out of paying their taxes at home by shipping jobs and factories overseas."
#                 ]
#               },
#               {
#                 "faithfulness_scores": [
#                   0.014
#                 ],
#                 "feature_name": "context3",
#                 "feature_values": [
#                   "It created jobs. Lots of jobs."
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "record_id": "0f167bbb-d5e8-4835-ab9a-3094e2d8f6ed",
#         "faithfulness": 0.9911,
#         "faithfulness_attributions": [
#           {
#             "output_text": "Intel is going to build a $20 billion semiconductor \"mega site\" with up to eight state-of-the-art factories.",
#             "faithfulness_score": 0.9911,
#             "attributions": [
#               {
#                 "faithfulness_scores": [
#                   0.9911,
#                   0.0024
#                 ],
#                 "feature_name": "context1",
#                 "feature_values": [
#                   "This is where Intel, the American company that helped build Silicon Valley, is going to build its $20 billion semiconductor \u201cmega site\u201d. Up to eight state-of-the-art factories in one place.",
#                   "It won\u2019t look like much, but if you stop and look closely, you\u2019ll see a \u201cField of dreams,\u201d the ground on which America\u2019s future will be built. This is where Intel, the American company that helped build Silicon Valley, is going to build its $20 billion semiconductor \u201cmega site\u201d."
#                 ]
#               },
#               {
#                 "faithfulness_scores": [
#                   0.0032
#                 ],
#                 "feature_name": "context3",
#                 "feature_values": [
#                   "That\u2019s why it is so important to pass the Bipartisan Innovation Act sitting in Congress that will make record investments in emerging technologies and American manufacturing. Let me give you one example of why it\u2019s so important to pass it."
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "record_id": "bb23daf2-6ce6-4c1e-8e16-1767a924fa69",
#         "faithfulness": 0.0138,
#         "faithfulness_attributions": [
#           {
#             "output_text": "The document does not provide information on the number of electric vehicle charging stations built.",
#             "faithfulness_score": 0.0147,
#             "attributions": [
#               {
#                 "faithfulness_scores": [
#                   0.0027
#                 ],
#                 "feature_name": "context1",
#                 "feature_values": [
#                   "Just look around and you\u2019ll see an amazing story. The rebirth of the pride that comes from stamping products \u201cMade In America.\u201d The revitalization of American manufacturing."
#                 ]
#               },
#               {
#                 "faithfulness_scores": [
#                   0.0147,
#                   0.0042
#                 ],
#                 "feature_name": "context3",
#                 "feature_values": [
#                   "And we\u2019ll do it all to withstand the devastating effects of the climate crisis and promote environmental justice. We\u2019ll build a national network of 500,000 electric vehicle charging stations, begin to replace poisonous lead pipes\u2014so every child\u2014and every American\u2014has clean water to drink at home and at school, provide affordable high-speed internet for every American\u2014urban, suburban, rural, and tribal communities.",
#                   "We\u2019ll build a national network of 500,000 electric vehicle charging stations, begin to replace poisonous lead pipes\u2014so every child\u2014and every American\u2014has clean water to drink at home and at school, provide affordable high-speed internet for every American\u2014urban, suburban, rural, and tribal communities. 4,000 projects have already been announced."
#                 ]
#               }
#             ]
#           },
#           {
#             "output_text": "It only mentions the plan to build a national network of 500,000 electric vehicle charging stations.",
#             "faithfulness_score": 0.0129,
#             "attributions": [
#               {
#                 "faithfulness_scores": [
#                   0.0129,
#                   0.0051
#                 ],
#                 "feature_name": "context3",
#                 "feature_values": [
#                   "And we\u2019ll do it all to withstand the devastating effects of the climate crisis and promote environmental justice. We\u2019ll build a national network of 500,000 electric vehicle charging stations, begin to replace poisonous lead pipes\u2014so every child\u2014and every American\u2014has clean water to drink at home and at school, provide affordable high-speed internet for every American\u2014urban, suburban, rural, and tribal communities.",
#                   "We\u2019ll build a national network of 500,000 electric vehicle charging stations, begin to replace poisonous lead pipes\u2014so every child\u2014and every American\u2014has clean water to drink at home and at school, provide affordable high-speed internet for every American\u2014urban, suburban, rural, and tribal communities. 4,000 projects have already been announced."
#                 ]
#               },
#               {
#                 "faithfulness_scores": [
#                   0.0017
#                 ],
#                 "feature_name": "context4",
#                 "feature_values": [
#                   "We won\u2019t be able to compete for the jobs of the 21st Century if we don\u2019t fix that. That\u2019s why it was so important to pass the Bipartisan Infrastructure Law\u2014the most sweeping investment to rebuild America in history."
#                 ]
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "answer_relevance": {
#     "metric_value": 0.9846,
#     "mean": 0.9846,
#     "min": 0.964,
#     "max": 0.9953,
#     "total_records": 5,
#     "record_level_metrics": [
#       {
#         "answer_relevance": 0.964,
#         "record_id": "fb035ee8-6ebf-4d3f-b252-eca2ff63fbc4"
#       },
#       {
#         "answer_relevance": 0.9877,
#         "record_id": "87f342b5-64f4-4f88-8318-c602c7d7d0b4"
#       },
#       {
#         "answer_relevance": 0.9953,
#         "record_id": "55405382-f7ef-4eec-8e98-641cc6b406b9"
#       },
#       {
#         "answer_relevance": 0.9935,
#         "record_id": "0f167bbb-d5e8-4835-ab9a-3094e2d8f6ed"
#       },
#       {
#         "answer_relevance": 0.9823,
#         "record_id": "bb23daf2-6ce6-4c1e-8e16-1767a924fa69"
#       }
#     ]
#   },
#   "retrieval_quality": {
#     "context_relevance": {
#       "metric_value": 0.5364,
#       "mean": 0.5364,
#       "min": 0.1992,
#       "max": 0.8737,
#       "total_records": 5
#     },
#     "reciprocal_rank": {
#       "metric_value": 0.4,
#       "mean": 0.4,
#       "min": 0.0,
#       "max": 1.0
#     },
#     "retrieval_precision": {
#       "metric_value": 0.15,
#       "mean": 0.15,
#       "min": 0.0,
#       "max": 0.5
#     },
#     "average_precision": {
#       "metric_value": 0.36,
#       "mean": 0.36,
#       "min": 0.0,
#       "max": 1.0
#     },
#     "hit_rate": {
#       "metric_value": 0.4,
#       "mean": 0.4,
#       "min": 0,
#       "max": 1
#     },
#     "ndcg": {
#       "metric_value": 0.9277,
#       "mean": 0.9277,
#       "min": 0.6561,
#       "max": 1.0
#     },
#     "record_level_metrics": [
#       {
#         "record_id": "fb035ee8-6ebf-4d3f-b252-eca2ff63fbc4",
#         "context_relevance": 0.8103,
#         "context_relevances": {
#           "context_columns": [
#             "context1",
#             "context2",
#             "context3",
#             "context4"
#           ],
#           "context_relevances": [
#             0.8103,
#             0.6411,
#             0.6468,
#             0.806
#           ]
#         },
#         "retrieval_precision": 0.5,
#         "average_precision": 0.8,
#         "reciprocal_rank": 1.0,
#         "hit_rate": 1,
#         "ndcg": 0.9828
#       },
#       {
#         "record_id": "87f342b5-64f4-4f88-8318-c602c7d7d0b4",
#         "context_relevance": 0.2005,
#         "context_relevances": {
#           "context_columns": [
#             "context1",
#             "context2",
#             "context3",
#             "context4"
#           ],
#           "context_relevances": [
#             0.2005,
#             0.0982,
#             0.034,
#             0.0215
#           ]
#         },
#         "retrieval_precision": 0.0,
#         "average_precision": 0,
#         "reciprocal_rank": 0,
#         "hit_rate": 0,
#         "ndcg": 1.0
#       },
#       {
#         "record_id": "55405382-f7ef-4eec-8e98-641cc6b406b9",
#         "context_relevance": 0.1992,
#         "context_relevances": {
#           "context_columns": [
#             "context1",
#             "context2",
#             "context3",
#             "context4"
#           ],
#           "context_relevances": [
#             0.1992,
#             0.0133,
#             0.0074,
#             0.0082
#           ]
#         },
#         "retrieval_precision": 0.0,
#         "average_precision": 0,
#         "reciprocal_rank": 0,
#         "hit_rate": 0,
#         "ndcg": 0.9997
#       },
#       {
#         "record_id": "0f167bbb-d5e8-4835-ab9a-3094e2d8f6ed",
#         "context_relevance": 0.8737,
#         "context_relevances": {
#           "context_columns": [
#             "context1",
#             "context2",
#             "context3",
#             "context4"
#           ],
#           "context_relevances": [
#             0.8737,
#             0.7133,
#             0.4553,
#             0.2424
#           ]
#         },
#         "retrieval_precision": 0.25,
#         "average_precision": 1.0,
#         "reciprocal_rank": 1.0,
#         "hit_rate": 1,
#         "ndcg": 1.0
#       },
#       {
#         "record_id": "bb23daf2-6ce6-4c1e-8e16-1767a924fa69",
#         "context_relevance": 0.5984,
#         "context_relevances": {
#           "context_columns": [
#             "context1",
#             "context2",
#             "context3",
#             "context4"
#           ],
#           "context_relevances": [
#             0.0601,
#             0.0134,
#             0.5984,
#             0.0058
#           ]
#         },
#         "retrieval_precision": 0.0,
#         "average_precision": 0,
#         "reciprocal_rank": 0,
#         "hit_rate": 0,
#         "ndcg": 0.6561
#       }
#     ],
#     "total_records": 5
#   }
# }

# %% [markdown]
# ## Step 6 - Display the results <a id="results"></a>

# %%
results_df = data.copy()

for metric_name, metric_data in metrics_result.items():
    vals = {}
    if "record_level_metrics" in metric_data:
        for rm in metric_data["record_level_metrics"]:
            for m, mv in rm.items():
                if m != "record_id" and m!= "faithfulness_attributions" and m!= "context_relevances":  # Excluding columns
                    if m in vals:
                        vals[m].append(mv)
                    else:
                        vals[m] = [mv]

    if vals:
        for k, v in vals.items():
            results_df[k] = v

results_df
# Out:
#                                             context1  \
# 0  Last month, I announced our plan to supercharg...
# 1  So let’s not wait any longer. Send it to my de...
# 2  My plan will cut the cost in half for most fam...
# 3  If you travel 20 miles east of Columbus, Ohio,...
# 4  So let’s not wait any longer. Send it to my de...
#
#                                             context2  \
# 0  For that purpose we’ve mobilized American grou...
# 1  If you travel 20 miles east of Columbus, Ohio,...
# 2  We got more than 130 countries to agree on a g...
# 3  So let’s not wait any longer. Send it to my de...
# 4  If you travel 20 miles east of Columbus, Ohio,...
#
#                                             context3  \
# 0  If you travel 20 miles east of Columbus, Ohio,...
# 1  When we use taxpayer dollars to rebuild Americ...
# 2  And unlike the $2 Trillion tax cut passed in t...
# 3  When we use taxpayer dollars to rebuild Americ...
# 4  It is going to transform America and put us on...
#
#                                             context4  \
# 0  But cancer from prolonged exposure to burn pit...
# 1  It is going to transform America and put us on...
# 2  We’re going after the criminals who stole bill...
# 3  It is going to transform America and put us on...
# 4  Vice President Harris and I ran for office wit...
#
#                                             question  \
# 0                                    What is ARPA-H?
# 1  What is the investment of Ford and GM to build...
# 2    What is the proposed tax rate for corporations?
# 3                      What is Intel going to build?
# 4  How many electric vehicle charging stations ar...
#
#                                               answer  faithfulness  \
# 0  ARPA-H is the Advanced Research Projects Agenc...        0.5906
# 1  Ford is investing $11 billion to build electri...        0.9452
# 2  The proposed tax rate for corporations is a 15...        0.9951
# 3  Intel is going to build a $20 billion semicond...        0.9911
# 4  The document does not provide information on t...        0.0138
#
#    answer_relevance  context_relevance  retrieval_precision  \
# 0            0.9640             0.8103                 0.50
# 1            0.9877             0.2005                 0.00
# 2            0.9953             0.1992                 0.00
# 3            0.9935             0.8737                 0.25
# 4            0.9823             0.5984                 0.00
#
#    average_precision  reciprocal_rank  hit_rate    ndcg
# 0                0.8              1.0         1  0.9828
# 1                0.0              0.0         0  1.0000
# 2                0.0              0.0         0  0.9997
# 3                1.0              1.0         1  1.0000
# 4                0.0              0.0         0  0.6561
