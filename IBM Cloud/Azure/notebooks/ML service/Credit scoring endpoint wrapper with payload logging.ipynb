# %% [markdown]
# # Logging the payload with scoring endpoint wrapper
#
# Now, you're ready to create credit risk scoring endpoint wrapper. The goal of the wrapper is to automatically log all input and output payloads from credit risk deployment (created previously).
#
# ## Prerequisites to this tutorial:
# > * Credit Risk model deployment on Azure ML Service (scoring endpoint)
#
#
# In this part of the tutorial, you use Azure Machine Learning service to:
#
# > * Set up your testing environment
# > * Retrieve the deployment from your workspace
# > * Test the deployment locally
# > * Deploy the wrapper to ACI
# > * Test the wrapper

# %% [markdown]
# If you have not already, provision an instance of IBM Watson OpenScale using the [OpenScale link in the Cloud catalog](https://cloud.ibm.com/catalog/services/watson-openscale).
#
# Your Cloud API key can be generated by going to the [**Users** section of the Cloud console](https://cloud.ibm.com/iam#/users). From that page, click your name, scroll down to the **API Keys** section, and click **Create an IBM Cloud API key**. Give your key a name and click **Create**, then copy the created key and paste it below.
#
# **NOTE:** You can also get OpenScale `API_KEY` using IBM CLOUD CLI.
#
# How to install IBM Cloud (bluemix) console: [instruction](https://console.bluemix.net/docs/cli/reference/ibmcloud/download_cli.html#install_use)
#
# How to get api key using console:
# ```
# bx login --sso
# bx iam api-key-create 'my_key'
# ```

# %%
CLOUD_API_KEY = 'wqMwzhQ7GRNBlH5iS3OVGlf3Ym4OD4EPJjaA6Eg8mQgg'

# %%
DB_CREDENTIALS=None
#DB_CREDENTIALS= {"hostname":"","username":"","password":"","database":"","port":"","ssl":True,"sslmode":"","certificate_base64":""}

# %% [markdown]
# ## Save training data to COS for Openscale reference

# %%
IAM_URL="https://iam.ng.bluemix.net/oidc/token"
COS_API_KEY_ID = "917Z-0MQzVpgdqkHClXbfDchrXZ_bl7kbCxZSkynzsLP"
COS_RESOURCE_CRN = "crn:v1:bluemix:public:cloud-object-storage:global:a/e0b56432b1f1bd804706dc29b8a89ca1:57b5eb6e-7b5d-4b90-a8e8-3736129c9010::" # eg "crn:v1:bluemix:public:cloud-object-storage:global:a/3bf0d9003abfb5d29761c3e97696b71c:d6f04d83-6c4f-4a62-a165-696756d63903::"
COS_ENDPOINT = "https://s3.us.cloud-object-storage.appdomain.cloud" # Current list avaiable at https://control.cloud-object-storage.cloud.ibm.com/v2/endpoints
BUCKET_NAME = "wmlv4-donotdelete-pr-e8rgr9bhcjtlae" #example: "credit-risk-training-data"
training_data_file_name="credit_risk_training.csv"

# %%
# !rm -rf credit_risk_training.csv
# !wget "https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/data/credit_risk/credit_risk_training.csv"
# Out:
# --2020-11-04 12:31:27--  https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/data/credit_risk/credit_risk_training.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.128.133, 151.101.192.133, 151.101.0.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.128.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 694222 (678K) [text/plain]
# Saving to: ‘credit_risk_training.csv’
#
# credit_risk_trainin 100%[===================>] 677.95K  2.85MB/s    in 0.2s
#
# 2020-11-04 12:31:28 (2.85 MB/s) - ‘credit_risk_training.csv’ saved [694222/694222]

# %%
import ibm_boto3
from ibm_botocore.client import Config, ClientError

cos_client = ibm_boto3.resource("s3",
    ibm_api_key_id=COS_API_KEY_ID,
    ibm_service_instance_id=COS_RESOURCE_CRN,
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version="oauth"),
    endpoint_url=COS_ENDPOINT
)

# %%
with open(training_data_file_name, "rb") as file_data:
    cos_client.Object(BUCKET_NAME, training_data_file_name).upload_fileobj(
        Fileobj=file_data
    )

# %%
import pandas as pd
data_df = pd.read_csv("credit_risk_training.csv",
                    dtype={'LoanDuration': int, 'LoanAmount': int, 'InstallmentPercent': int, 'CurrentResidenceDuration': int, 'Age': int, 'ExistingCreditsCount': int, 'Dependents': int})

# %% [markdown]
# ## Install `ibm-watson-openscale` package

# %%
# !pip install --upgrade ibm-cloud-sdk-core --no-cache | tail -n 1
# !pip install --upgrade ibm-watson-openscale --no-cache | tail -n 1
# !pip install --upgrade azureml-core --no-cache | tail -n 1
# Out:
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Applications/anaconda3/lib/python3.7/site-packages (from python_dateutil>=2.5.3->ibm-cloud-sdk-core) (1.12.0)
# Requirement already satisfied, skipping upgrade: PyJWT>=1.7.1 in /Applications/anaconda3/lib/python3.7/site-packages (from ibm-cloud-sdk-core>=1.5->ibm-watson-openscale) (1.7.1)
# Requirement already satisfied, skipping upgrade: pycparser in /Applications/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core) (2.19)

# %% [markdown]
# ### Action: Restart the kernel

# %% [markdown]
# ## Set up the workspace

# %%
import os
import urllib.request
from azureml.core import Workspace
from azureml.core.authentication import InteractiveLoginAuthentication

az_ml_service_credentials = {'tenant_id': 'fcf67057-50c9-4ad4-98f3-ffca64add9e9',
                             'subscription_id': '744bca72-2299-451c-b682-ed6fb75fb671', 
                             'resource_group': 'ai-ops-squad',
                             'workspace_name': 'wos-ws'}

# %%
interactive_auth = InteractiveLoginAuthentication(tenant_id=az_ml_service_credentials['tenant_id'])

ws = Workspace(subscription_id=az_ml_service_credentials['subscription_id'], 
               resource_group=az_ml_service_credentials['resource_group'], 
               workspace_name=az_ml_service_credentials['workspace_name'], 
               auth=interactive_auth)

# %%
ws.write_config()

# %%
ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep='\n')
# Out:
# Workspace name: wos-ws
# Azure region: southcentralus
# Subscription id: 744bca72-2299-451c-b682-ed6fb75fb671
# Resource group: ai-ops-squad

# %% [markdown]
# ## Set up the environment
#
# Start by setting up a testing environment.
#
# ### Import packages
#
# Import the Python packages needed for this tutorial.

# %%
import azureml.core
import os 

print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  1.17.0

# %% [markdown]
# ### Retrieve deployments
#
# You created a model deployment in your workspace in the previous tutorial. Now, let's list the deployments.

# %%
from azureml.core.webservice import AciWebservice

credit_risk_deployment_name = 'credit-risk-rsalehin'
credit_risk_scoring_endpoint = None

webservices = AciWebservice.list(ws)
for service in webservices:
    if service.name == credit_risk_deployment_name:
        credit_risk_scoring_endpoint = service.scoring_uri
        
print('scoring endpoint', credit_risk_scoring_endpoint)
# Out:
# scoring endpoint http://4931176f-9943-46a2-857f-dd355d52914a.southcentralus.azurecontainer.io/score

# %% [markdown]
# ## Test endpoint locally
#
# Before creating a scoring endpoint wrapper let's test the original scoring endpoint.

# %%
scoring_data = {"input":[{
                            'CheckingStatus': "0_to_200", 'LoanDuration': 31, 'CreditHistory': "credits_paid_to_date", 'LoanPurpose': "other",
                            'LoanAmount': 1889, 'ExistingSavings': "100_to_500",'EmploymentDuration': "less_1",'InstallmentPercent': 3,'Sex': "female",
                            'OthersOnLoan': "none",'CurrentResidenceDuration': 3, 'OwnsProperty': "savings_insurance", 'Age': 32,'InstallmentPlans': "none",
                            'Housing': "own",'ExistingCreditsCount': 1,'Job': "skilled",'Dependents': 1,'Telephone': "none",'ForeignWorker': "yes",
                        },
                        {
                            'CheckingStatus': "no_checking", 'LoanDuration': 13, 'CreditHistory': "credits_paid_to_date", 'LoanPurpose': "car_new",
                            'LoanAmount': 1389, 'ExistingSavings': "100_to_500",'EmploymentDuration': "1_to_4",'InstallmentPercent': 2,'Sex': "male",
                            'OthersOnLoan': "none",'CurrentResidenceDuration': 3, 'OwnsProperty': "savings_insurance", 'Age': 25,'InstallmentPlans': "none",
                            'Housing': "own",'ExistingCreditsCount': 2,'Job': "skilled",'Dependents': 2,'Telephone': "none",'ForeignWorker': "yes",
                        }]
              }

# %%
import requests

headers = {'Content-Type':'application/json'}
resp = requests.post(credit_risk_scoring_endpoint, json=scoring_data, headers=headers)
output_data = json.loads(resp.json())

print("POST to url", credit_risk_scoring_endpoint)
print(output_data)
# Out:
# POST to url http://4931176f-9943-46a2-857f-dd355d52914a.southcentralus.azurecontainer.io/score
# {'output': [{'Scored Labels': 'No Risk', 'Scored Probabilities': [0.8922524675865824, 0.10774753241341757]}, {'Scored Labels': 'No Risk', 'Scored Probabilities': [0.8335192848546905, 0.1664807151453095]}]}

# %% [markdown]
# ## Add service provider in Openscale

# %%
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator,BearerTokenAuthenticator

from ibm_watson_openscale import *
from ibm_watson_openscale.supporting_classes.enums import *
from ibm_watson_openscale.supporting_classes import *


authenticator = IAMAuthenticator(apikey=CLOUD_API_KEY)
#authenticator = BearerTokenAuthenticator(bearer_token=IAM_TOKEN) ## uncomment if using IAM token
wos_client = APIClient(authenticator=authenticator)
wos_client.version
# Out:
# '3.0.2'

# %%
wos_client.data_marts.show()
# Out:
# <HTML>
#         <body>
#             <h3>Data Marts</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>name</th><th style='border: 1px solid #dddddd'>description</th><th style='border: 1px solid #dddddd'>internal_database</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>WOS Data Mart</td><td style='border: 1px solid #dddddd'>Data Mart created by WOS tutorial notebook</td><td style='border: 1px solid #dddddd'>True</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2020-07-22 22:17:14.701000+00:00</td><td style='border: 1px solid #dddddd'>5a0b9076-fcf6-49e8-a824-9e3a6b4c2a56</td></tr>
#             </table>
#         </body>
#         </HTML>

# %%
data_marts = wos_client.data_marts.list().result.data_marts
if len(data_marts) == 0:
    if DB_CREDENTIALS is not None:
        if SCHEMA_NAME is None: 
            print("Please specify the SCHEMA_NAME and rerun the cell")

        print('Setting up external datamart')
        added_data_mart_result = wos_client.data_marts.add(
                background_mode=False,
                name="WOS Data Mart",
                description="Data Mart created by WOS tutorial notebook",
                database_configuration=DatabaseConfigurationRequest(
                  database_type=DatabaseType.POSTGRESQL, # if using DB2 use DatabaseType.DB2
                    credentials=PrimaryStorageCredentialsLong(
                        hostname=DB_CREDENTIALS['hostname'],
                        username=DB_CREDENTIALS['username'],
                        password=DB_CREDENTIALS['password'],
                        db=DB_CREDENTIALS['database'],
                        port=DB_CREDENTIALS['port'],
                        ssl=True,
                        sslmode=DB_CREDENTIALS['sslmode'],
                        certificate_base64=DB_CREDENTIALS['certificate_base64']
                    ),
                    location=LocationSchemaName(
                        schema_name= SCHEMA_NAME
                    )
                )
             ).result
    else:
        print('Setting up internal datamart')
        added_data_mart_result = wos_client.data_marts.add(
                background_mode=False,
                name="WOS Data Mart",
                description="Data Mart created by WOS tutorial notebook", 
                internal_database = True).result
        
    data_mart_id = added_data_mart_result.metadata.id
    
else:
    data_mart_id=data_marts[0].metadata.id
    print('Using existing datamart {}'.format(data_mart_id))
# Out:
# Using existing datamart 5a0b9076-fcf6-49e8-a824-9e3a6b4c2a56

# %%
AZURE_ENGINE_CREDENTIALS = {
    "client_id": "c943757b-86e7-417c-b3e4-45e2738fe59c",
    "client_secret": "5c975694-9d72-4c42-9bef-5255bdb8475c",
    "subscription_id": "744bca72-2299-451c-b682-ed6fb75fb671",
    "tenant": "fcf67057-50c9-4ad4-98f3-ffca64add9e9"
}

# %%
SERVICE_PROVIDER_NAME = "Azure Machine Learning service"
SERVICE_PROVIDER_DESCRIPTION = "Added by Azure tutorial WOS notebook."

# %%
service_providers = wos_client.service_providers.list().result.service_providers
for service_provider in service_providers:
    service_instance_name = service_provider.entity.name
    if service_instance_name == SERVICE_PROVIDER_NAME:
        service_provider_id = service_provider.metadata.id
        wos_client.service_providers.delete(service_provider_id)
        print("Deleted existing service_provider for WML instance: {}".format(service_provider_id))

# %%
service_type = "azure_machine_learning_service"
added_service_provider_result = wos_client.service_providers.add(
        name=SERVICE_PROVIDER_NAME,
        description=SERVICE_PROVIDER_DESCRIPTION,
        service_type = service_type,
        credentials=AzureCredentials(
            subscription_id= AZURE_ENGINE_CREDENTIALS['subscription_id'], 
            client_id = AZURE_ENGINE_CREDENTIALS['client_id'], 
            client_secret= AZURE_ENGINE_CREDENTIALS['client_secret'],
            tenant = AZURE_ENGINE_CREDENTIALS['tenant']
        ),
        background_mode=False
    ).result
service_provider_id = added_service_provider_result.metadata.id
service_provider_id
# Out:
# =================================================================================
#
#  Waiting for end of adding service provider 188dabe9-cac0-45ba-89e2-cf9946941a74
#
# =================================================================================
#
#
#
# active
#
# -----------------------------------------------
#  Successfully finished adding service provider
# -----------------------------------------------
# '188dabe9-cac0-45ba-89e2-cf9946941a74'

# %%
asset_deployment_details = wos_client.service_providers.list_assets(data_mart_id=data_mart_id, service_provider_id=service_provider_id).result
asset_deployment_details
# Out:
# {'resources': [{'metadata': {'guid': 'd52e1c7c6f76161c133bf552afeb3499',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/campaign-effectiveness-mon-qa?api-version=2018-03-01-preview',
#     'created_at': '2020-06-12T21:25:10.4208064Z',
#     'modified_at': '2020-06-12T21:25:10.4208064Z'},
#    'entity': {'name': 'campaign-effectiveness-mon-qa',
#     'deployment_rn': 'campaign-effectiveness-mon-qa',
#     'type': 'online',
#     'description': 'campaign-effectiveness used for monitor automation tests',
#     'scoring_endpoint': {'url': 'http://76f68e7a-9a31-4f83-8038-9df18b3e1e9d.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '1856ecb5898d3b88cf3c95c8f47f992f',
#      'asset_rn': 'campaign-effectiveness-mon-qa',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/campaign-effectiveness-mon-qa?api-version=2018-03-01-preview',
#      'name': 'campaign-effectiveness-mon-qa',
#      'asset_type': 'model',
#      'created_at': '2020-06-12T21:25:10.4208064Z'}}},
#   {'metadata': {'guid': '93113b89f46ed19c2bfb167921b90504',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/ai-ops-aks-mon-qa?api-version=2018-03-01-preview',
#     'created_at': '2020-05-29T22:28:47.6919234Z',
#     'modified_at': '2020-05-29T22:28:47.6919234Z'},
#    'entity': {'name': 'ai-ops-aks-mon-qa',
#     'deployment_rn': 'ai-ops-aks-mon-qa',
#     'type': 'online',
#     'description': 'ai-ops-aks used for monitor automation tests (actually, using ACI though)',
#     'scoring_endpoint': {'url': 'http://3ebb2913-4b1a-4709-88b3-6f5bee6f84a7.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'bfd6ad30cf3a037f50498a54af04e1d1',
#      'asset_rn': 'ai-ops-aks-mon-qa',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/ai-ops-aks-mon-qa?api-version=2018-03-01-preview',
#      'name': 'ai-ops-aks-mon-qa',
#      'asset_type': 'model',
#      'created_at': '2020-05-29T22:28:47.6919234Z'}}},
#   {'metadata': {'guid': '4939a113425e454df51188e4919e3f52',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-ops?api-version=2018-03-01-preview',
#     'created_at': '2019-07-05T08:06:00.6552118Z',
#     'modified_at': '2019-07-05T08:06:00.6552118Z'},
#    'entity': {'name': 'german-credit-risk-ops',
#     'deployment_rn': 'german-credit-risk-ops',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn',
#     'scoring_endpoint': {'url': 'http://4cc24b75-befc-4f1c-bb7b-1163fd5412f4.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '4c162752243b9a79f68ad0e92c237bab',
#      'asset_rn': 'german-credit-risk-ops',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-ops?api-version=2018-03-01-preview',
#      'name': 'german-credit-risk-ops',
#      'asset_type': 'model',
#      'created_at': '2019-07-05T08:06:00.6552118Z'}}},
#   {'metadata': {'guid': '8fea0911cdce4ddeb4d470300716beab',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-bias?api-version=2018-03-01-preview',
#     'created_at': '2019-07-05T07:57:41.4884409Z',
#     'modified_at': '2019-07-05T07:57:41.4884409Z'},
#    'entity': {'name': 'german-credit-risk-bias',
#     'deployment_rn': 'german-credit-risk-bias',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn',
#     'scoring_endpoint': {'url': 'http://b12ac4ab-04dd-4557-8300-70d56dfc1521.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '70e8313c241db2680aa551f1656ffe4e',
#      'asset_rn': 'german-credit-risk-bias',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-bias?api-version=2018-03-01-preview',
#      'name': 'german-credit-risk-bias',
#      'asset_type': 'model',
#      'created_at': '2019-07-05T07:57:41.4884409Z'}}},
#   {'metadata': {'guid': '5aeb349e68009fdfa66a3db64b8b5e7e',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/ai-ops-aks-mlg-qa?api-version=2018-03-01-preview',
#     'created_at': '2019-07-02T18:25:58.5088977Z',
#     'modified_at': '2019-07-02T18:25:59.9034374Z'},
#    'entity': {'name': 'ai-ops-aks-mlg-qa',
#     'deployment_rn': 'ai-ops-aks-mlg-qa',
#     'type': 'online',
#     'description': 'ai-ops-aks used for ML Gateway automation tests',
#     'scoring_endpoint': {'url': 'http://13.65.32.22:80/api/v1/service/ai-ops-aks-mlg-qa/score',
#      'credentials': {'secondaryKey': 'O0uevsk04v9Z2dBzgNyhDvPltlbiDgnT',
#       'token': 'o3XPcimysWJIyYvvGrT7sDGJaLwSgaCn'},
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'b17220026885e46280b4c8293f3ce616',
#      'asset_rn': 'ai-ops-aks-mlg-qa',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/ai-ops-aks-mlg-qa?api-version=2018-03-01-preview',
#      'name': 'ai-ops-aks-mlg-qa',
#      'asset_type': 'model',
#      'created_at': '2019-07-02T18:25:58.5088977Z'}}},
#   {'metadata': {'guid': 'ac8fbf63279e728a88aa1b3e3e495c37',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/campaign-effectiveness-mlg-qa?api-version=2018-03-01-preview',
#     'created_at': '2019-07-02T18:08:16.1707412Z',
#     'modified_at': '2019-07-02T18:08:16.1707412Z'},
#    'entity': {'name': 'campaign-effectiveness-mlg-qa',
#     'deployment_rn': 'campaign-effectiveness-mlg-qa',
#     'type': 'online',
#     'description': 'campaign-effectiveness used for ML Gateway automation tests',
#     'scoring_endpoint': {'url': 'http://4170e9ac-eec3-4d1f-8963-c89be35498db.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '1d0aeabb537f172913cc71a89d701b93',
#      'asset_rn': 'campaign-effectiveness-mlg-qa',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/campaign-effectiveness-mlg-qa?api-version=2018-03-01-preview',
#      'name': 'campaign-effectiveness-mlg-qa',
#      'asset_type': 'model',
#      'created_at': '2019-07-02T18:08:16.1707412Z'}}},
#   {'metadata': {'guid': 'ad886464e73c23e5003f3117bbb831f7',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-azure-mlg-qa?api-version=2018-03-01-preview',
#     'created_at': '2019-07-02T18:02:45.8521824Z',
#     'modified_at': '2019-07-02T18:02:45.8521824Z'},
#    'entity': {'name': 'german-credit-risk-azure-mlg-qa',
#     'deployment_rn': 'german-credit-risk-azure-mlg-qa',
#     'type': 'online',
#     'description': 'german-credit-risk-azure used for ML Gateway automation tests',
#     'scoring_endpoint': {'url': 'http://bd240467-4af5-4f6c-bb8a-6db95924c1ea.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'a01991859bc568e7f2e0630113c3d281',
#      'asset_rn': 'german-credit-risk-azure-mlg-qa',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-azure-mlg-qa?api-version=2018-03-01-preview',
#      'name': 'german-credit-risk-azure-mlg-qa',
#      'asset_type': 'model',
#      'created_at': '2019-07-02T18:02:45.8521824Z'}}},
#   {'metadata': {'guid': '4295edeaf78d9e41fe728b09ae3ca7a9',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-rohit?api-version=2018-03-01-preview',
#     'created_at': '2019-06-28T08:37:36.4883007Z',
#     'modified_at': '2019-06-28T08:37:36.4883007Z'},
#    'entity': {'name': 'german-credit-risk-rohit',
#     'deployment_rn': 'german-credit-risk-rohit',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn from Watson Studio',
#     'scoring_endpoint': {'url': 'http://79acaec9-085f-4761-bf82-abf36445fdbb.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '6087c15ec6885e33807012940e8d427b',
#      'asset_rn': 'german-credit-risk-rohit',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-rohit?api-version=2018-03-01-preview',
#      'name': 'german-credit-risk-rohit',
#      'asset_type': 'model',
#      'created_at': '2019-06-28T08:37:36.4883007Z'}}},
#   {'metadata': {'guid': '456dfbf540e45d604d35ef1c30abdce4',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-azure-hc?api-version=2018-03-01-preview',
#     'created_at': '2019-06-24T23:24:14.7188195Z',
#     'modified_at': '2019-06-24T23:24:14.7188195Z'},
#    'entity': {'name': 'german-credit-risk-azure-hc',
#     'deployment_rn': 'german-credit-risk-azure-hc',
#     'type': 'online',
#     'description': 'High capacity deployment (2 CPU, 4GB) for german-credit-risk-azure',
#     'scoring_endpoint': {'url': 'http://70c8b2a1-edab-422a-b8e6-438ceadca0ad.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'd2131068b59b6e4ae946bd970d4896f2',
#      'asset_rn': 'german-credit-risk-azure-hc',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-azure-hc?api-version=2018-03-01-preview',
#      'name': 'german-credit-risk-azure-hc',
#      'asset_type': 'model',
#      'created_at': '2019-06-24T23:24:14.7188195Z'}}},
#   {'metadata': {'guid': '97be5b6fb06dd081226035da8ac3c61d',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/campaign-effectiveness?api-version=2018-03-01-preview',
#     'created_at': '2019-06-13T08:30:42.2725336Z',
#     'modified_at': '2019-06-13T08:30:43.1774452Z'},
#    'entity': {'name': 'campaign-effectiveness',
#     'deployment_rn': 'campaign-effectiveness',
#     'type': 'online',
#     'description': 'campaign_effectiveness multiclass',
#     'scoring_endpoint': {'url': 'http://13.65.32.22:80/api/v1/service/campaign-effectiveness/score',
#      'credentials': {'secondaryKey': 'QousX6yhtVQkgy0UpWVdMqPBlAb7Hq8n',
#       'token': 'b7sxrmqLiTXTNwTQGxDnTSNKlnwtyAqI'},
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '022d3813f27185621d12dad9fa7355a2',
#      'asset_rn': 'campaign-effectiveness',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/campaign-effectiveness?api-version=2018-03-01-preview',
#      'name': 'campaign-effectiveness',
#      'asset_type': 'model',
#      'created_at': '2019-06-13T08:30:42.2725336Z'}}},
#   {'metadata': {'guid': '5635fbbf87810c04e90752fd0093f6f9',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/ai-ops-aks?api-version=2018-03-01-preview',
#     'created_at': '2019-06-11T11:28:36.9594525Z',
#     'modified_at': '2019-06-11T11:28:43.0447383Z'},
#    'entity': {'name': 'ai-ops-aks',
#     'deployment_rn': 'ai-ops-aks',
#     'type': 'online',
#     'scoring_endpoint': {'url': 'http://13.65.32.22:80/api/v1/service/ai-ops-aks/score',
#      'credentials': {'secondaryKey': '2ZfeVgJbcvNwiWEumTg9jxTiYKYsUMo4',
#       'token': 'BSqsHI9dsyzQxycioBdB93raDi8uQI1P'},
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '3bbe4572551e5ce819be41c94615be50',
#      'asset_rn': 'ai-ops-aks',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/ai-ops-aks?api-version=2018-03-01-preview',
#      'name': 'ai-ops-aks',
#      'asset_type': 'model',
#      'created_at': '2019-06-11T11:28:36.9594525Z'}}},
#   {'metadata': {'guid': 'e52c25f8bce0d5cd9fad97b11f61b2de',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/credit-risk-endpoint-wrapper?api-version=2018-03-01-preview',
#     'created_at': '2019-05-20T11:44:41.4037899Z',
#     'modified_at': '2019-05-20T11:44:41.4037899Z'},
#    'entity': {'name': 'credit-risk-endpoint-wrapper',
#     'deployment_rn': 'credit-risk-endpoint-wrapper',
#     'type': 'online',
#     'description': 'Credit risk scoring endpoint with payload logging',
#     'scoring_endpoint': {'url': 'http://13.91.146.172:80/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '7902428228e2f18cc8a206b01e169c55',
#      'asset_rn': 'credit-risk-endpoint-wrapper',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/credit-risk-endpoint-wrapper?api-version=2018-03-01-preview',
#      'name': 'credit-risk-endpoint-wrapper',
#      'asset_type': 'model',
#      'created_at': '2019-05-20T11:44:41.4037899Z'}}},
#   {'metadata': {'guid': '8f1c58449ed0e9b39b71cab875bf9a42',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/credit-risk-prediction-wrapper?api-version=2018-03-01-preview',
#     'created_at': '2019-05-17T09:59:23.2409737Z',
#     'modified_at': '2019-05-17T09:59:23.2409737Z'},
#    'entity': {'name': 'credit-risk-prediction-wrapper',
#     'deployment_rn': 'credit-risk-prediction-wrapper',
#     'type': 'online',
#     'description': 'Credit risk scoring endpoint with payload logging',
#     'scoring_endpoint': {'url': 'http://13.86.233.123:80/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '696c412096566cb964ccab30604330f5',
#      'asset_rn': 'credit-risk-prediction-wrapper',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/credit-risk-prediction-wrapper?api-version=2018-03-01-preview',
#      'name': 'credit-risk-prediction-wrapper',
#      'asset_type': 'model',
#      'created_at': '2019-05-17T09:59:23.2409737Z'}}},
#   {'metadata': {'guid': '36fc29a3afa485c294991864bb2e775a',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/credit-risk-prediction?api-version=2018-03-01-preview',
#     'created_at': '2019-05-16T08:36:40.1143742Z',
#     'modified_at': '2019-05-16T08:36:40.1143742Z'},
#    'entity': {'name': 'credit-risk-prediction',
#     'deployment_rn': 'credit-risk-prediction',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn on Azure Service',
#     'scoring_endpoint': {'url': 'http://20.189.138.213:80/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '27fbe9111d24fb44fa9c64aa42fdd1f6',
#      'asset_rn': 'credit-risk-prediction',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/credit-risk-prediction?api-version=2018-03-01-preview',
#      'name': 'credit-risk-prediction',
#      'asset_type': 'model',
#      'created_at': '2019-05-16T08:36:40.1143742Z'}}},
#   {'metadata': {'guid': '3b020e1010e829c996c3f0edddb5d2e4',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-azure?api-version=2018-03-01-preview',
#     'created_at': '2019-04-26T10:49:30.181827Z',
#     'modified_at': '2019-04-26T10:49:30.181827Z'},
#    'entity': {'name': 'german-credit-risk-azure',
#     'deployment_rn': 'german-credit-risk-azure',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn',
#     'scoring_endpoint': {'url': 'http://13.83.247.161:80/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '8d379dc4b0081ba66f54578cbb10bd07',
#      'asset_rn': 'german-credit-risk-azure',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-azure?api-version=2018-03-01-preview',
#      'name': 'german-credit-risk-azure',
#      'asset_type': 'model',
#      'created_at': '2019-04-26T10:49:30.181827Z'}}},
#   {'metadata': {'guid': '1bb5f6e493b995565ed35f8851a40be0',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-wml?api-version=2018-03-01-preview',
#     'created_at': '2019-04-26T09:22:20.1318785Z',
#     'modified_at': '2019-04-26T09:22:20.1318785Z'},
#    'entity': {'name': 'german-credit-risk-wml',
#     'deployment_rn': 'german-credit-risk-wml',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn',
#     'scoring_endpoint': {'url': 'http://13.83.246.47:80/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'e2e9b93ab09c48426c2a57b24d5059a4',
#      'asset_rn': 'german-credit-risk-wml',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-squad-server/services/german-credit-risk-wml?api-version=2018-03-01-preview',
#      'name': 'german-credit-risk-wml',
#      'asset_type': 'model',
#      'created_at': '2019-04-26T09:22:20.1318785Z'}}},
#   {'metadata': {'guid': '7aee5521a21aa2147f94ab809778f31f',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/hung-aios-ws/services/my-aci-service-2?api-version=2018-03-01-preview',
#     'created_at': '2019-02-08T17:22:53.5745336Z',
#     'modified_at': '2019-02-08T17:22:53.5745336Z'},
#    'entity': {'name': 'my-aci-service-2',
#     'deployment_rn': 'my-aci-service-2',
#     'type': 'online',
#     'description': 'Predict diabetes using regression model',
#     'scoring_endpoint': {'url': 'http://52.180.89.158:80/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'a6198376f1553243a27b9c7e663693b3',
#      'asset_rn': 'my-aci-service-2',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/hung-aios-ws/services/my-aci-service-2?api-version=2018-03-01-preview',
#      'name': 'my-aci-service-2',
#      'asset_type': 'model',
#      'created_at': '2019-02-08T17:22:53.5745336Z'}}},
#   {'metadata': {'guid': 'b69e6f0916f4920c0b407a2b099c33db',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/hung-aios-ws/services/sklearn-mnist-svc?api-version=2018-03-01-preview',
#     'created_at': '2019-02-08T08:04:20.0627687Z',
#     'modified_at': '2019-02-08T08:04:20.0627687Z'},
#    'entity': {'name': 'sklearn-mnist-svc',
#     'deployment_rn': 'sklearn-mnist-svc',
#     'type': 'online',
#     'description': 'Predict MNIST with sklearn',
#     'scoring_endpoint': {'url': 'http://52.180.88.46:80/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '55959fa838ea0b7afcc9d733ad6adeb4',
#      'asset_rn': 'sklearn-mnist-svc',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/hung-aios-ws/services/sklearn-mnist-svc?api-version=2018-03-01-preview',
#      'name': 'sklearn-mnist-svc',
#      'asset_type': 'model',
#      'created_at': '2019-02-08T08:04:20.0627687Z'}}},
#   {'metadata': {'guid': 'dfb94f005bbe8fa8d664e1c8cf42ab97',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-binary-tokyoqa-hc?api-version=2018-03-01-preview',
#     'created_at': '2019-06-24T23:03:53.3270862Z',
#     'modified_at': '2019-06-24T23:03:53.3270862Z'},
#    'entity': {'name': 'nyc-taxi-binary-tokyoqa-hc',
#     'deployment_rn': 'nyc-taxi-binary-tokyoqa-hc',
#     'type': 'online',
#     'description': 'High capacity deployment (2 CPU, 4GB) for nyc-taxi-binary-tokyoqa',
#     'scoring_endpoint': {'url': 'http://28247eab-f73e-44c4-9fa0-f870d7c7e23b.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'fd1c405450a4b466b146991b9253bee9',
#      'asset_rn': 'nyc-taxi-binary-tokyoqa-hc',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-binary-tokyoqa-hc?api-version=2018-03-01-preview',
#      'name': 'nyc-taxi-binary-tokyoqa-hc',
#      'asset_type': 'model',
#      'created_at': '2019-06-24T23:03:53.3270862Z'}}},
#   {'metadata': {'guid': '0a0b7fb2881119ab1f0068b1916713d2',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-multiclass-tokyoqa?api-version=2018-03-01-preview',
#     'created_at': '2019-06-13T04:53:50.0748277Z',
#     'modified_at': '2019-06-13T04:53:50.0748277Z'},
#    'entity': {'name': 'nyc-taxi-multiclass-tokyoqa',
#     'deployment_rn': 'nyc-taxi-multiclass-tokyoqa',
#     'type': 'online',
#     'description': 'Predict NYC-Taxi vendor with sklearn',
#     'scoring_endpoint': {'url': 'http://3bd2ad1b-d4f7-444b-b808-d4ea83d49916.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'a561cea5c7642c9df1d14418fd270690',
#      'asset_rn': 'nyc-taxi-multiclass-tokyoqa',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-multiclass-tokyoqa?api-version=2018-03-01-preview',
#      'name': 'nyc-taxi-multiclass-tokyoqa',
#      'asset_type': 'model',
#      'created_at': '2019-06-13T04:53:50.0748277Z'}}},
#   {'metadata': {'guid': '41717f73211157158054af50e0c617c4',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-regression-tokyoqa?api-version=2018-03-01-preview',
#     'created_at': '2019-06-13T04:24:04.2145521Z',
#     'modified_at': '2019-06-13T04:24:04.2145521Z'},
#    'entity': {'name': 'nyc-taxi-regression-tokyoqa',
#     'deployment_rn': 'nyc-taxi-regression-tokyoqa',
#     'type': 'online',
#     'description': 'Predict NYC-Taxi cost with sklearn',
#     'scoring_endpoint': {'url': 'http://19fc51de-aa20-4946-a139-3fb2b42e7a67.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '317bad17a803c2253c9ecdc0b32183a7',
#      'asset_rn': 'nyc-taxi-regression-tokyoqa',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-regression-tokyoqa?api-version=2018-03-01-preview',
#      'name': 'nyc-taxi-regression-tokyoqa',
#      'asset_type': 'model',
#      'created_at': '2019-06-13T04:24:04.2145521Z'}}},
#   {'metadata': {'guid': '36c0711986e36b9333a37c10253d7a8a',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-binary-tokyoqa?api-version=2018-03-01-preview',
#     'created_at': '2019-06-13T03:46:32.495248Z',
#     'modified_at': '2019-06-13T03:46:32.495248Z'},
#    'entity': {'name': 'nyc-taxi-binary-tokyoqa',
#     'deployment_rn': 'nyc-taxi-binary-tokyoqa',
#     'type': 'online',
#     'description': 'Predict NYC-Taxi expensive high or low with sklearn',
#     'scoring_endpoint': {'url': 'http://008e1ccb-1644-43fc-952c-98e9e9a2f53a.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '5a73d15cee9f3577d4010c1a3a7a1fd8',
#      'asset_rn': 'nyc-taxi-binary-tokyoqa',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-binary-tokyoqa?api-version=2018-03-01-preview',
#      'name': 'nyc-taxi-binary-tokyoqa',
#      'asset_type': 'model',
#      'created_at': '2019-06-13T03:46:32.495248Z'}}},
#   {'metadata': {'guid': 'bd9d6d125f0a9de2781d11b69a779c30',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-binary?api-version=2018-03-01-preview',
#     'created_at': '2019-05-27T09:46:52.1695792Z',
#     'modified_at': '2019-05-27T09:46:52.1695792Z'},
#    'entity': {'name': 'nyc-taxi-binary',
#     'deployment_rn': 'nyc-taxi-binary',
#     'type': 'online',
#     'description': 'Predict NYC-Taxi expensive high or low with sklearn',
#     'scoring_endpoint': {'url': 'http://44ae23b4-c9a2-4d65-ba24-b0920f831946.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'a6b146363c4f52eeec6db3dac4a860db',
#      'asset_rn': 'nyc-taxi-binary',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-binary?api-version=2018-03-01-preview',
#      'name': 'nyc-taxi-binary',
#      'asset_type': 'model',
#      'created_at': '2019-05-27T09:46:52.1695792Z'}}},
#   {'metadata': {'guid': '5c51ae8ce23d66386d392a4c482f472e',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-regression?api-version=2018-03-01-preview',
#     'created_at': '2019-05-27T09:26:38.9139093Z',
#     'modified_at': '2019-05-27T09:26:38.9139093Z'},
#    'entity': {'name': 'nyc-taxi-regression',
#     'deployment_rn': 'nyc-taxi-regression',
#     'type': 'online',
#     'description': 'Predict NYC-Taxi cost with sklearn',
#     'scoring_endpoint': {'url': 'http://d19ec431-0ec7-481a-8e99-05e9ddc2dca1.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '8abb67a6e88f9b5ca2815e272240ec1f',
#      'asset_rn': 'nyc-taxi-regression',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-regression?api-version=2018-03-01-preview',
#      'name': 'nyc-taxi-regression',
#      'asset_type': 'model',
#      'created_at': '2019-05-27T09:26:38.9139093Z'}}},
#   {'metadata': {'guid': 'fc5a3f1cd54ee381dc5d8cc02284f4e7',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-multiclass?api-version=2018-03-01-preview',
#     'created_at': '2019-05-27T04:40:32.3826997Z',
#     'modified_at': '2019-05-27T04:40:32.3826997Z'},
#    'entity': {'name': 'nyc-taxi-multiclass',
#     'deployment_rn': 'nyc-taxi-multiclass',
#     'type': 'online',
#     'description': 'Predict NYC-Taxi vendor with sklearn',
#     'scoring_endpoint': {'url': 'http://00828647-8db5-482a-8bae-8919c3385119.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'bffa76165faf8f6041d1b36ad7d64cf9',
#      'asset_rn': 'nyc-taxi-multiclass',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad/services/nyc-taxi-multiclass?api-version=2018-03-01-preview',
#      'name': 'nyc-taxi-multiclass',
#      'asset_type': 'model',
#      'created_at': '2019-05-27T04:40:32.3826997Z'}}},
#   {'metadata': {'guid': 'f291a9d430fa73f7b92a346754b898ea',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ml-service-for-aiops/services/circle-area-calculator?api-version=2018-03-01-preview',
#     'created_at': '2019-05-06T08:49:18.7488461Z',
#     'modified_at': '2019-05-06T08:49:18.7488461Z'},
#    'entity': {'name': 'circle-area-calculator',
#     'deployment_rn': 'circle-area-calculator',
#     'type': 'online',
#     'scoring_endpoint': {'url': 'http://13.86.239.24:80/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '658cb6fd3c1a08464747bcb0163e1bda',
#      'asset_rn': 'circle-area-calculator',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/ml-service-for-aiops/services/circle-area-calculator?api-version=2018-03-01-preview',
#      'name': 'circle-area-calculator',
#      'asset_type': 'model',
#      'created_at': '2019-05-06T08:49:18.7488461Z'}}},
#   {'metadata': {'guid': '91a58dcc30f1cf7ee72f06ac6f8f3c67',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/wos-ws/services/credit-risk-rsalehin?api-version=2018-03-01-preview',
#     'created_at': '2020-11-03T21:47:30.4776095Z',
#     'modified_at': '2020-11-03T21:47:30.4776095Z'},
#    'entity': {'name': 'credit-risk-rsalehin',
#     'deployment_rn': 'credit-risk-rsalehin',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn from Watson Studio',
#     'scoring_endpoint': {'url': 'http://4931176f-9943-46a2-857f-dd355d52914a.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '9099ad7e60c9698597199983c976c65a',
#      'asset_rn': 'credit-risk-rsalehin',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/wos-ws/services/credit-risk-rsalehin?api-version=2018-03-01-preview',
#      'name': 'credit-risk-rsalehin',
#      'asset_type': 'model',
#      'created_at': '2020-11-03T21:47:30.4776095Z'}}},
#   {'metadata': {'guid': 'b810bfedc1c40f398990627eea7b150c',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/wos-ws/services/credit-risk-rsalehin-wrapper1?api-version=2018-03-01-preview',
#     'created_at': '2020-10-21T05:24:58.1491236Z',
#     'modified_at': '2020-10-21T05:24:58.1491236Z'},
#    'entity': {'name': 'credit-risk-rsalehin-wrapper1',
#     'deployment_rn': 'credit-risk-rsalehin-wrapper1',
#     'type': 'online',
#     'description': 'Credit risk scoring endpoint wrapper with payload logging',
#     'scoring_endpoint': {'url': 'http://a53bbdd6-45e7-4302-9c61-9f5beb196932.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '92eec7430bf9dfd358577952a6f8949a',
#      'asset_rn': 'credit-risk-rsalehin-wrapper1',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/wos-ws/services/credit-risk-rsalehin-wrapper1?api-version=2018-03-01-preview',
#      'name': 'credit-risk-rsalehin-wrapper1',
#      'asset_type': 'model',
#      'created_at': '2020-10-21T05:24:58.1491236Z'}}},
#   {'metadata': {'guid': '2c97fa049727af32bb5ce1c7322c91ff',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad2/services/german-credit-risk-wml?api-version=2018-03-01-preview',
#     'created_at': '2019-05-06T04:10:44.5366001Z',
#     'modified_at': '2019-05-06T05:30:02.927025Z'},
#    'entity': {'name': 'german-credit-risk-wml',
#     'deployment_rn': 'german-credit-risk-wml',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn',
#     'scoring_endpoint': {'url': 'http://13.86.239.141:80/score',
#      'credentials': {'secondaryKey': 'v030WYcRcBe3N8xYehOHtXRCmBKTQoCR',
#       'token': 'llC2EHbMKFVX2Le0R2kCW5e7JLLzmpD4'},
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'e2e9b93ab09c48426c2a57b24d5059a4',
#      'asset_rn': 'german-credit-risk-wml',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ops-dashboard/providers/Microsoft.MachineLearningServices/workspaces/ai-ops-dashboard-squad2/services/german-credit-risk-wml?api-version=2018-03-01-preview',
#      'name': 'german-credit-risk-wml',
#      'asset_type': 'model',
#      'created_at': '2019-05-06T04:10:44.5366001Z'}}},
#   {'metadata': {'guid': 'd3a023bd2b2500c17c757eb9805b5b26',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/openscale-fastpath/providers/Microsoft.MachineLearningServices/workspaces/openscale-fastpath-workspace/services/fp-german-credit-risk-azs-azure?api-version=2018-03-01-preview',
#     'created_at': '2019-06-19T02:13:46.2710827Z',
#     'modified_at': '2019-06-19T02:13:46.2710827Z'},
#    'entity': {'name': 'fp-german-credit-risk-azs-azure',
#     'deployment_rn': 'fp-german-credit-risk-azs-azure',
#     'type': 'online',
#     'description': 'Predict Credit Risk with sklearn',
#     'scoring_endpoint': {'url': 'http://d98cf993-a56c-40bb-8d62-8236d895e30a.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '1fb7638e14a4b6544ea4454475f13d23',
#      'asset_rn': 'fp-german-credit-risk-azs-azure',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/openscale-fastpath/providers/Microsoft.MachineLearningServices/workspaces/openscale-fastpath-workspace/services/fp-german-credit-risk-azs-azure?api-version=2018-03-01-preview',
#      'name': 'fp-german-credit-risk-azs-azure',
#      'asset_type': 'model',
#      'created_at': '2019-06-19T02:13:46.2710827Z'}}},
#   {'metadata': {'guid': '979a42aedbd8fa5f8f19dc72f336c9c3',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/credit-risk-rsalehin?api-version=2018-03-01-preview',
#     'created_at': '2020-10-19T07:08:10.563491Z',
#     'modified_at': '2020-10-19T07:08:10.563491Z'},
#    'entity': {'name': 'credit-risk-rsalehin',
#     'deployment_rn': 'credit-risk-rsalehin',
#     'type': 'online',
#     'scoring_endpoint': {'url': 'http://02ae7611-227d-4f9c-b304-b066558d7c39.westus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '9099ad7e60c9698597199983c976c65a',
#      'asset_rn': 'credit-risk-rsalehin',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/credit-risk-rsalehin?api-version=2018-03-01-preview',
#      'name': 'credit-risk-rsalehin',
#      'asset_type': 'model',
#      'created_at': '2020-10-19T07:08:10.563491Z'}}},
#   {'metadata': {'guid': 'e7ad8b50175ada929b37245540400572',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/insurance-fraud-ib-dep?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T17:51:00.3865262Z',
#     'modified_at': '2020-07-15T17:51:00.3865262Z'},
#    'entity': {'name': 'insurance-fraud-ib-dep',
#     'deployment_rn': 'insurance-fraud-ib-dep',
#     'type': 'online',
#     'description': 'Insurance fraud detection',
#     'scoring_endpoint': {'url': 'http://1b23d902-c15a-45f1-b9f7-1f2de645eb96.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '7277a6f52fda86d5dc6c51190983ab6c',
#      'asset_rn': 'insurance-fraud-ib-dep',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/insurance-fraud-ib-dep?api-version=2018-03-01-preview',
#      'name': 'insurance-fraud-ib-dep',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T17:51:00.3865262Z'}}},
#   {'metadata': {'guid': 'b30435c911902913dc5e716cc363fbe1',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-5-deployment-1?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T10:50:36.6158405Z',
#     'modified_at': '2020-07-15T10:50:36.6158405Z'},
#    'entity': {'name': 'adult-census-ib-5-deployment-1',
#     'deployment_rn': 'adult-census-ib-5-deployment-1',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://3dec7e72-22e1-4df0-87a1-dd9ac3ab5ecb.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '74aedb35bf5445663513f44a7a8c68bf',
#      'asset_rn': 'adult-census-ib-5-deployment-1',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-5-deployment-1?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-5-deployment-1',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T10:50:36.6158405Z'}}},
#   {'metadata': {'guid': 'b7b3aaa26be1eba581544cc9149a86d7',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-5-deployment?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T09:55:40.07173Z',
#     'modified_at': '2020-07-15T09:55:40.07173Z'},
#    'entity': {'name': 'adult-census-ib-5-deployment',
#     'deployment_rn': 'adult-census-ib-5-deployment',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://2c9a67ff-637e-418a-a309-efa4d05334b1.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '0708ad4eef167fda70cd22b257c52234',
#      'asset_rn': 'adult-census-ib-5-deployment',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-5-deployment?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-5-deployment',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T09:55:40.07173Z'}}},
#   {'metadata': {'guid': '94272d944686683b7643b17256f877a7',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-4-deployment?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T08:41:27.8008626Z',
#     'modified_at': '2020-07-15T08:41:27.8008626Z'},
#    'entity': {'name': 'adult-census-ib-4-deployment',
#     'deployment_rn': 'adult-census-ib-4-deployment',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://83f8b543-f65c-481f-af92-46f41291a50c.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '7b4243339f8c3f2d675e23a004b12fae',
#      'asset_rn': 'adult-census-ib-4-deployment',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-4-deployment?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-4-deployment',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T08:41:27.8008626Z'}}},
#   {'metadata': {'guid': '1d15247ca22add806961a8edaf0fefba',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-3-deployment?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T06:35:41.2056611Z',
#     'modified_at': '2020-07-15T06:35:41.2056611Z'},
#    'entity': {'name': 'adult-census-ib-3-deployment',
#     'deployment_rn': 'adult-census-ib-3-deployment',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://d87cc98a-6ac4-41f0-b765-6ff1de201312.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '8db3da9f431139c19d6e111d61cd550c',
#      'asset_rn': 'adult-census-ib-3-deployment',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-3-deployment?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-3-deployment',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T06:35:41.2056611Z'}}},
#   {'metadata': {'guid': 'b3be03e308b1974dd2749dbdbf055203',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-2-deployment?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T06:13:40.9655365Z',
#     'modified_at': '2020-07-15T06:13:40.9655365Z'},
#    'entity': {'name': 'adult-census-ib-2-deployment',
#     'deployment_rn': 'adult-census-ib-2-deployment',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://687dff68-ef05-4134-809b-913febfc4d84.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '2d4a5e861b5aad2d4b51a270a571b34f',
#      'asset_rn': 'adult-census-ib-2-deployment',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-2-deployment?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-2-deployment',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T06:13:40.9655365Z'}}},
#   {'metadata': {'guid': '29ef8fc875d57b868dbeceab8367fcb6',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/dep-adult-census-ib-2?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T05:26:45.3384503Z',
#     'modified_at': '2020-07-15T05:26:45.3384503Z'},
#    'entity': {'name': 'dep-adult-census-ib-2',
#     'deployment_rn': 'dep-adult-census-ib-2',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://30995d53-187f-4ab2-bc68-390f33bddc1f.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'ce4b01e41477b2a117c7d951c47b2907',
#      'asset_rn': 'dep-adult-census-ib-2',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/dep-adult-census-ib-2?api-version=2018-03-01-preview',
#      'name': 'dep-adult-census-ib-2',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T05:26:45.3384503Z'}}},
#   {'metadata': {'guid': '345096f43beee63b3f2c152e43a1d26b',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/dep-adult-census-ib?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T04:38:26.1464006Z',
#     'modified_at': '2020-07-15T04:38:26.1464006Z'},
#    'entity': {'name': 'dep-adult-census-ib',
#     'deployment_rn': 'dep-adult-census-ib',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://d56e24c1-d138-4873-87a6-54230ccf0a1d.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'd38140d1fd7d0b2e1d6eac014b6e9934',
#      'asset_rn': 'dep-adult-census-ib',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/dep-adult-census-ib?api-version=2018-03-01-preview',
#      'name': 'dep-adult-census-ib',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T04:38:26.1464006Z'}}},
#   {'metadata': {'guid': 'a2973fc61d902514181063706c4174c6',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/dep-adult-census-ib-1?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T03:32:53.0482123Z',
#     'modified_at': '2020-07-15T03:32:53.0482123Z'},
#    'entity': {'name': 'dep-adult-census-ib-1',
#     'deployment_rn': 'dep-adult-census-ib-1',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://0f453ab4-6a1b-48d7-b8b0-4e3d088d860f.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'f80dccb3ca45bd1caef2e93963ab7324',
#      'asset_rn': 'dep-adult-census-ib-1',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/dep-adult-census-ib-1?api-version=2018-03-01-preview',
#      'name': 'dep-adult-census-ib-1',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T03:32:53.0482123Z'}}},
#   {'metadata': {'guid': '07f55d8abca244947ed92cf19cd883e6',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-1-dep?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T03:03:55.3293265Z',
#     'modified_at': '2020-07-15T03:03:55.3293265Z'},
#    'entity': {'name': 'adult-census-ib-1-dep',
#     'deployment_rn': 'adult-census-ib-1-dep',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://7eae9a2c-cebc-41bf-b477-05ed390d3dfd.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '3b60cf97bdd44db710cb845677dbfead',
#      'asset_rn': 'adult-census-ib-1-dep',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-1-dep?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-1-dep',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T03:03:55.3293265Z'}}},
#   {'metadata': {'guid': '1236f920e7d0d21c535af86df910b241',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-dep?api-version=2018-03-01-preview',
#     'created_at': '2020-07-15T02:31:39.7693493Z',
#     'modified_at': '2020-07-15T02:31:39.7693493Z'},
#    'entity': {'name': 'adult-census-ib-dep',
#     'deployment_rn': 'adult-census-ib-dep',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://63c9b8fa-456b-4ffb-8f87-c15d67deec17.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '0a8fd3e8f198b424d672635ccc6eb251',
#      'asset_rn': 'adult-census-ib-dep',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-dep?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-dep',
#      'asset_type': 'model',
#      'created_at': '2020-07-15T02:31:39.7693493Z'}}},
#   {'metadata': {'guid': '7a4ae064613062aacd8652794d2edabb',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-b2ba?api-version=2018-03-01-preview',
#     'created_at': '2020-07-14T15:10:21.3143045Z',
#     'modified_at': '2020-07-14T15:10:21.3143045Z'},
#    'entity': {'name': 'adult-census-ib-svc-b2ba',
#     'deployment_rn': 'adult-census-ib-svc-b2ba',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://e6305146-4a8b-4b63-a779-49c50272f76e.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '346df4c372b56cd99f9350a4d56834a9',
#      'asset_rn': 'adult-census-ib-svc-b2ba',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-b2ba?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-svc-b2ba',
#      'asset_type': 'model',
#      'created_at': '2020-07-14T15:10:21.3143045Z'}}},
#   {'metadata': {'guid': '89868e0c124958ae517de70120bede3a',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-e1b0?api-version=2018-03-01-preview',
#     'created_at': '2020-07-14T14:42:38.0964978Z',
#     'modified_at': '2020-07-14T14:42:38.0964978Z'},
#    'entity': {'name': 'adult-census-ib-svc-e1b0',
#     'deployment_rn': 'adult-census-ib-svc-e1b0',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://b85a2c1d-f97d-486d-8fd5-217a5e2698d9.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'dc7a798ca93c37e1b12515226d8d8370',
#      'asset_rn': 'adult-census-ib-svc-e1b0',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-e1b0?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-svc-e1b0',
#      'asset_type': 'model',
#      'created_at': '2020-07-14T14:42:38.0964978Z'}}},
#   {'metadata': {'guid': '456ba0640f38ed1644a254a3c1280134',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-d1d5?api-version=2018-03-01-preview',
#     'created_at': '2020-07-14T14:14:39.32638Z',
#     'modified_at': '2020-07-14T14:14:39.32638Z'},
#    'entity': {'name': 'adult-census-ib-svc-d1d5',
#     'deployment_rn': 'adult-census-ib-svc-d1d5',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://2f558f02-ff0a-46b6-ac2c-3e56df096a65.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '98db2838fc0c4301e21d8481e5f0212b',
#      'asset_rn': 'adult-census-ib-svc-d1d5',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-d1d5?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-svc-d1d5',
#      'asset_type': 'model',
#      'created_at': '2020-07-14T14:14:39.32638Z'}}},
#   {'metadata': {'guid': '735ed18e956e34ed35ea03fdc8c8f415',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-a603?api-version=2018-03-01-preview',
#     'created_at': '2020-07-14T13:31:45.1060774Z',
#     'modified_at': '2020-07-14T13:31:45.1060774Z'},
#    'entity': {'name': 'adult-census-ib-svc-a603',
#     'deployment_rn': 'adult-census-ib-svc-a603',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://87d32ed7-0a65-43cb-9253-55ee2c98b9a9.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': 'fc99ef790ed84bf1e559209aec2b4791',
#      'asset_rn': 'adult-census-ib-svc-a603',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-a603?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-svc-a603',
#      'asset_type': 'model',
#      'created_at': '2020-07-14T13:31:45.1060774Z'}}},
#   {'metadata': {'guid': 'c8c8b4099ffdf47f390647986792740c',
#     'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-cd88?api-version=2018-03-01-preview',
#     'created_at': '2020-07-14T13:04:32.9365028Z',
#     'modified_at': '2020-07-14T13:04:32.9365028Z'},
#    'entity': {'name': 'adult-census-ib-svc-cd88',
#     'deployment_rn': 'adult-census-ib-svc-cd88',
#     'type': 'online',
#     'description': 'Adult census income classifier',
#     'scoring_endpoint': {'url': 'http://355176e9-8c4f-4d41-976c-b5076b93e7c2.southcentralus.azurecontainer.io/score',
#      'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#     'asset': {'asset_id': '775008ec4d8e96f689f5b7a7ef5ecdca',
#      'asset_rn': 'adult-census-ib-svc-cd88',
#      'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-cd88?api-version=2018-03-01-preview',
#      'name': 'adult-census-ib-svc-cd88',
#      'asset_type': 'model',
#      'created_at': '2020-07-14T13:04:32.9365028Z'}}}],
#  'count': 47}

# %%
deployment_id='91a58dcc30f1cf7ee72f06ac6f8f3c67' # get the GUID for related deployment
for model_asset_details in asset_deployment_details['resources']:
    if model_asset_details['metadata']['guid']==deployment_id:
        break
model_asset_details
# Out:
# {'metadata': {'guid': '91a58dcc30f1cf7ee72f06ac6f8f3c67',
#   'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/wos-ws/services/credit-risk-rsalehin?api-version=2018-03-01-preview',
#   'created_at': '2020-11-03T21:47:30.4776095Z',
#   'modified_at': '2020-11-03T21:47:30.4776095Z'},
#  'entity': {'name': 'credit-risk-rsalehin',
#   'deployment_rn': 'credit-risk-rsalehin',
#   'type': 'online',
#   'description': 'Predict Credit Risk with sklearn from Watson Studio',
#   'scoring_endpoint': {'url': 'http://4931176f-9943-46a2-857f-dd355d52914a.southcentralus.azurecontainer.io/score',
#    'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#   'asset': {'asset_id': '9099ad7e60c9698597199983c976c65a',
#    'asset_rn': 'credit-risk-rsalehin',
#    'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/ai-ops-squad/providers/Microsoft.MachineLearningServices/workspaces/wos-ws/services/credit-risk-rsalehin?api-version=2018-03-01-preview',
#    'name': 'credit-risk-rsalehin',
#    'asset_type': 'model',
#    'created_at': '2020-11-03T21:47:30.4776095Z'}}}

# %%
model_id='9099ad7e60c9698597199983c976c65a'
for asset_details in asset_deployment_details['resources']:
    if asset_details['metadata']['guid']==model_id:
        break
asset_details
# Out:
# {'metadata': {'guid': 'c8c8b4099ffdf47f390647986792740c',
#   'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-cd88?api-version=2018-03-01-preview',
#   'created_at': '2020-07-14T13:04:32.9365028Z',
#   'modified_at': '2020-07-14T13:04:32.9365028Z'},
#  'entity': {'name': 'adult-census-ib-svc-cd88',
#   'deployment_rn': 'adult-census-ib-svc-cd88',
#   'type': 'online',
#   'description': 'Adult census income classifier',
#   'scoring_endpoint': {'url': 'http://355176e9-8c4f-4d41-976c-b5076b93e7c2.southcentralus.azurecontainer.io/score',
#    'request_headers': {'Content-Type': 'application/json; charset=UTF-8'}},
#   'asset': {'asset_id': '775008ec4d8e96f689f5b7a7ef5ecdca',
#    'asset_rn': 'adult-census-ib-svc-cd88',
#    'url': 'https://southcentralus.modelmanagement.azureml.net/api/subscriptions/744bca72-2299-451c-b682-ed6fb75fb671/resourceGroups/bias_explainability/providers/Microsoft.MachineLearningServices/workspaces/bias_dev/services/adult-census-ib-svc-cd88?api-version=2018-03-01-preview',
#    'name': 'adult-census-ib-svc-cd88',
#    'asset_type': 'model',
#    'created_at': '2020-07-14T13:04:32.9365028Z'}}}

# %%
wos_client.subscriptions.show()
# Out:
# <HTML>
#         <body>
#             <h3>Subscriptions</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>asset_id</th><th style='border: 1px solid #dddddd'>asset_name</th><th style='border: 1px solid #dddddd'>data_mart_id</th><th style='border: 1px solid #dddddd'>deployment_id</th><th style='border: 1px solid #dddddd'>deployment_name</th><th style='border: 1px solid #dddddd'>service_provider_id</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>ac19f6fd-ae79-46a9-9fd2-7bede4b8c313</td><td style='border: 1px solid #dddddd'>house_price_xgbregression</td><td style='border: 1px solid #dddddd'>5a0b9076-fcf6-49e8-a824-9e3a6b4c2a56</td><td style='border: 1px solid #dddddd'>a9d12e3e-d251-43ab-bda6-500160babea7</td><td style='border: 1px solid #dddddd'>house_price_xgbregression_deployment</td><td style='border: 1px solid #dddddd'>6763d6c4-a40e-4b1b-a58f-7c18b56b37a5</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2020-11-03 01:06:22.009000+00:00</td><td style='border: 1px solid #dddddd'>a337d621-5de4-4c63-8d83-fd02d6db14af</td></tr><tr><td style='border: 1px solid #dddddd'>d551ef44-2d40-4e5c-b5ad-4abf1b67a0ec</td><td style='border: 1px solid #dddddd'>gosales_multiclass</td><td style='border: 1px solid #dddddd'>5a0b9076-fcf6-49e8-a824-9e3a6b4c2a56</td><td style='border: 1px solid #dddddd'>3ee743dc-20e9-4ff7-b46f-10939fff9ee0</td><td style='border: 1px solid #dddddd'>house_price_xgbregression_deployment</td><td style='border: 1px solid #dddddd'>33814b15-fd8a-47ff-9302-a78b2062d1ac</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2020-11-02 22:56:49.711000+00:00</td><td style='border: 1px solid #dddddd'>887596d0-87f9-4eaf-9ee9-30b87d5d03ba</td></tr><tr><td style='border: 1px solid #dddddd'>9099ad7e60c9698597199983c976c65a</td><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>5a0b9076-fcf6-49e8-a824-9e3a6b4c2a56</td><td style='border: 1px solid #dddddd'>91a58dcc30f1cf7ee72f06ac6f8f3c67</td><td style='border: 1px solid #dddddd'>credit-risk-rsalehin</td><td style='border: 1px solid #dddddd'>5d4cede3-0d09-42da-903b-7283d553c882</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2020-10-21 20:54:17.435000+00:00</td><td style='border: 1px solid #dddddd'>72a076d6-fb87-4f52-96b8-891cd405c6e1</td></tr>
#             </table>
#         </body>
#         </HTML>

# %%
feature_columns = ['CheckingStatus', 'LoanDuration', 'CreditHistory', 'LoanPurpose', 'LoanAmount', 'ExistingSavings', 'EmploymentDuration', 'InstallmentPercent', 'Sex', 'OthersOnLoan', 'CurrentResidenceDuration', 'OwnsProperty', 'Age', 'InstallmentPlans', 'Housing', 'ExistingCreditsCount', 'Job', 'Dependents', 'Telephone', 'ForeignWorker']
categorical_columns = ['CheckingStatus', 'CreditHistory', 'LoanPurpose', 'ExistingSavings', 'EmploymentDuration', 'Sex', 'OthersOnLoan', 'OwnsProperty', 'InstallmentPlans', 'Housing', 'Job', 'Telephone', 'ForeignWorker']

# %%
azure_asset = Asset(
            asset_id=model_asset_details["entity"]["asset"]["asset_id"],
            name=model_asset_details["entity"]["asset"]["name"],
            url=model_asset_details["entity"]["asset"]["url"],
            asset_type=model_asset_details['entity']['asset']['asset_type'] if 'asset_type' in model_asset_details['entity']['asset'] else 'model',
            input_data_type=InputDataType.STRUCTURED,
            problem_type=ProblemType.BINARY_CLASSIFICATION
        )

# %%
from ibm_watson_openscale.base_classes.watson_open_scale_v2 import ScoringEndpointRequest
deployment_scoring_endpoint = model_asset_details['entity']['scoring_endpoint']
scoring_endpoint = ScoringEndpointRequest(url = model_asset_details['entity']['scoring_endpoint']['url'],request_headers = model_asset_details['entity']['scoring_endpoint']['request_headers'],
                                                 credentials = None)  

deployment = AssetDeploymentRequest(
    deployment_id=model_asset_details['metadata']['guid'],
    url=model_asset_details['metadata']['url'],
    name=model_asset_details['entity']['name'],
    description=model_asset_details['entity']['description'],
    deployment_type=model_asset_details['entity']['type'],
    scoring_endpoint = scoring_endpoint
)

# %%
training_data_reference = TrainingDataReference(type='cos',
                                              location=COSTrainingDataReferenceLocation(bucket = BUCKET_NAME,
                                                                                        file_name = training_data_file_name),
                                              connection=COSTrainingDataReferenceConnection(
                                                                        resource_instance_id= COS_RESOURCE_CRN,
                                                                        url= COS_ENDPOINT,
                                                                        api_key= COS_API_KEY_ID,
                                                                        iam_url=IAM_URL)
                                               )

# %%
asset_properties = AssetPropertiesRequest(
        label_column="Risk",
        prediction_field='Scored Labels',
        probability_fields=['Scored Probabilities'],
        training_data_reference=training_data_reference,
        training_data_schema=None,
        input_data_schema=None,
        output_data_schema=None,
    )

# %%
subscription_details = wos_client.subscriptions.add(
        data_mart_id=data_mart_id,
        service_provider_id=service_provider_id,
        asset=azure_asset,
        deployment=deployment,
        asset_properties=asset_properties,
        background_mode=False
).result
subscription_id = subscription_details.metadata.id
subscription_id
# Out:
# =============================================================================
#
#  Waiting for end of adding subscription d21cb288-716b-43f1-9b89-766a070f3e1e
#
# =============================================================================
#
#
#
# active
#
# -------------------------------------------
#  Successfully finished adding subscription
# -------------------------------------------
# 'd21cb288-716b-43f1-9b89-766a070f3e1e'

# %%
import time

time.sleep(5)
payload_data_set_id = None
payload_data_set_id = wos_client.data_sets.list(type=DataSetTypes.PAYLOAD_LOGGING, 
                                                target_target_id=subscription_id, 
                                                target_target_type=TargetTypes.SUBSCRIPTION).result.data_sets[0].metadata.id
if payload_data_set_id is None:
    print("Payload data set not found. Please check subscription status.")
else:
    print("Payload data set id: ", payload_data_set_id)
# Out:
# Payload data set id:  299c2030-ad65-492f-a19b-2bb7ce3522f8

# %% [markdown]
# ## Implement the wrapper
#
# Once you've tested the deployment, let's implement the wrapper that will:
# * call the original scoring endpoint (credit risk)
# * conver the scoring request and response to the OpenScale format
# * store converted request and response as payload records in OpenScale data mart
#
#
# To build the correct environment for ACI, provide the following:
# * A scoring script to show how to use the scoring wrapper
# * An environment file to show what packages need to be installed
# * A configuration file to build the ACI
#
#
# ### Create scoring script
#
# Create the scoring script, called score.py, used by the web service call to show how to use the deployment.
#
# You must include two required functions into the scoring script:
# * The `init()` function, which typically loads the required credentials into a global object. This function is run only once when the Docker container is started.
#
# * The `run(input_data)` function uses the original scoring endpoint to predict a value based on the input data. Next it makes format conversions and finally stored payload records in OpenScale data mart.

# %% [markdown]
# ### ACTION: You need to update below score.py content by changing the following lines:
#
# - `scoring_endpoint` - PUT your scoring endpoint there
# - `scoring_headers` - PUT your scoring header there
# - `openscale_credentials` - PUT your OpenScale credentials there
# - `openscale_subscription_uid` - PUT uid of created subscription there
# - you may also need to modify conversion methods to fit your custom format of payloads

# %% [markdown]
# ### Scoring endpoint wrapper code

# %%
credit_risk_scoring_endpoint
# Out:
# 'http://4931176f-9943-46a2-857f-dd355d52914a.southcentralus.azurecontainer.io/score'

# %%
subscription_id
# Out:
# 'd21cb288-716b-43f1-9b89-766a070f3e1e'

# %%
# %%writefile score.py
import json
import numpy as np
import os
import time
import requests
import uuid

from ibm_cloud_sdk_core.authenticators import IAMAuthenticator,BearerTokenAuthenticator
from ibm_watson_openscale import APIClient
from ibm_watson_openscale.supporting_classes.payload_record import PayloadRecord
from ibm_watson_openscale.supporting_classes.enums import *


def convert_user_input_2_openscale(input_data):
    users_records = input_data['input']
    openscale_fields = list(users_records[0])
    openscale_values = [[rec[k] for k in openscale_fields] for rec in users_records] 

    return {'fields':openscale_fields, 'values':openscale_values}


def convert_user_output_2_openscale(output_data):
    output_data = json.loads(output_data)
    users_records = output_data['output']
    openscale_fields = list(users_records[0])
    openscale_values = [[rec[k] for k in openscale_fields] for rec in users_records] 

    return {'fields':openscale_fields, 'values':openscale_values}


def init():
    global openscale_client
    global cloud_api_key
    global openscale_subscription_uid
    global openscale_subscription
    global scoring_endpoint
    global scoring_headers
    global payload_data_set_id
    
    
    scoring_endpoint = 'http://4931176f-9943-46a2-857f-dd355d52914a.southcentralus.azurecontainer.io/score'
    scoring_headers = {'Content-Type': 'application/json'}
    cloud_api_key = 'wqMwzhQ7GRNBlH5iS3OVGlf3Ym4OD4EPJjaA6Eg8mQgg'
    openscale_subscription_uid = "d21cb288-716b-43f1-9b89-766a070f3e1e"
    authenticator = IAMAuthenticator(apikey=cloud_api_key)
    openscale_client = APIClient(authenticator=authenticator)
    payload_data_set_id = openscale_client.data_sets.list(type=DataSetTypes.PAYLOAD_LOGGING, 
                                                target_target_id=openscale_subscription_uid, 
                                                target_target_type=TargetTypes.SUBSCRIPTION).result.data_sets[0].metadata.id
    #openscale_subscription = openscale_client.data_mart.subscriptions.get(openscale_subscription_uid)
    
    
def run(input_data):
   
    # ------ CALL SCORING ENDPOINT --------------
    if type(input_data) is str:
        input_data = json.loads(input_data)

    start_time = time.time()        
    response = requests.post(scoring_endpoint, json=input_data, headers=scoring_headers)
    response_time = int((time.time() - start_time)*1000)
    output_data = response.json()

    # ------ PAYLOAD COVERSION TO OPENSCALE FORMAT and LOGGING --------------
    try:
        
        openscale_input = convert_user_input_2_openscale(input_data)
        openscale_output = convert_user_output_2_openscale(output_data)  
        
        records_list=[PayloadRecord(
               request=openscale_input,
               response=openscale_output,
               response_time=response_time
           )]
        openscale_client.data_sets.store_records(data_set_id=payload_data_set_id, request_body=records_list)
        
    
    except Exception as e:
        error = str(e)
        print(error)
    finally:
        return output_data
# Out:
# Writing score.py

# %% [markdown]
# ## Test wrapper locally

# %%
scoring_data
# Out:
# {'input': [{'CheckingStatus': '0_to_200',
#    'LoanDuration': 15,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 250,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 2,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 21,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 4,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'education',
#    'LoanAmount': 250,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 2,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'real_estate',
#    'Age': 28,
#    'InstallmentPlans': 'stores',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'unskilled',
#    'Dependents': 2,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 8,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 5992,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 4,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'unknown',
#    'Age': 28,
#    'InstallmentPlans': 'none',
#    'Housing': 'free',
#    'ExistingCreditsCount': 2,
#    'Job': 'management_self-employed',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 15,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 3440,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 4,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 37,
#    'InstallmentPlans': 'stores',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'unskilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 13,
#    'CreditHistory': 'all_credits_paid_back',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 1241,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 3,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 1,
#    'OwnsProperty': 'real_estate',
#    'Age': 29,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 16,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'appliances',
#    'LoanAmount': 1443,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 1,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 1,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 39,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 13,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'vacation',
#    'LoanAmount': 7200,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 3,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'car_other',
#    'Age': 35,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'management_self-employed',
#    'Dependents': 2,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 15,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 4097,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 3,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'car_other',
#    'Age': 43,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 33,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'repairs',
#    'LoanAmount': 5595,
#    'ExistingSavings': 'unknown',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 5,
#    'Sex': 'male',
#    'OthersOnLoan': 'co-applicant',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'unknown',
#    'Age': 54,
#    'InstallmentPlans': 'none',
#    'Housing': 'free',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 2,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 38,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'furniture',
#    'LoanAmount': 7176,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 5,
#    'Sex': 'male',
#    'OthersOnLoan': 'co-applicant',
#    'CurrentResidenceDuration': 5,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 50,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 29,
#    'CreditHistory': 'all_credits_paid_back',
#    'LoanPurpose': 'repairs',
#    'LoanAmount': 3972,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 4,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'car_other',
#    'Age': 39,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 2,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 16,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 1008,
#    'ExistingSavings': 'greater_1000',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 4,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 34,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 11,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 1928,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': 'unemployed',
#    'InstallmentPercent': 1,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'car_other',
#    'Age': 23,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 21,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 1467,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 1,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 25,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 17,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'furniture',
#    'LoanAmount': 626,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 2,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'car_other',
#    'Age': 28,
#    'InstallmentPlans': 'none',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 45,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 6773,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 5,
#    'Sex': 'male',
#    'OthersOnLoan': 'co-applicant',
#    'CurrentResidenceDuration': 5,
#    'OwnsProperty': 'car_other',
#    'Age': 54,
#    'InstallmentPlans': 'none',
#    'Housing': 'free',
#    'ExistingCreditsCount': 3,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 29,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 1751,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 3,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 32,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 22,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'furniture',
#    'LoanAmount': 2150,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 4,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 55,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'management_self-employed',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 39,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'repairs',
#    'LoanAmount': 10913,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 4,
#    'Sex': 'male',
#    'OthersOnLoan': 'co-applicant',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'unknown',
#    'Age': 45,
#    'InstallmentPlans': 'none',
#    'Housing': 'free',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 16,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 1891,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': 'unemployed',
#    'InstallmentPercent': 2,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'real_estate',
#    'Age': 19,
#    'InstallmentPlans': 'none',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 10,
#    'CreditHistory': 'all_credits_paid_back',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 250,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 1,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 27,
#    'InstallmentPlans': 'stores',
#    'Housing': 'own',
#    'ExistingCreditsCount': 3,
#    'Job': 'unskilled',
#    'Dependents': 2,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 29,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'appliances',
#    'LoanAmount': 5123,
#    'ExistingSavings': 'greater_1000',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 5,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 46,
#    'InstallmentPlans': 'stores',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 27,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'appliances',
#    'LoanAmount': 4204,
#    'ExistingSavings': 'unknown',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 3,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'car_other',
#    'Age': 52,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 37,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 5119,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 4,
#    'Sex': 'male',
#    'OthersOnLoan': 'co-applicant',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'car_other',
#    'Age': 49,
#    'InstallmentPlans': 'none',
#    'Housing': 'free',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'no'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 26,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'appliances',
#    'LoanAmount': 3127,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 3,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'unknown',
#    'Age': 38,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 39,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 7691,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 5,
#    'Sex': 'male',
#    'OthersOnLoan': 'co-applicant',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'car_other',
#    'Age': 41,
#    'InstallmentPlans': 'stores',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'unskilled',
#    'Dependents': 2,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 41,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'repairs',
#    'LoanAmount': 3754,
#    'ExistingSavings': 'unknown',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 5,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 5,
#    'OwnsProperty': 'car_other',
#    'Age': 55,
#    'InstallmentPlans': 'none',
#    'Housing': 'free',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 2,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 16,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 250,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 3,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 1,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 19,
#    'InstallmentPlans': 'bank',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'unemployed',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 4,
#    'CreditHistory': 'all_credits_paid_back',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 250,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 2,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 1,
#    'OwnsProperty': 'real_estate',
#    'Age': 19,
#    'InstallmentPlans': 'none',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 15,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'furniture',
#    'LoanAmount': 4609,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 4,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'car_other',
#    'Age': 54,
#    'InstallmentPlans': 'stores',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'unskilled',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 14,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 2849,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 4,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'unknown',
#    'Age': 45,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 8,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 3925,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 2,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'real_estate',
#    'Age': 31,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'management_self-employed',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 20,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 4183,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 2,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'car_other',
#    'Age': 21,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 2,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 20,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 4292,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 3,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'car_other',
#    'Age': 33,
#    'InstallmentPlans': 'bank',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'unemployed',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'greater_200',
#    'LoanDuration': 25,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 2792,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 3,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'car_other',
#    'Age': 40,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 7,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'repairs',
#    'LoanAmount': 3801,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 3,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 4,
#    'OwnsProperty': 'unknown',
#    'Age': 28,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 35,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'vacation',
#    'LoanAmount': 4311,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 5,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 27,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 36,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'business',
#    'LoanAmount': 3631,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 4,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 48,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'greater_200',
#    'LoanDuration': 7,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 7831,
#    'ExistingSavings': '500_to_1000',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 3,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'unknown',
#    'Age': 39,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'skilled',
#    'Dependents': 2,
#    'Telephone': 'yes',
#    'ForeignWorker': 'no'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 17,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 5772,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 2,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'car_other',
#    'Age': 31,
#    'InstallmentPlans': 'stores',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 19,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 2804,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 3,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'real_estate',
#    'Age': 31,
#    'InstallmentPlans': 'stores',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 4,
#    'CreditHistory': 'all_credits_paid_back',
#    'LoanPurpose': 'furniture',
#    'LoanAmount': 4231,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 2,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 1,
#    'OwnsProperty': 'real_estate',
#    'Age': 19,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 37,
#    'CreditHistory': 'outstanding_credit',
#    'LoanPurpose': 'other',
#    'LoanAmount': 7916,
#    'ExistingSavings': 'unknown',
#    'EmploymentDuration': 'greater_7',
#    'InstallmentPercent': 5,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 5,
#    'OwnsProperty': 'unknown',
#    'Age': 53,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 3,
#    'Job': 'skilled',
#    'Dependents': 2,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 31,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'furniture',
#    'LoanAmount': 5789,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 3,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 43,
#    'InstallmentPlans': 'stores',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'unskilled',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'no_checking',
#    'LoanDuration': 28,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 4387,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 4,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'car_other',
#    'Age': 46,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 2,
#    'Job': 'management_self-employed',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 11,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'car_used',
#    'LoanAmount': 3098,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 3,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 3,
#    'OwnsProperty': 'savings_insurance',
#    'Age': 32,
#    'InstallmentPlans': 'none',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'yes',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 28,
#    'CreditHistory': 'credits_paid_to_date',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 250,
#    'ExistingSavings': '100_to_500',
#    'EmploymentDuration': '4_to_7',
#    'InstallmentPercent': 2,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'real_estate',
#    'Age': 19,
#    'InstallmentPlans': 'stores',
#    'Housing': 'own',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 4,
#    'CreditHistory': 'all_credits_paid_back',
#    'LoanPurpose': 'car_new',
#    'LoanAmount': 250,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': '1_to_4',
#    'InstallmentPercent': 1,
#    'Sex': 'male',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'real_estate',
#    'Age': 19,
#    'InstallmentPlans': 'stores',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': 'less_0',
#    'LoanDuration': 9,
#    'CreditHistory': 'all_credits_paid_back',
#    'LoanPurpose': 'vacation',
#    'LoanAmount': 772,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 2,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'real_estate',
#    'Age': 25,
#    'InstallmentPlans': 'none',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'skilled',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'},
#   {'CheckingStatus': '0_to_200',
#    'LoanDuration': 16,
#    'CreditHistory': 'prior_payments_delayed',
#    'LoanPurpose': 'radio_tv',
#    'LoanAmount': 2321,
#    'ExistingSavings': 'less_100',
#    'EmploymentDuration': 'less_1',
#    'InstallmentPercent': 2,
#    'Sex': 'female',
#    'OthersOnLoan': 'none',
#    'CurrentResidenceDuration': 2,
#    'OwnsProperty': 'car_other',
#    'Age': 39,
#    'InstallmentPlans': 'bank',
#    'Housing': 'rent',
#    'ExistingCreditsCount': 1,
#    'Job': 'unemployed',
#    'Dependents': 1,
#    'Telephone': 'none',
#    'ForeignWorker': 'yes'}]}

# %%
import score
score.init()

# %%
scores = score.run(scoring_data)
# Out:
# Total payload records for payload_data_set_id 299c2030-ad65-492f-a19b-2bb7ce3522f8: 2

# %%
json.loads(scores)
# Out:
# {'output': [{'Scored Labels': 'No Risk',
#    'Scored Probabilities': [0.8922524675865824, 0.10774753241341757]},
#   {'Scored Labels': 'No Risk',
#    'Scored Probabilities': [0.8335192848546905, 0.1664807151453095]}]}

# %%
wos_client.data_sets.get_records_count(data_set_id=payload_data_set_id)
# Out:
# 4

# %% [markdown]
# ## Deploy the wrapper as web service

# %% [markdown]
# ### Create environment file
#
# Next, create an environment file, called myenv.yml, that specifies all of the script's package dependencies. This file is used to ensure that all of those dependencies are installed in the Docker image. This model needs `scikit-learn` and `azureml-sdk`.

# %%
from azureml.core.conda_dependencies import CondaDependencies 
from azureml.core import Environment

environment = Environment('my-sklearn-environment')

environment.python.conda_dependencies = CondaDependencies.create(pip_packages=[
    'azureml-defaults',
    'ibm-watson-openscale'
])

# %% [markdown]
# ### Create configuration file
#
# Create a deployment configuration file and specify the number of CPUs and gigabyte of RAM needed for your ACI container. While it depends on your model, the default of 1 core and 1 gigabyte of RAM is usually sufficient for many models. If you feel you need more later, you would have to recreate the image and redeploy the service.

# %%
from azureml.core.webservice import AciWebservice

aciconfig = AciWebservice.deploy_configuration(cpu_cores=0.5, 
                                               memory_gb=0.5, 
                                               tags={"data": "german credit risk",  "method" : "scoring-endpoint-wrapper"}, 
                                               description='Credit risk scoring endpoint wrapper with payload logging')

# %% [markdown]
# ### Deploy in ACI
# Estimated time to complete: **about 7-8 minutes**
#
# Configure the image and deploy. The following code goes through these steps:
#
# 1. Build an image using:
#    * The scoring file (`score.py`)
#    * The environment definition
#    * The model file
# 1. Register that image under the workspace.
# 1. Send the image to the ACI container.
# 1. Start up a container in ACI using the image.
# 1. Get the web service HTTP endpoint.

# %% [markdown]
# ## Scoring endpoint creation

# %%
# %%time
from azureml.core import Model
from azureml.core.webservice import Webservice
from azureml.exceptions import WebserviceException
from azureml.core.model import InferenceConfig
from azureml.core.image import ContainerImage


service_name = 'credit-risk-rsalehin-wrapper1'

# Remove any existing service under the same name.
try:
    Webservice(ws, service_name).delete()
except WebserviceException:
    pass

inference_config = InferenceConfig(entry_script='score.py', environment=environment)


service = Model.deploy(workspace=ws,
                       name=service_name,
                       models=[],
                       inference_config=inference_config,
                       deployment_config=aciconfig,
                       overwrite=True)
service.wait_for_deployment(show_output=True)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running..............................................................
# Succeeded
# ACI service creation operation finished, operation "Succeeded"
# CPU times: user 442 ms, sys: 78.3 ms, total: 520 ms
# Wall time: 5min 58s

# %% [markdown]
# ## Test deployed wrapper
#
# The following code goes through these steps:
# 1. Send the scoring request to the web service hosted in ACI.
# 2. Print the returned predictions.
# 3. Check if the scoring request and response has been logged as payload records in OpenScale

# %%
scoring_data = {"input":data_df.sample(50).drop(['Risk'],axis=1).to_dict('records')
              }

# %%
from azureml.core.webservice import AciWebservice

credit_risk_wrapper_deployment_name = 'credit-risk-rsalehin-wrapper1'
credit_risk_wrapper_endpoint = None

webservices = AciWebservice.list(ws)
for service in webservices:
    if service.name == credit_risk_wrapper_deployment_name:
        credit_risk_wrapper_endpoint = service.scoring_uri
        
print('scoring endpoint', credit_risk_wrapper_endpoint)
# Out:
# scoring endpoint http://6887514b-5936-4e32-b2b2-bd8e29a0265a.southcentralus.azurecontainer.io/score

# %%
import requests

headers = {'Content-Type':'application/json'}
resp = requests.post(credit_risk_wrapper_endpoint, json=scoring_data, headers=headers)

print("POST to url", credit_risk_wrapper_endpoint)
print(resp.json())
# Out:
# POST to url http://6887514b-5936-4e32-b2b2-bd8e29a0265a.southcentralus.azurecontainer.io/score
# {"output": [{"Scored Labels": "No Risk", "Scored Probabilities": [0.6116460835854189, 0.388353916414581]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.32910592287714735, 0.6708940771228527]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.6918373590339282, 0.3081626409660719]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.7997472129700317, 0.20025278702996827]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.27491685827030143, 0.7250831417296986]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.8577533270189861, 0.14224667298101387]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.7882079942718002, 0.2117920057281998]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.2958438999515982, 0.7041561000484018]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.67717024730288, 0.32282975269711994]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.210999231041601, 0.789000768958399]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.40757688201976794, 0.5924231179802321]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.11701789954584307, 0.8829821004541569]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.9374465581852555, 0.06255344181474456]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.8274776594342426, 0.17252234056575744]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.8958827235697637, 0.10411727643023624]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.6096143087651581, 0.3903856912348419]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.9195182511711442, 0.08048174882885581]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.9559161579671698, 0.04408384203283021]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.514485212267787, 0.48551478773221296]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.6754891111674819, 0.3245108888325181]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.6253582845313805, 0.37464171546861946]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.6283378826430555, 0.3716621173569445]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.9531961003265939, 0.046803899673406146]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.9676577622206721, 0.03234223777932784]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.8825802977535689, 0.11741970224643102]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.7928006655799228, 0.2071993344200772]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.5426794085229281, 0.45732059147707194]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.677865901803532, 0.32213409819646793]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.9659430557876351, 0.03405694421236493]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.7755538105586657, 0.22444618944133438]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.11701789954584307, 0.8829821004541569]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.3827274701282286, 0.6172725298717714]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.6963570574562441, 0.30364294254375584]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.5825807231331506, 0.4174192768668495]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.5934272024401139, 0.40657279755988607]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.1443238536713629, 0.8556761463286371]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.7674392423395829, 0.23256075766041703]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.8736114035812197, 0.12638859641878036]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.4806417200452996, 0.5193582799547004]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.9738485401452762, 0.026151459854723818]}, {"Scored Labels": "No Risk", "Scored Probabilities": [0.9612657756517806, 0.038734224348219416]}, {"Scored Labels": "Risk", "Scored Probabilities": [0.33986 ...

# %% [markdown]
# ### Check if the payload has been logged

# %%
time.sleep(2)
wos_client.data_sets.get_records_count(data_set_id=payload_data_set_id)
# Out:
# 54

# %% [markdown]
# ## Quality monitoring and Feedback logging

# %%
import time

time.sleep(10)
target = Target(
        target_type=TargetTypes.SUBSCRIPTION,
        target_id=subscription_id
)
parameters = {
    "min_feedback_data_size": 10
}
thresholds = [
                {
                    "metric_id": "area_under_roc",
                    "type": "lower_limit",
                    "value": .80
                }
            ]
quality_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.QUALITY.ID,
    target=target,
    parameters=parameters,
    thresholds=thresholds
).result
# Out:
# ===================================================================================
#
#  Waiting for end of monitor instance creation 47dbd1e3-33c2-4841-87ed-b18724c6dd49
#
# ===================================================================================
#
#
#
# active
#
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------

# %%
quality_monitor_instance_id = quality_monitor_details.metadata.id
quality_monitor_instance_id
# Out:
# '47dbd1e3-33c2-4841-87ed-b18724c6dd49'

# %%
# !rm additional_feedback_data_v2.json
# !wget https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/data/credit_risk/additional_feedback_data_v2.json
# Out:
# --2020-11-04 12:49:07--  https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/data/credit_risk/additional_feedback_data_v2.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.192.133, 151.101.64.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50890 (50K) [text/plain]
# Saving to: ‘additional_feedback_data_v2.json’
#
# additional_feedback 100%[===================>]  49.70K  --.-KB/s    in 0.04s
#
# 2020-11-04 12:49:07 (1.27 MB/s) - ‘additional_feedback_data_v2.json’ saved [50890/50890]

# %%
feedback_dataset_id = None
feedback_dataset = wos_client.data_sets.list(type=DataSetTypes.FEEDBACK, 
                                                target_target_id=subscription_id, 
                                                target_target_type=TargetTypes.SUBSCRIPTION).result
#print(feedback_dataset)
feedback_dataset_id = feedback_dataset.data_sets[0].metadata.id
if feedback_dataset_id is None:
    print("Feedback data set not found. Please check quality monitor status.")

# %%
with open('additional_feedback_data_v2.json') as feedback_file:
    additional_feedback_data = json.load(feedback_file)

wos_client.data_sets.store_records(feedback_dataset_id, request_body=additional_feedback_data, background_mode=False)
# Out:
# ==========================================================================================
#
#  Waiting for end of storing records with request id: 73d5596d-603c-4fc8-8b71-99e4555dd073
#
# ==========================================================================================
#
#
#
# active
#
# ---------------------------------------
#  Successfully finished storing records
# ---------------------------------------

# %%
# manually records scoring and store as feedback data

# records = [
#     ["no_checking","28","outstanding_credit","appliances","5990","500_to_1000","greater_7","5","male","co-applicant","3","car_other","55","none","free","2","skilled","2","yes","yes","Risk"],
#     ["greater_200","22","all_credits_paid_back","car_used","3376","less_100","less_1","3","female","none","2","car_other","32","none","own","1","skilled","1","none","yes","No Risk"],
#     ["no_checking","39","credits_paid_to_date","vacation","6434","unknown","greater_7","5","male","none","4","car_other","39","none","own","2","skilled","2","yes","yes","Risk"],
#     ["0_to_200","20","credits_paid_to_date","furniture","2442","less_100","unemployed","3","female","none","1","real_estate","42","none","own","1","skilled","1","none","yes","No Risk"],
#     ["greater_200","4","all_credits_paid_back","education","4206","less_100","unemployed","1","female","none","3","savings_insurance","27","none","own","1","management_self-employed","1","none","yes","No Risk"],
#     ["greater_200","23","credits_paid_to_date","car_used","2963","greater_1000","greater_7","4","male","none","4","car_other","46","none","own","2","skilled","1","none","yes","Risk"],
#     ["no_checking","31","prior_payments_delayed","vacation","2673","500_to_1000","1_to_4","3","male","none","2","real_estate","35","stores","rent","1","skilled","2","none","yes","Risk"],
#     ["no_checking","37","prior_payments_delayed","other","6971","500_to_1000","1_to_4","3","male","none","3","savings_insurance","54","none","own","2","skilled","1","yes","yes","Risk"],
#     ["0_to_200","39","prior_payments_delayed","appliances","5685","100_to_500","1_to_4","4","female","none","2","unknown","37","none","own","2","skilled","1","yes","yes","Risk"],
#     ["no_checking","38","prior_payments_delayed","appliances","4990","500_to_1000","greater_7","4","male","none","4","car_other","50","bank","own","2","unemployed","2","yes","yes","Risk"]]

# fields = feature_columns.copy()
# fields.append('Risk')

# payload_scoring =  [{"fields": fields, "values": records}]
# payload_scoring

# wos_client.data_sets.store_records(feedback_dataset_id, request_body=payload_scoring, background_mode=False)

# %%
wos_client.data_sets.get_records_count(data_set_id=feedback_dataset_id)
# Out:
# 98

# %%
run_details = wos_client.monitor_instances.run(monitor_instance_id=quality_monitor_instance_id, background_mode=False).result
# Out:
# ========================================================================
#
#  Waiting for end of monitoring run f59179b8-2851-46b1-8b8b-91e140dfd83a
#
# ========================================================================
#
#
#
# running
# finished
#
# ---------------------------
#  Successfully finished run
# ---------------------------

# %%
time.sleep(5)
wos_client.monitor_instances.show_metrics(monitor_instance_id=quality_monitor_instance_id)
# Out:
# <HTML>
#         <body>
#             <h3>47dbd1e3-33c2-4841-87ed-b18724c6dd49 Monitor Runs Metrics from: 2020-10-28 12:55:48.976098  till: 2020-11-04 12:55:48.976111</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>ts</th><th style='border: 1px solid #dddddd'>id</th><th style='border: 1px solid #dddddd'>measurement_id</th><th style='border: 1px solid #dddddd'>value</th><th style='border: 1px solid #dddddd'>lower_limit</th><th style='border: 1px solid #dddddd'>upper_limit</th><th style='border: 1px solid #dddddd'>tags</th><th style='border: 1px solid #dddddd'>monitor_definition_id</th><th style='border: 1px solid #dddddd'>monitor_instance_id</th><th style='border: 1px solid #dddddd'>run_id</th><th style='border: 1px solid #dddddd'>target_type</th><th style='border: 1px solid #dddddd'>target_id</th>
#
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ## Fairness, Drift and Explainability configuration

# %%
target = Target(
    target_type=TargetTypes.SUBSCRIPTION,
    target_id=subscription_id

)
parameters = {
    "features": [
        {"feature": "Sex",
         "majority": ['male'],
         "minority": ['female'],
         "threshold": 0.95
         },
        {"feature": "Age",
         "majority": [[26, 75]],
         "minority": [[18, 25]],
         "threshold": 0.95
         }
    ],
    "favourable_class": ["No Risk"],
    "unfavourable_class": ["Risk"],
    "min_records": 50
}

fairness_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.FAIRNESS.ID,
    target=target,
    parameters=parameters).result
fairness_monitor_instance_id =fairness_monitor_details.metadata.id
fairness_monitor_instance_id
# Out:
# ===================================================================================
#
#  Waiting for end of monitor instance creation 14ceaa49-fa60-4e93-9792-c66d9e362538
#
# ===================================================================================
#
#
#
# active
#
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------
# '14ceaa49-fa60-4e93-9792-c66d9e362538'

# %%
run_details = wos_client.monitor_instances.run(monitor_instance_id=fairness_monitor_instance_id, background_mode=False)
# Out:
# ========================================================================
#
#  Waiting for end of monitoring run acf13d70-1e84-4fd9-a1f3-55a766a01b1e
#
# ========================================================================
#
#
#
# finished
#
# ---------------------------
#  Successfully finished run
# ---------------------------

# %% [markdown]
# ### Drift configuration
#
# - Drift requires a trained model to be uploaded manually for Azure. You can train, create and download a drift detection model using template given ( check for Drift detection model generation) [here](https://github.com/IBM-Watson/aios-data-distribution/blob/master/training_statistics_notebook.ipynb)

# %%
# !rm -rf creditrisk_azure_drift_detection_model.tar.gz
# !wget -O creditrisk_azure_drift_detection_model.tar.gz https://github.com/IBM/watson-openscale-samples/blob/main/assets/models/credit_risk/azure_creditrisk_drift_detection_model.tar.gz?raw=true
# Out:
# --2020-11-04 12:57:14--  https://github.com/IBM/watson-openscale-samples/blob/main/assets/models/credit_risk/azure_creditrisk_drift_detection_model.tar.gz?raw=true
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/IBM/watson-openscale-samples/raw/main/assets/models/credit_risk/azure_creditrisk_drift_detection_model.tar.gz [following]
# --2020-11-04 12:57:14--  https://github.com/IBM/watson-openscale-samples/raw/main/assets/models/credit_risk/azure_creditrisk_drift_detection_model.tar.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/models/credit_risk/azure_creditrisk_drift_detection_model.tar.gz [following]
# --2020-11-04 12:57:14--  https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/models/credit_risk/azure_creditrisk_drift_detection_model.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.128.133, 151.101.192.133, 151.101.0.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.128.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229416 (224K) [application/octet-stream]
# Saving to: ‘creditrisk_azure_drift_detection_model.tar.gz’
#
# creditrisk_azure_dr 100%[===================>] 224.04K  --.-KB/s    in 0.08s
#
# 2020-11-04 12:57:15 (2.59 MB/s) - ‘creditrisk_azure_drift_detection_model.tar.gz’ saved [229416/229416]

# %%
wos_client.monitor_instances.upload_drift_model(
        model_path='creditrisk_azure_drift_detection_model.tar.gz',
        data_mart_id=data_mart_id,
        subscription_id=subscription_id
     )

# %%
monitor_instances = wos_client.monitor_instances.list().result.monitor_instances
for monitor_instance in monitor_instances:
    monitor_def_id=monitor_instance.entity.monitor_definition_id
    if monitor_def_id == "drift" and monitor_instance.entity.target.target_id == subscription_id:
        wos_client.monitor_instances.delete(monitor_instance.metadata.id)
        print('Deleted existing drift monitor instance with id: ', monitor_instance.metadata.id)

# %%
target = Target(
    target_type=TargetTypes.SUBSCRIPTION,
    target_id=subscription_id

)
parameters = {
    "min_samples": 50,
    "drift_threshold": 0.1,
    "train_drift_model": False,
    "enable_model_drift": True,
    "enable_data_drift": True
}

drift_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.DRIFT.ID,
    target=target,
    parameters=parameters
).result

drift_monitor_instance_id = drift_monitor_details.metadata.id
drift_monitor_instance_id
# Out:
# ===================================================================================
#
#  Waiting for end of monitor instance creation 85027099-5242-4da2-819d-349f35667954
#
# ===================================================================================
#
#
#
# active
#
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------
# '85027099-5242-4da2-819d-349f35667954'

# %%
drift_run_details = wos_client.monitor_instances.run(monitor_instance_id=drift_monitor_instance_id, background_mode=False)
# Out:
# ========================================================================
#
#  Waiting for end of monitoring run 708b96a3-7ce4-4d9e-8d33-bf32d884576e
#
# ========================================================================
#
#
#
# finished
#
# ---------------------------
#  Successfully finished run
# ---------------------------

# %%
time.sleep(5)
wos_client.monitor_instances.show_metrics(monitor_instance_id=drift_monitor_instance_id)
# Out:
# <HTML>
#         <body>
#             <h3>3e360b30-dc5f-4487-99b9-d9a0b32f1748 Monitor Runs Metrics from: 2020-10-14 01:31:55.903355  till: 2020-10-21 01:31:55.903375</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>ts</th><th style='border: 1px solid #dddddd'>id</th><th style='border: 1px solid #dddddd'>measurement_id</th><th style='border: 1px solid #dddddd'>value</th><th style='border: 1px solid #dddddd'>lower_limit</th><th style='border: 1px solid #dddddd'>upper_limit</th><th style='border: 1px solid #dddddd'>tags</th><th style='border: 1px solid #dddddd'>monitor_definition_id</th><th style='border: 1px solid #dddddd'>monitor_instance_id</th><th style='border: 1px solid #dddddd'>run_id</th><th style='border: 1px solid #dddddd'>target_type</th><th style='border: 1px solid #dddddd'>target_id</th>
#
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ### Explainability configuration

# %%
target = Target(
    target_type=TargetTypes.SUBSCRIPTION,
    target_id=subscription_id
)
parameters = {
    "enabled": True
}
explainability_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.EXPLAINABILITY.ID,
    target=target,
    parameters=parameters
).result
# Out:
# ===================================================================================
#
#  Waiting for end of monitor instance creation 0e7e5fe5-2746-45b7-9b53-4e396dff87f1
#
# ===================================================================================
#
#
#
# active
#
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------

# %%
explainability_monitor_id = explainability_details.metadata.id
explainability_monitor_id
# Out:
# '0e7e5fe5-2746-45b7-9b53-4e396dff87f1'

# %%
pl_records_resp = wos_client.data_sets.get_list_of_records(data_set_id=payload_data_set_id, limit=1, offset=0).result
scoring_ids = [pl_records_resp["records"][0]["entity"]["values"]["scoring_id"]]
print("Running explanations on scoring IDs: {}".format(scoring_ids))
explanation_types = ["lime", "contrastive"]
result = wos_client.monitor_instances.explanation_tasks(scoring_ids=scoring_ids, explanation_types=explanation_types).result
print(result)
explanation_task_id=result.to_dict()['metadata']['explanation_task_ids'][0]
explanation_task_id
# Out:
# Running explanations on scoring IDs: ['b976be46-b8a0-49be-a22c-0f3489819c63-1']
# {
#   "metadata": {
#     "explanation_task_ids": [
#       "798956ef-0414-416e-83eb-634762286d9a"
#     ],
#     "created_by": "IBMid-310002F0G1",
#     "created_at": "2020-11-04T18:00:50.890336Z"
#   }
# }
# '798956ef-0414-416e-83eb-634762286d9a'

# %%
wos_client.monitor_instances.get_explanation_tasks(explanation_task_id=explanation_task_id).result.to_dict()
# Out:
# {'metadata': {'explanation_task_id': '798956ef-0414-416e-83eb-634762286d9a',
#   'created_by': 'IBMid-310002F0G1',
#   'created_at': '2020-11-04T18:00:50.890336Z',
#   'updated_at': '2020-11-04T18:01:02.433626Z'},
#  'entity': {'status': {'state': 'in_progress'},
#   'asset': {'id': '9099ad7e60c9698597199983c976c65a',
#    'name': 'credit-risk-rsalehin',
#    'input_data_type': 'structured',
#    'problem_type': 'binary',
#    'deployment': {'id': '91a58dcc30f1cf7ee72f06ac6f8f3c67',
#     'name': 'credit-risk-rsalehin'}},
#   'input_features': [{'name': 'CheckingStatus',
#     'value': 'no_checking',
#     'feature_type': 'categorical'},
#    {'name': 'LoanDuration', 'value': '8', 'feature_type': 'numerical'},
#    {'name': 'CreditHistory',
#     'value': 'prior_payments_delayed',
#     'feature_type': 'categorical'},
#    {'name': 'LoanPurpose', 'value': 'car_used', 'feature_type': 'categorical'},
#    {'name': 'LoanAmount', 'value': '1367', 'feature_type': 'numerical'},
#    {'name': 'ExistingSavings',
#     'value': '500_to_1000',
#     'feature_type': 'categorical'},
#    {'name': 'EmploymentDuration',
#     'value': '1_to_4',
#     'feature_type': 'categorical'},
#    {'name': 'InstallmentPercent', 'value': '2', 'feature_type': 'numerical'},
#    {'name': 'Sex', 'value': 'male', 'feature_type': 'categorical'},
#    {'name': 'OthersOnLoan', 'value': 'none', 'feature_type': 'categorical'},
#    {'name': 'CurrentResidenceDuration',
#     'value': '3',
#     'feature_type': 'numerical'},
#    {'name': 'OwnsProperty',
#     'value': 'savings_insurance',
#     'feature_type': 'categorical'},
#    {'name': 'Age', 'value': '45', 'feature_type': 'numerical'},
#    {'name': 'InstallmentPlans',
#     'value': 'none',
#     'feature_type': 'categorical'},
#    {'name': 'Housing', 'value': 'rent', 'feature_type': 'categorical'},
#    {'name': 'ExistingCreditsCount', 'value': '1', 'feature_type': 'numerical'},
#    {'name': 'Job',
#     'value': 'management_self-employed',
#     'feature_type': 'categorical'},
#    {'name': 'Dependents', 'value': '1', 'feature_type': 'numerical'},
#    {'name': 'Telephone', 'value': 'yes', 'feature_type': 'categorical'},
#    {'name': 'ForeignWorker', 'value': 'yes', 'feature_type': 'categorical'}],
#   'perturbed': False,
#   'explanations': [{'explanation_type': 'lime',
#     'predictions': [{'explanation_features': [{'feature_name': 'Dependents',
#         'weight': 0.1409962308353755,
#         'feature_range': {'max_inclusive': True, 'max': '1.00'}},
#        {'feature_name': 'OthersOnLoan',
#         'feature_value': 'none',
#         'weight': 0.13395924397455214},
#        {'feature_name': 'ExistingSavings',
#         'feature_value': '500_to_1000',
#         'weight': 0.13046805351983673},
#        {'feature_name': 'CheckingStatus',
#         'feature_value': 'no_checking',
#         'weight': 0.12963553853465518},
#        {'feature_name': 'ForeignWorker',
#         'feature_value': 'yes',
#         'weight': 0.12489964008626796},
#        {'feature_name': 'LoanPurpose',
#         'feature_value': 'car_used',
#         'weight': 0.12170632083611793},
#        {'feature_name': 'Sex',
#         'feature_value': 'male',
#         'weight': 0.05692091152163934},
#        {'feature_name': 'LoanAmount',
#         'weight': 0.05568918152352167,
#         'feature_range': {'max_inclusive': True,
#          'min': '1326.75',
#          'max': '3238.50',
#          'min_inclusive': False}},
#        {'feature_name': 'LoanDuration',
#         'weight': 0.053892302695723746,
#         'feature_range': {'max_inclusive': True, 'max': '13.00'}},
#        {'feature_name': 'EmploymentDuration',
#         'feature_value': '1_to_4',
#         'weight': 0.05183257647230985}],
#       'probability': 0.6116460835854189,
#       'value': 'No Risk'},
#      {'probability': 0.38835391641458106, 'value': 'Risk'}]}]}}

# %% [markdown]
# ## Congratulations
#
# You have finished the tutorial for IBM Watson OpenScale and Azure Machine Learning Studio. You can now view the [OpenScale Dashboard](https://aiopenscale.cloud.ibm.com/). Click on the tile for the German Credit Azure model to see fairness, accuracy, and performance monitors. Click on the timeseries graph to get detailed information on transactions during a specific time window.
