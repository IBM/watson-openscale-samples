# %% [markdown]
# <img src="https://github.com/pmservice/ai-openscale-tutorials/raw/master/notebooks/images/banner.png" align="left" alt="banner">

# %% [markdown]
# # Working with SPSS Collaboration and Deployment Services
#
# ### Compatible with Cloud Pak for Data Only

# %% [markdown]
# This notebook shows how to log the payload for the model deployed on custom model serving engine using Watson OpenScale python sdk.

# %% [markdown]
# Contents
#  - Setup
#  - Binding machine learning engine
#  - Subscriptions
#  - Performance monitor, scoring and payload logging
#  - Quality monitor and feedback logging
#  - Fairness,Drift monitoring and explanations

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Sample model creation using SPSS Modeler

# %% [markdown]
# - Download training data set from [here](https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/data/credit_risk/credit_risk_training.csv)
# - Download SPSS Modeler stream from [here](https://github.com/IBM/watson-openscale-samples/tree/main/assets/models/credit_risk/german_credit_risk_tutorial.str)
# - Deploy the model using SPSS C&DS as web service

# %% [markdown]
# ### Installation and authentication

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install --upgrade ibm-watson-openscale | tail -n 1
# Out:
# Requirement already satisfied, skipping upgrade: PyJWT>=1.7.1 in /opt/conda/envs/Python-3.6-WMLCE/lib/python3.6/site-packages (from ibm-cloud-sdk-core>=1.5->ibm-watson-openscale) (1.7.1)

# %% [markdown]
# Import and initiate.

# %%
WOS_CREDENTIALS = {
    "url": "https://namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com",
    "username": "admin",
    "password": "password"
}

# %%
WML_CREDENTIALS = {
                   "url": "https://namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com",
                    "username": "admin",
                    "password": "password",
                    "instance_id": "wml_local",
                   "version" : "3.5"

                  }

# %%
IAM_URL="https://iam.ng.bluemix.net/oidc/token"
COS_API_KEY_ID = "917Z-0MQzVpgdqkHClXbfDchrXZ_bl7kbCxZSkynzsLP"
COS_RESOURCE_CRN = "crn:v1:bluemix:public:cloud-object-storage:global:a/e0b56432b1f1bd804706dc29b8a89ca1:57b5eb6e-7b5d-4b90-a8e8-3736129c9010::" # eg "crn:v1:bluemix:public:cloud-object-storage:global:a/3bf0d9003abfb5d29761c3e97696b71c:d6f04d83-6c4f-4a62-a165-696756d63903::"
COS_ENDPOINT = "https://s3.us.cloud-object-storage.appdomain.cloud" # Current list avaiable at https://control.cloud-object-storage.cloud.ibm.com/v2/endpoints

# %%
BUCKET_NAME = "wmlv4-donotdelete-pr-e8rgr9bhcjtlae" #example: "credit-risk-training-data"
training_data_file_name="credit_risk_training.csv"

# %%
instance_id='00000000-0000-0000-0000-1604128772718153' ## default instance ID: 00000000-0000-0000-0000-0000000000000000

# %%
from ibm_cloud_sdk_core.authenticators import CloudPakForDataAuthenticator
from ibm_watson_openscale import APIClient

from ibm_watson_openscale import *
from ibm_watson_openscale.supporting_classes.enums import *
from ibm_watson_openscale.supporting_classes import *

authenticator = CloudPakForDataAuthenticator(
        url=WOS_CREDENTIALS['url'],
        username=WOS_CREDENTIALS['username'],
        password=WOS_CREDENTIALS['password'],
        disable_ssl_verification=True
    )

wos_client = APIClient(service_url=WOS_CREDENTIALS['url'],service_instance_id=instance_id,authenticator=authenticator)
wos_client.version
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# '3.0.2'

# %% [markdown]
# #### Let's define some constants required to set up data mart:
#
# - AIOS_CREDENTIALS (ICP)
# - DATABASE_CREDENTIALS (DB2 on ICP)
# - SCHEMA_NAME

# %%
DB_CREDENTIALS=None
#DB_CREDENTIALS= {"hostname":"","username":"","password":"","database":"","port":"","ssl":True,"sslmode":"","certificate_base64":""}

# %%
SCHEMA_NAME = 'SPSSTF01'

# %% [markdown]
# ### DataMart setup
#
# Watson OpenScale uses a database to store payload logs and calculated metrics. If database credentials were **not** supplied above, the notebook will use the free, internal lite database. If database credentials were supplied, the datamart will be created there **unless** there is an existing datamart **and** the **KEEP_MY_INTERNAL_POSTGRES** variable is set to **True**. If an OpenScale datamart exists in Db2 or PostgreSQL, the existing datamart will be used and no data will be overwritten.
#
# Prior instances of the German Credit model will be removed from OpenScale monitoring.

# %%
wos_client.data_marts.show()
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <HTML>
#         <body>
#             <h3>Data Marts</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>name</th><th style='border: 1px solid #dddddd'>description</th><th style='border: 1px solid #dddddd'>internal_database</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>False</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2020-10-31 07:22:08.779000+00:00</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-1604128772718153</td></tr>
#             </table>
#         </body>
#         </HTML>

# %%
data_marts = wos_client.data_marts.list().result.data_marts
if len(data_marts) == 0:
    if DB_CREDENTIALS is not None:
        if SCHEMA_NAME is None: 
            print("Please specify the SCHEMA_NAME and rerun the cell")

        print('Setting up external datamart')
        added_data_mart_result = wos_client.data_marts.add(
                background_mode=False,
                name="WOS Data Mart",
                description="Data Mart created by WOS tutorial notebook",
                database_configuration=DatabaseConfigurationRequest(
                  database_type=DatabaseType.POSTGRESQL,
                    credentials=PrimaryStorageCredentialsLong(
                        hostname=DB_CREDENTIALS['hostname'],
                        username=DB_CREDENTIALS['username'],
                        password=DB_CREDENTIALS['password'],
                        db=DB_CREDENTIALS['database'],
                        port=DB_CREDENTIALS['port'],
                        ssl=True,
                        sslmode=DB_CREDENTIALS['sslmode'],
                        certificate_base64=DB_CREDENTIALS['certificate_base64']
                    ),
                    location=LocationSchemaName(
                        schema_name= SCHEMA_NAME
                    )
                )
             ).result
    else:
        print('Setting up internal datamart')
        added_data_mart_result = wos_client.data_marts.add(
                background_mode=False,
                name="WOS Data Mart",
                description="Data Mart created by WOS tutorial notebook", 
                internal_database = True).result
        
    data_mart_id = added_data_mart_result.metadata.id
    
else:
    data_mart_id=data_marts[0].metadata.id
    print('Using existing datamart {}'.format(data_mart_id))
# Out:
# Using existing datamart 00000000-0000-0000-0000-1604128772718153
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# <a id="binding"></a>
# ## Bind machine learning engines

# %% [markdown]
# ### Bind  `SPSS C&DS` machine learning engine
#
# Provide credentials using following fields:
# - `username`
# - `password`
# - `url`

# %%
SPSS_CDS_ENGINE_CREDENTIALS = {
        "url": "http://dismiss1.fyre.ibm.com:9080",
        "username": "admin",
        "password": "spss",
    }

# %%
SERVICE_PROVIDER_NAME = "V2 SPSS test"
SERVICE_PROVIDER_DESCRIPTION = "Added by tutorial WOS notebook."

# %%
service_providers = wos_client.service_providers.list().result.service_providers
for service_provider in service_providers:
    service_instance_name = service_provider.entity.name
    if service_instance_name == SERVICE_PROVIDER_NAME:
        service_provider_id = service_provider.metadata.id
        wos_client.service_providers.delete(service_provider_id)
        print("Deleted existing service_provider for WML instance: {}".format(service_provider_id))
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Deleted existing service_provider for WML instance: 9469fe28-59d3-4194-9523-9f0d2f7d82b2
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
added_service_provider_result = wos_client.service_providers.add(
        name=SERVICE_PROVIDER_NAME,
        description=SERVICE_PROVIDER_DESCRIPTION,
        service_type=ServiceTypes.SPSS_COLLABORATION_AND_DEPLOYMENT_SERVICES,
        credentials=SPSSCredentials(
            url=SPSS_CDS_ENGINE_CREDENTIALS['url'],      
            username=SPSS_CDS_ENGINE_CREDENTIALS["username"],
            password=SPSS_CDS_ENGINE_CREDENTIALS['password']
        ),
        background_mode=False
    ).result
service_provider_id = added_service_provider_result.metadata.id
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# =================================================================================
#
#  Waiting for end of adding service provider b45a656e-38fc-4a61-87ad-28025a2032b0
#
# =================================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# active
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# -----------------------------------------------
#  Successfully finished adding service provider
# -----------------------------------------------

# %%
asset_deployment_details = wos_client.service_providers.list_assets(data_mart_id=data_mart_id, service_provider_id=service_provider_id).result['resources']
asset_deployment_details
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# [{'metadata': {'guid': 'credit_risk_db2',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/credit_risk_db2/score'},
#   'entity': {'name': 'credit_risk_db2',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/credit_risk_db2/score'},
#    'asset': {'asset_id': '091edbc5c4e74be500000168f14b3eb1be39',
#     'url': '/credit_risk/credit_risk_db2.str',
#     'name': 'credit_risk_db2'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'DASH101323.CREDIT_RISK_SCORING_DATA',
#      'id': 'id4XSTWFFJR3V',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': '$L-Risk', 'type': 'string', 'nullable': False},
#       {'name': '$LP-Risk', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'credit risk+mlogistic&test',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/credit risk+mlogistic&test/score'},
#   'entity': {'name': 'credit risk+mlogistic&test',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/credit risk+mlogistic&test/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110990e',
#     'url': '/aiopenscale/credit_risk_mlogistic.str',
#     'name': 'credit risk+mlogistic&test'},
#    'asset_properties': {}}},
#  {'metadata': {'guid': 'ai_drug_mlp',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_drug_mlp/score'},
#   'entity': {'name': 'ai_drug_mlp',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_drug_mlp/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110992c',
#     'url': '/aiopenscale/Drug1n.str',
#     'name': 'ai_drug_mlp'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'scoreInput',
#      'id': 'id1JRRSIWAHWX',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False},
#       {'name': '$N-Drug', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Drug', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'SPSS-テスト-German-credit-risk-tutorial-BiasQA',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/SPSS-テスト-German-credit-risk-tutorial-BiasQA/score'},
#   'entity': {'name': 'SPSS-テスト-German-credit-risk-tutorial-BiasQA',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/SPSS-テスト-German-credit-risk-tutorial-BiasQA/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110cafe',
#     'url': '/credit_risk/german_credit_risk_tutorial.str',
#     'name': 'SPSS-テスト-German-credit-risk-tutorial-BiasQA'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'credit_risk_scoring.csv',
#      'id': 'id4QCUV9G15M2',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': '$N-Risk', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Risk', 'type': 'double', 'nullable': False},
#       {'name': '$NP-No Risk', 'type': 'double', 'nullable': False},
#       {'name': '$NP-Risk', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'Drug1n',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/Drug1n/score'},
#   'entity': {'name': 'Drug1n',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/Drug1n/score'},
#    'asset': {'asset_id': '091edbc5418240f600000166f5190140d404',
#     'url': '/Test/Drug1n.str',
#     'name': 'Drug1n'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'scoreInput',
#      'id': 'id1JRRSIWAHWX',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False},
#       {'name': '$N-Drug', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Drug', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'ai_drug_mlp_proba_BiasQA',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_drug_mlp_proba_BiasQA/score'},
#   'entity': {'name': 'ai_drug_mlp_proba_BiasQA',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_drug_mlp_proba_BiasQA/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110a105',
#     'url': '/aiopenscale/Drug1n_proba.str',
#     'name': 'ai_drug_mlp_proba_BiasQA'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'scoreInput',
#      'id': 'id1JRRSIWAHWX',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False},
#       {'name': '$N-Drug', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Drug', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugA', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugB', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugC', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugX', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugY', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'credit_risk_binary_type',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/credit_risk_binary_type/score'},
#   'entity': {'name': 'credit_risk_binary_type',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/credit_risk_binary_type/score'},
#    'asset': {'asset_id': '091e7b2d81f7115e0000016bf1fc253a741e',
#     'url': '/credit_risk/credit_risk_binary_type.str',
#     'name': 'credit_risk_binary_type'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'credit_risk_scoring.csv',
#      'id': 'id2HIU7NQSJN4',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': '$L-CreditRisk', 'type': 'string', 'nullable': False},
#       {'name': '$LRP-CreditRisk', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'german_credit_risk_tutorial',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/german_credit_risk_tutorial/score'},
#   'entity': {'name': 'german_credit_risk_tutorial',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/german_credit_risk_tutorial/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110cafe',
#     'url': '/credit_risk/german_credit_risk_tutorial.str',
#     'name': 'german_credit_risk_tutorial'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'credit_risk_scoring.csv',
#      'id': 'id4QCUV9G15M2',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': '$N-Risk', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Risk', 'type': 'double', 'nullable': False},
#       {'name': '$NP-No Risk', 'type': 'double', 'nullable': False},
#       {'name': '$NP-Risk', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'toy_linear_as_regression',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/toy_linear_as_regression/score'},
#   'entity': {'name': 'toy_linear_as_regression',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/toy_linear_as_regression/score'},
#    'asset': {'asset_id': '091edbc5c4e74be500000168f14b3eb164de',
#     'url': '/toy/regression/linear_as.str',
#     'name': 'toy_linear_as_regression'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'score_data.csv',
#      'id': 'id33TTKRFV72H',
#      'fields': [{'name': 'X1', 'type': 'double', 'nullable': False},
#       {'name': 'X2', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'X1', 'type': 'double', 'nullable': False},
#       {'name': 'X2', 'type': 'double', 'nullable': False},
#       {'name': '$L-y', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'ai_housing_model_crt',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_housing_model_crt/score'},
#   'entity': {'name': 'ai_housing_model_crt',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_housing_model_crt/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c71109918',
#     'url': '/aiopenscale/housing_model.str',
#     'name': 'ai_housing_model_crt'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'housing_data.csv',
#      'id': 'id7JFTNZZMJQL',
#      'fields': [{'name': 'CRIM', 'type': 'double', 'nullable': False},
#       {'name': 'ZN', 'type': 'double', 'nullable': False},
#       {'name': 'INDUS', 'type': 'double', 'nullable': False},
#       {'name': 'CHAS', 'type': 'long', 'nullable': False},
#       {'name': 'NOX', 'type': 'double', 'nullable': False},
#       {'name': 'RM', 'type': 'double', 'nullable': False},
#       {'name': 'AGE', 'type': 'double', 'nullable': False},
#       {'name': 'DIS', 'type': 'double', 'nullable': False},
#       {'name': 'RAD', 'type': 'long', 'nullable': False},
#       {'name': 'TAX', 'type': 'double', 'nullable': False},
#       {'name': 'PTRATIO', 'type': 'double', 'nullable': False},
#       {'name': 'Bk', 'type': 'double', 'nullable': False},
#       {'name': 'LSTAT', 'type': 'double', 'nullable': False},
#       {'name': 'MEDV', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CRIM', 'type': 'double', 'nullable': False},
#       {'name': 'ZN', 'type': 'double', 'nullable': False},
#       {'name': 'INDUS', 'type': 'double', 'nullable': False},
#       {'name': 'CHAS', 'type': 'long', 'nullable': False},
#       {'name': 'NOX', 'type': 'double', 'nullable': False},
#       {'name': 'RM', 'type': 'double', 'nullable': False},
#       {'name': 'AGE', 'type': 'double', 'nullable': False},
#       {'name': 'DIS', 'type': 'double', 'nullable': False},
#       {'name': 'RAD', 'type': 'long', 'nullable': False},
#       {'name': 'TAX', 'type': 'double', 'nullable': False},
#       {'name': 'PTRATIO', 'type': 'double', 'nullable': False},
#       {'name': 'Bk', 'type': 'double', 'nullable': False},
#       {'name': 'LSTAT', 'type': 'double', 'nullable': False},
#       {'name': 'MEDV', 'type': 'double', 'nullable': False},
#       {'name': '$R-MEDV', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'test_pm_selflearn',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/test_pm_selflearn/score'},
#   'entity': {'name': 'test_pm_selflearn',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/test_pm_selflearn/score'},
#    'asset': {'asset_id': '091edbc5c4e74be500000168f14b3eb1661f',
#     'url': '/toy/pm_selflearn.str',
#     'name': 'test_pm_selflearn'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'pm_customer_train3.sav',
#      'id': 'id2L7RSHX7WGS',
#      'fields': [{'name': 'customer_id', 'type': 'long', 'nullable': False},
#       {'name': 'campaign', 'type': 'long', 'nullable': False},
#       {'name': 'response', 'type': 'long', 'nullable': False},
#       {'name': 'response_date', 'type': 'timestamp', 'nullable': False},
#       {'name': 'purchase', 'type': 'long', 'nullable': False},
#       {'name': 'purchase_date', 'type': 'timestamp', 'nullable': False},
#       {'name': 'product_id', 'type': 'long', 'nullable': False},
#       {'name': 'Rowid', 'type': 'long', 'nullable': False},
#       {'name': 'age', 'type': 'long', 'nullable': False},
#       {'name': 'age_youngest_child', 'type': 'long', 'nullable': False},
#       {'name': 'average#balance#feed#index',
#        'type': 'long',
#        'nullable': False},
#       {'name': 'branch', 'type': 'string', 'nullable': False},
#       {'name': 'debt_equity', 'type': 'long', 'nullable': False},
#       {'name': 'gender', 'type': 'string', 'nullable': False},
#       {'name': 'bad_payment', 'type': 'long', 'nullable': False},
#       {'name': 'gold_card', 'type': 'long', 'nullable': False},
#       {'name': 'pension_plan', 'type': 'long', 'nullable': False},
#       {'name': 'household_debt_to_equity_ratio',
#        'type': 'long',
#        'nullable': False},
#       {'name': 'income', 'type': 'double', 'nullable': False},
#       {'name': 'marital', 'type': 'string', 'nullable': False},
#       {'name': 'members_in_household', 'type': 'long', 'nullable': False},
#       {'name': 'months_current_account', 'type': 'long', 'nullable': False},
#       {'name': 'months_customer', 'type': 'string', 'nullable': False},
#       {'name': 'call_center_contacts', 'type': 'long', 'nullable': False},
#       {'name': 'loan_accounts', 'type': 'long', 'nullable': False},
#       {'name': 'number_products', 'type': 'long', 'nullable': False},
#       {'name': 'number_transactions', 'type': 'long', 'nullable': False},
#       {'name': 'non_worker_percentage', 'type': 'long', 'nullable': False},
#       {'name': 'white_collar_percentage', 'type': 'long', 'nullable': False},
#       {'name': 'rfm_score', 'type': 'double', 'nullable': False},
#       {'name': 'X_random', 'type': 'long', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'customer_id', 'type': 'long', 'nullable': False},
#       {'name': 'campaign', 'type': 'string', 'nullable': False},
#       {'name': 'response', 'type': 'long', 'nullable': False},
#       {'name': 'response_date', 'type': 'timestamp', 'nullable': False},
#       {'name': 'purchase', 'type': 'long', 'nullable': False},
#       {'name': 'purchase_date', 'type': 'timestamp', 'nullable': False},
#       {'name': 'product_id', 'type': 'long', 'nullable': False},
#       {'name': 'Rowid', 'type': 'long', 'nullable': False},
#       {'name': 'age', 'type': 'long', 'nullable': False},
#       {'name': 'age_youngest_child', 'type': 'long', 'nullable': False},
#       {'name': 'average#balance#feed#index',
#        'type': 'long',
#        'nullable': False},
#       {'name': 'branch', 'type': 'string', 'nullable': False},
#       {'name': 'debt_equity', 'type': 'long', 'nullable': False},
#       {'name': 'gender', 'type': 'string', 'nullable': False},
#       {'name': 'bad_payment', 'type': 'long', 'nullable': False},
#       {'name': 'gold_card', 'type': 'long', 'nullable': False},
#       {'name': 'pension_plan', 'type': 'long', 'nullable': False},
#       {'name': 'household_debt_to_equity_ratio',
#        'type': 'long',
#        'nullable': False},
#       {'name': 'income', 'type': 'double', 'nullable': False},
#       {'name': 'marital', 'type': 'string', 'nullable': False},
#       {'name': 'members_in_household', 'type': 'long', 'nullable': False},
#       {'name': 'months_current_account', 'type': 'long', 'nullable': False},
#       {'name': 'months_customer', 'type': 'string', 'nullable': False},
#       {'name': 'call_center_contacts', 'type': 'long', 'nullable': False},
#       {'name': 'loan_accounts', 'type': 'long', 'nullable': False},
#       {'name': 'number_products', 'type': 'long', 'nullable': False},
#       {'name': 'number_transactions', 'type': 'long', 'nullable': False},
#       {'name': 'non_worker_percentage', 'type': 'long', 'nullable': False},
#       {'name': 'white_collar_percentage', 'type': 'long', 'nullable': False},
#       {'name': 'rfm_score', 'type': 'double', 'nullable': False},
#       {'name': 'X_random', 'type': 'long', 'nullable': False},
#       {'name': '$S-campaign-1', 'type': 'string', 'nullable': False},
#       {'name': '$SC-campaign-1', 'type': 'double', 'nullable': False},
#       {'name': '$S-campaign-2', 'type': 'string', 'nullable': False},
#       {'name': '$SC-campaign-2', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'house_prices',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/house_prices/score'},
#   'entity': {'name': 'house_prices',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/house_prices/score'},
#    'asset': {'asset_id': '091edbc5c4e74be500000167bc5c18e0595e',
#     'url': '/Test/housing_model.str',
#     'name': 'house_prices'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'housing_data.csv',
#      'id': 'id7JFTNZZMJQL',
#      'fields': [{'name': 'CRIM', 'type': 'double', 'nullable': False},
#       {'name': 'ZN', 'type': 'double', 'nullable': False},
#       {'name': 'INDUS', 'type': 'double', 'nullable': False},
#       {'name': 'CHAS', 'type': 'long', 'nullable': False},
#       {'name': 'NOX', 'type': 'double', 'nullable': False},
#       {'name': 'RM', 'type': 'double', 'nullable': False},
#       {'name': 'AGE', 'type': 'double', 'nullable': False},
#       {'name': 'DIS', 'type': 'double', 'nullable': False},
#       {'name': 'RAD', 'type': 'long', 'nullable': False},
#       {'name': 'TAX', 'type': 'double', 'nullable': False},
#       {'name': 'PTRATIO', 'type': 'double', 'nullable': False},
#       {'name': 'Bk', 'type': 'double', 'nullable': False},
#       {'name': 'LSTAT', 'type': 'double', 'nullable': False},
#       {'name': 'MEDV', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CRIM', 'type': 'double', 'nullable': False},
#       {'name': 'ZN', 'type': 'double', 'nullable': False},
#       {'name': 'INDUS', 'type': 'double', 'nullable': False},
#       {'name': 'CHAS', 'type': 'long', 'nullable': False},
#       {'name': 'NOX', 'type': 'double', 'nullable': False},
#       {'name': 'RM', 'type': 'double', 'nullable': False},
#       {'name': 'AGE', 'type': 'double', 'nullable': False},
#       {'name': 'DIS', 'type': 'double', 'nullable': False},
#       {'name': 'RAD', 'type': 'long', 'nullable': False},
#       {'name': 'TAX', 'type': 'double', 'nullable': False},
#       {'name': 'PTRATIO', 'type': 'double', 'nullable': False},
#       {'name': 'Bk', 'type': 'double', 'nullable': False},
#       {'name': 'LSTAT', 'type': 'double', 'nullable': False},
#       {'name': 'MEDV', 'type': 'double', 'nullable': False},
#       {'name': '$R-MEDV', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'ai_drug_mlp_proba',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_drug_mlp_proba/score'},
#   'entity': {'name': 'ai_drug_mlp_proba',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_drug_mlp_proba/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110a105',
#     'url': '/aiopenscale/Drug1n_proba.str',
#     'name': 'ai_drug_mlp_proba'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'scoreInput',
#      'id': 'id1JRRSIWAHWX',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False},
#       {'name': '$N-Drug', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Drug', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugA', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugB', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugC', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugX', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugY', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'SPSS-テスト-ai-drug-mlp-proba-BiasQA',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/SPSS-テスト-ai-drug-mlp-proba-BiasQA/score'},
#   'entity': {'name': 'SPSS-テスト-ai-drug-mlp-proba-BiasQA',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/SPSS-テスト-ai-drug-mlp-proba-BiasQA/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110a105',
#     'url': '/aiopenscale/Drug1n_proba.str',
#     'name': 'SPSS-テスト-ai-drug-mlp-proba-BiasQA'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'scoreInput',
#      'id': 'id1JRRSIWAHWX',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'BP', 'type': 'string', 'nullable': False},
#       {'name': 'Cholesterol', 'type': 'string', 'nullable': False},
#       {'name': 'Na', 'type': 'double', 'nullable': False},
#       {'name': 'K', 'type': 'double', 'nullable': False},
#       {'name': '$N-Drug', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Drug', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugA', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugB', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugC', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugX', 'type': 'double', 'nullable': False},
#       {'name': '$NP-drugY', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'boston_house_prices_tutorial_BiasQA',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/boston_house_prices_tutorial_BiasQA/score'},
#   'entity': {'name': 'boston_house_prices_tutorial_BiasQA',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/boston_house_prices_tutorial_BiasQA/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c71102cb4',
#     'url': '/house_prices/boston_house_prices_tutorial.str',
#     'name': 'boston_house_prices_tutorial_BiasQA'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'housing_data_scoring.csv',
#      'id': 'id61BUEWF8PLL',
#      'fields': [{'name': 'CRIM', 'type': 'double', 'nullable': False},
#       {'name': 'ZN', 'type': 'double', 'nullable': False},
#       {'name': 'INDUS', 'type': 'double', 'nullable': False},
#       {'name': 'CHAS', 'type': 'long', 'nullable': False},
#       {'name': 'NOX', 'type': 'double', 'nullable': False},
#       {'name': 'RM', 'type': 'double', 'nullable': False},
#       {'name': 'AGE', 'type': 'double', 'nullable': False},
#       {'name': 'DIS', 'type': 'double', 'nullable': False},
#       {'name': 'RAD', 'type': 'long', 'nullable': False},
#       {'name': 'TAX', 'type': 'double', 'nullable': False},
#       {'name': 'PTRATIO', 'type': 'double', 'nullable': False},
#       {'name': 'Bk', 'type': 'double', 'nullable': False},
#       {'name': 'LSTAT', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CRIM', 'type': 'double', 'nullable': False},
#       {'name': 'ZN', 'type': 'double', 'nullable': False},
#       {'name': 'INDUS', 'type': 'double', 'nullable': False},
#       {'name': 'CHAS', 'type': 'long', 'nullable': False},
#       {'name': 'NOX', 'type': 'double', 'nullable': False},
#       {'name': 'RM', 'type': 'double', 'nullable': False},
#       {'name': 'AGE', 'type': 'double', 'nullable': False},
#       {'name': 'DIS', 'type': 'double', 'nullable': False},
#       {'name': 'RAD', 'type': 'long', 'nullable': False},
#       {'name': 'TAX', 'type': 'double', 'nullable': False},
#       {'name': 'PTRATIO', 'type': 'double', 'nullable': False},
#       {'name': 'Bk', 'type': 'double', 'nullable': False},
#       {'name': 'LSTAT', 'type': 'double', 'nullable': False},
#       {'name': '$R-MEDV', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'ai_credit_risk_mlogistic',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_credit_risk_mlogistic/score'},
#   'entity': {'name': 'ai_credit_risk_mlogistic',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/ai_credit_risk_mlogistic/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110990e',
#     'url': '/aiopenscale/credit_risk_mlogistic.str',
#     'name': 'ai_credit_risk_mlogistic'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'credit_risk_training.csv',
#      'id': 'id17STY5BAZ1Y',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': 'Risk', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': 'Risk', 'type': 'string', 'nullable': False},
#       {'name': '$L-Risk', 'type': 'string', 'nullable': False},
#       {'name': '$LP-Risk', 'type': 'double', 'nullable': False},
#       {'name': '$LRP-Risk', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'credit_risk_btree',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/credit_risk_btree/score'},
#   'entity': {'name': 'credit_risk_btree',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/credit_risk_btree/score'},
#    'asset': {'asset_id': '091edbc5c4e74be500000167bc5c18e0703a',
#     'url': '/Test/credit_risk_btree.str',
#     'name': 'credit_risk_btree'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'credit_risk_training.csv',
#      'id': 'id17STY5BAZ1Y',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': 'Risk', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
# ...
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': 'Risk', 'type': 'string', 'nullable': False},
#       {'name': '$L-Risk', 'type': 'string', 'nullable': False},
#       {'name': '$LP-Risk', 'type': 'double', 'nullable': False},
#       {'name': '$LRP-Risk', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'NewTelcoChurnScore',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/NewTelcoChurnScore/score'},
#   'entity': {'name': 'NewTelcoChurnScore',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/NewTelcoChurnScore/score'},
#    'asset': {'asset_id': '091e7b2df8a364c300000169e4e5bfd4754f',
#     'url': '/DEMO/NewTelcoChurnWithMiscalcSplits4BoostingAndMatrix (2).str',
#     'name': 'NewTelcoChurnScore'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'telcoanonchurnnomissing_score.csv',
#      'id': 'id4VMTTHSIKR6',
#      'fields': [{'name': 'MID', 'type': 'long', 'nullable': False},
#       {'name': 'CALL_CENTRE_CALLS', 'type': 'long', 'nullable': False},
#       {'name': 'MFTR', 'type': 'string', 'nullable': False},
#       {'name': 'EXTERNAL_CONGESTION_ERRORS',
#        'type': 'long',
#        'nullable': False},
#       {'name': 'NORMAL_CALLS', 'type': 'long', 'nullable': False},
#       {'name': 'SUBSCRIBER_ERRORS', 'type': 'long', 'nullable': False},
#       {'name': 'QOS_GROUP', 'type': 'string', 'nullable': False},
#       {'name': 'USAGE_DIRECTION', 'type': 'double', 'nullable': False},
#       {'name': 'EVENT_TYPE_DATA_USAGE_DIRECTION',
#        'type': 'double',
#        'nullable': False},
#       {'name': 'EVENT_TYPE_INCOMING_USAGE_DIRECT',
#        'type': 'double',
#        'nullable': False},
#       {'name': 'EVENT_TYPE_OUTGOING_USAGE_DIRECT',
#        'type': 'double',
#        'nullable': False},
#       {'name': 'EVENT_TYPE_SMS_USAGE_DIRECTION',
#        'type': 'double',
#        'nullable': False},
#       {'name': 'OUTGOING_OVERALL', 'type': 'double', 'nullable': False},
#       {'name': 'INCOMING_OVERALL', 'type': 'double', 'nullable': False},
#       {'name': 'SMS_OVERALL', 'type': 'double', 'nullable': False},
#       {'name': 'DATA_OVERALL', 'type': 'double', 'nullable': False},
#       {'name': 'USAGE_LIFESTYLE', 'type': 'string', 'nullable': False},
#       {'name': 'LIFESTYLE', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'MSISDN', 'type': 'long', 'nullable': False},
#       {'name': 'Churn Predicted', 'type': 'string', 'nullable': False},
#       {'name': 'Churn Propensity', 'type': 'double', 'nullable': False},
#       {'name': 'Usage Lifestyle', 'type': 'string', 'nullable': False},
#       {'name': 'Mobility Lifestyle', 'type': 'string', 'nullable': False},
#       {'name': 'Churn Group', 'type': 'long', 'nullable': False},
#       {'name': 'Complete Rule', 'type': 'string', 'nullable': False},
#       {'name': 'Rule Number', 'type': 'string', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'boston_house_prices_tutorial',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/boston_house_prices_tutorial/score'},
#   'entity': {'name': 'boston_house_prices_tutorial',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/boston_house_prices_tutorial/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c71102cb4',
#     'url': '/house_prices/boston_house_prices_tutorial.str',
#     'name': 'boston_house_prices_tutorial'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'housing_data_scoring.csv',
#      'id': 'id61BUEWF8PLL',
#      'fields': [{'name': 'CRIM', 'type': 'double', 'nullable': False},
#       {'name': 'ZN', 'type': 'double', 'nullable': False},
#       {'name': 'INDUS', 'type': 'double', 'nullable': False},
#       {'name': 'CHAS', 'type': 'long', 'nullable': False},
#       {'name': 'NOX', 'type': 'double', 'nullable': False},
#       {'name': 'RM', 'type': 'double', 'nullable': False},
#       {'name': 'AGE', 'type': 'double', 'nullable': False},
#       {'name': 'DIS', 'type': 'double', 'nullable': False},
#       {'name': 'RAD', 'type': 'long', 'nullable': False},
#       {'name': 'TAX', 'type': 'double', 'nullable': False},
#       {'name': 'PTRATIO', 'type': 'double', 'nullable': False},
#       {'name': 'Bk', 'type': 'double', 'nullable': False},
#       {'name': 'LSTAT', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CRIM', 'type': 'double', 'nullable': False},
#       {'name': 'ZN', 'type': 'double', 'nullable': False},
#       {'name': 'INDUS', 'type': 'double', 'nullable': False},
#       {'name': 'CHAS', 'type': 'long', 'nullable': False},
#       {'name': 'NOX', 'type': 'double', 'nullable': False},
#       {'name': 'RM', 'type': 'double', 'nullable': False},
#       {'name': 'AGE', 'type': 'double', 'nullable': False},
#       {'name': 'DIS', 'type': 'double', 'nullable': False},
#       {'name': 'RAD', 'type': 'long', 'nullable': False},
#       {'name': 'TAX', 'type': 'double', 'nullable': False},
#       {'name': 'PTRATIO', 'type': 'double', 'nullable': False},
#       {'name': 'Bk', 'type': 'double', 'nullable': False},
#       {'name': 'LSTAT', 'type': 'double', 'nullable': False},
#       {'name': '$R-MEDV', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'toy_random_tree_regression',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/toy_random_tree_regression/score'},
#   'entity': {'name': 'toy_random_tree_regression',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/toy_random_tree_regression/score'},
#    'asset': {'asset_id': '091edbc5c4e74be500000168f14b3eb16500',
#     'url': '/toy/regression/random_tree.str',
#     'name': 'toy_random_tree_regression'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'score_data.csv',
#      'id': 'id33TTKRFV72H',
#      'fields': [{'name': 'X1', 'type': 'double', 'nullable': False},
#       {'name': 'X2', 'type': 'double', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'X1', 'type': 'double', 'nullable': False},
#       {'name': 'X2', 'type': 'double', 'nullable': False},
#       {'name': '$R-y', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'german_credit_risk_tutorial_BiasQA',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/german_credit_risk_tutorial_BiasQA/score'},
#   'entity': {'name': 'german_credit_risk_tutorial_BiasQA',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/german_credit_risk_tutorial_BiasQA/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110cafe',
#     'url': '/credit_risk/german_credit_risk_tutorial.str',
#     'name': 'german_credit_risk_tutorial_BiasQA'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'credit_risk_scoring.csv',
#      'id': 'id4QCUV9G15M2',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': '$N-Risk', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Risk', 'type': 'double', 'nullable': False},
#       {'name': '$NP-No Risk', 'type': 'double', 'nullable': False},
#       {'name': '$NP-Risk', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}},
#  {'metadata': {'guid': 'German-credit-risk-tutorial-BiasQA',
#    'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/German-credit-risk-tutorial-BiasQA/score'},
#   'entity': {'name': 'German-credit-risk-tutorial-BiasQA',
#    'type': 'online',
#    'scoring_endpoint': {'url': 'http://dismiss1.fyre.ibm.com:9080/scoring/rest/configuration/German-credit-risk-tutorial-BiasQA/score'},
#    'asset': {'asset_id': '091edbc5c4e74be5000001686a7c7110cafe',
#     'url': '/credit_risk/german_credit_risk_tutorial.str',
#     'name': 'German-credit-risk-tutorial-BiasQA'},
#    'asset_properties': {'input_data_schema': {'type': 'struct',
#      'name': 'credit_risk_scoring.csv',
#      'id': 'id4QCUV9G15M2',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False}]},
#     'output_data_schema': {'type': 'struct',
#      'fields': [{'name': 'CheckingStatus',
#        'type': 'string',
#        'nullable': False},
#       {'name': 'LoanDuration', 'type': 'long', 'nullable': False},
#       {'name': 'CreditHistory', 'type': 'string', 'nullable': False},
#       {'name': 'LoanPurpose', 'type': 'string', 'nullable': False},
#       {'name': 'LoanAmount', 'type': 'long', 'nullable': False},
#       {'name': 'ExistingSavings', 'type': 'string', 'nullable': False},
#       {'name': 'EmploymentDuration', 'type': 'string', 'nullable': False},
#       {'name': 'InstallmentPercent', 'type': 'long', 'nullable': False},
#       {'name': 'Sex', 'type': 'string', 'nullable': False},
#       {'name': 'OthersOnLoan', 'type': 'string', 'nullable': False},
#       {'name': 'CurrentResidenceDuration', 'type': 'long', 'nullable': False},
#       {'name': 'OwnsProperty', 'type': 'string', 'nullable': False},
#       {'name': 'Age', 'type': 'long', 'nullable': False},
#       {'name': 'InstallmentPlans', 'type': 'string', 'nullable': False},
#       {'name': 'Housing', 'type': 'string', 'nullable': False},
#       {'name': 'ExistingCreditsCount', 'type': 'long', 'nullable': False},
#       {'name': 'Job', 'type': 'string', 'nullable': False},
#       {'name': 'Dependents', 'type': 'long', 'nullable': False},
#       {'name': 'Telephone', 'type': 'string', 'nullable': False},
#       {'name': 'ForeignWorker', 'type': 'string', 'nullable': False},
#       {'name': '$N-Risk', 'type': 'string', 'nullable': False},
#       {'name': '$NC-Risk', 'type': 'double', 'nullable': False},
#       {'name': '$NP-No Risk', 'type': 'double', 'nullable': False},
#       {'name': '$NP-Risk', 'type': 'double', 'nullable': False},
#       {'name': 'ProbabilityVector',
#        'type': {'type': 'array',
#         'elementType': 'double',
#         'containsNull': True},
#        'nullable': True,
#        'metadata': {'modeling_role': 'probability'}}]}}}}]

# %%
MODEL_NAME='german_credit_risk_tutorial_BiasQA' # use the model name here 
model_asset_details_from_deployment = [asset for asset in asset_deployment_details if asset['entity']["name"]==MODEL_NAME]
source_uid = [asset['entity']['asset']['asset_id'] for asset in asset_deployment_details if asset['entity']["name"]==MODEL_NAME]
if len(model_asset_details_from_deployment)>0:
    [model_asset_details_from_deployment] = model_asset_details_from_deployment
    [source_uid] = source_uid
else:
    raise ValueError('Model with name "{}" not found.'.format(MODEL_NAME))

# %% [markdown]
# <a id="subsciption"></a>
# ## Subscriptions

# %% [markdown]
# ### Add subscriptions

# %% [markdown]
# List available deployments.
#
# **Note:** Depending on number of assets it may take some time.

# %%
wos_client.subscriptions.show()
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <HTML>
#         <body>
#             <h3>Subscriptions</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>asset_id</th><th style='border: 1px solid #dddddd'>asset_name</th><th style='border: 1px solid #dddddd'>data_mart_id</th><th style='border: 1px solid #dddddd'>deployment_id</th><th style='border: 1px solid #dddddd'>deployment_name</th><th style='border: 1px solid #dddddd'>service_provider_id</th><th style='border: 1px solid #dddddd'>status</th><th style='border: 1px solid #dddddd'>created_at</th><th style='border: 1px solid #dddddd'>id</th>
#                 <tr><td style='border: 1px solid #dddddd'>091edbc5c4e74be5000001686a7c7110cafe</td><td style='border: 1px solid #dddddd'>german_credit_risk_tutorial_BiasQA</td><td style='border: 1px solid #dddddd'>00000000-0000-0000-0000-1604128772718153</td><td style='border: 1px solid #dddddd'>german_credit_risk_tutorial_BiasQA</td><td style='border: 1px solid #dddddd'>german_credit_risk_tutorial_BiasQA</td><td style='border: 1px solid #dddddd'>b45a656e-38fc-4a61-87ad-28025a2032b0</td><td style='border: 1px solid #dddddd'>active</td><td style='border: 1px solid #dddddd'>2020-11-01 00:59:15.557000+00:00</td><td style='border: 1px solid #dddddd'>05411c64-167c-4eba-b1f4-9934222ec9f0</td></tr>
#             </table>
#         </body>
#         </HTML>

# %%
subscriptions = wos_client.subscriptions.list().result.subscriptions
for subscription in subscriptions:
    sub_model_id = subscription.entity.asset.asset_id
    if sub_model_id == source_uid:
        wos_client.subscriptions.delete(subscription.metadata.id)
        print('Deleted existing subscription for model', sub_model_id)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
training_data_reference= TrainingDataReference(type='cos',
                                                          location=COSTrainingDataReferenceLocation(bucket = BUCKET_NAME,
                                                                                                    file_name = training_data_file_name),
                                                          connection=COSTrainingDataReferenceConnection.from_dict({
                                                                        "resource_instance_id": COS_RESOURCE_CRN,
                                                                        "url": COS_ENDPOINT,
                                                                        "api_key": COS_API_KEY_ID,
                                                                        "iam_url": IAM_URL}))

# %%
subscription_details = wos_client.subscriptions.add(
        data_mart_id=data_mart_id,
        service_provider_id=service_provider_id,
        asset=Asset(
            asset_id=model_asset_details_from_deployment["entity"]["asset"]["asset_id"],
            name=model_asset_details_from_deployment["entity"]["asset"]["name"],
            url=model_asset_details_from_deployment["entity"]["asset"]["url"],
            asset_type=AssetTypes.MODEL,
            input_data_type=InputDataType.STRUCTURED,
            problem_type=ProblemType.BINARY_CLASSIFICATION
        ),
        deployment=AssetDeploymentRequest(
            deployment_id=model_asset_details_from_deployment['metadata']['guid'],
            name=model_asset_details_from_deployment['entity']['name'],
            deployment_type= DeploymentTypes.ONLINE,
            url=model_asset_details_from_deployment['entity']['scoring_endpoint']['url']
        ),
        asset_properties=AssetPropertiesRequest(
            label_column='Risk',
            probability_fields=['$NP-No Risk','$NP-Risk'],
            prediction_field='$N-Risk',
            feature_fields = ["CheckingStatus","LoanDuration","CreditHistory","LoanPurpose","LoanAmount","ExistingSavings","EmploymentDuration","InstallmentPercent","Sex","OthersOnLoan","CurrentResidenceDuration","OwnsProperty","Age","InstallmentPlans","Housing","ExistingCreditsCount","Job","Dependents","Telephone","ForeignWorker"],
            categorical_fields = ["CheckingStatus","CreditHistory","LoanPurpose","ExistingSavings","EmploymentDuration","Sex","OthersOnLoan","OwnsProperty","InstallmentPlans","Housing","Job","Telephone","ForeignWorker"],
            training_data_reference=training_data_reference,
            input_data_schema=SparkStruct.from_dict(model_asset_details_from_deployment["entity"]["asset_properties"]["input_data_schema"]),
            output_data_schema=SparkStruct.from_dict(model_asset_details_from_deployment["entity"]["asset_properties"]["output_data_schema"])

        )
    ).result
subscription_id = subscription_details.metadata.id
subscription_id
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# '69e435b9-b62f-4c81-8cf4-fafd17e19476'

# %% [markdown]
# ## Performance monitor, scoring and payload logging

# %% [markdown]
# ### Score the credit risk model and measure response time

# %%
import requests
from requests.auth import HTTPBasicAuth
import time
import json

scoring_endpoint = subscription_details.to_dict()['entity']['deployment']['url']
input_table_id = subscription_details.to_dict()['entity']['asset_properties']['input_data_schema']['id']
node_id = subscription_details.to_dict()['entity']['asset']['name']

scoring_payload = {'requestInputTable': [{'id': input_table_id, 'requestInputRow': [{'input': [
            {'name': 'CheckingStatus', 'value': '0_to_200'}, {'name': 'LoanDuration', 'value': 31},
            {'name': 'CreditHistory', 'value': 'credits_paid_to_date'}, {'name': 'LoanPurpose', 'value': 'other'},
            {'name': 'LoanAmount', 'value': 1889}, {'name': 'ExistingSavings', 'value': '100_to_500'},
            {'name': 'EmploymentDuration', 'value': 'less_1'}, {'name': 'InstallmentPercent', 'value': 3},
            {'name': 'Sex', 'value': 'female'}, {'name': 'OthersOnLoan', 'value': 'none'},
            {'name': 'CurrentResidenceDuration', 'value': 3}, {'name': 'OwnsProperty', 'value': 'savings_insurance'},
            {'name': 'Age', 'value': 32}, {'name': 'InstallmentPlans', 'value': 'none'},
            {'name': 'Housing', 'value': 'own'}, {'name': 'ExistingCreditsCount', 'value': 1},
            {'name': 'Job', 'value': 'skilled'}, {'name': 'Dependents', 'value': 1},
            {'name': 'Telephone', 'value': 'none'}, {'name': 'ForeignWorker', 'value': 'yes'}]}]}], 'id': node_id}

start_time = time.time()
resp_score = requests.post(url=scoring_endpoint, json=scoring_payload, auth=HTTPBasicAuth(username=SPSS_CDS_ENGINE_CREDENTIALS['username'], password=SPSS_CDS_ENGINE_CREDENTIALS['password']))

response_time = int((time.time() - start_time)*1000)
result = resp_score.json()

print(result)
# Out:
# {'providedBy': 'german_credit_risk_tutorial_BiasQA', 'id': 'c9d4ba4c-91da-4fa2-bacf-4575ff0a5af6', 'columnNames': {'name': ['CheckingStatus', 'LoanDuration', 'CreditHistory', 'LoanPurpose', 'LoanAmount', 'ExistingSavings', 'EmploymentDuration', 'InstallmentPercent', 'Sex', 'OthersOnLoan', 'CurrentResidenceDuration', 'OwnsProperty', 'Age', 'InstallmentPlans', 'Housing', 'ExistingCreditsCount', 'Job', 'Dependents', 'Telephone', 'ForeignWorker', '$N-Risk', '$NC-Risk', '$NP-No Risk', '$NP-Risk']}, 'rowValues': [{'value': [{'value': '0_to_200'}, {'value': '31'}, {'value': 'credits_paid_to_date'}, {'value': 'other'}, {'value': '1889'}, {'value': '100_to_500'}, {'value': 'less_1'}, {'value': '3'}, {'value': 'female'}, {'value': 'none'}, {'value': '3'}, {'value': 'savings_insurance'}, {'value': '32'}, {'value': 'none'}, {'value': 'own'}, {'value': '1'}, {'value': 'skilled'}, {'value': '1'}, {'value': 'none'}, {'value': 'yes'}, {'value': 'No Risk'}, {'value': '0.8252855725848809'}, {'value': '0.8252855725848809'}, {'value': '0.17471442741511914'}]}]}

# %% [markdown]
# ### Store the request and response in payload logging table

# %% [markdown]
# #### Store the payload using Python SDK

# %% [markdown]
# **Hint:** You can embed payload logging code into your application so it is logged automatically each time you score the model.

# %%
import time

time.sleep(5)
payload_data_set_id = None
payload_data_set_id = wos_client.data_sets.list(type=DataSetTypes.PAYLOAD_LOGGING, 
                                                target_target_id=subscription_id, 
                                                target_target_type=TargetTypes.SUBSCRIPTION).result.data_sets[0].metadata.id
if payload_data_set_id is None:
    print("Payload data set not found. Please check subscription status.")
else:
    print("Payload data set id: ", payload_data_set_id)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Payload data set id:  4af55405-0d25-4d7c-95fe-bf9fb824dd0e

# %%
import pandas as pd
df_data = pd.read_csv("https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/data/credit_risk_spss/payload_credit_risk.csv")
df_data=df_data.drop(['Risk'],axis=1)

# %%
#score using couple sample records
payload=df_data.sample(2)

# %%
values = payload.values.tolist()
columns = payload.columns.tolist()

# %%
records_list=[]
for i in payload.to_dict('records'):
    b=[{"name":x,"value":v} for x,v in i.items()]
    records_list.append({'input': b})

# %%
scoring_payload = {'requestInputTable': [{'id': input_table_id, 'requestInputRow': records_list}], 'id': node_id}

# %%
resp_score = requests.post(url=scoring_endpoint, json=scoring_payload, auth=HTTPBasicAuth(username=SPSS_CDS_ENGINE_CREDENTIALS['username'], password=SPSS_CDS_ENGINE_CREDENTIALS['password']))

response_time = int((time.time() - start_time)*1000)
result = resp_score.json()
print(result)
# Out:
# {'providedBy': 'german_credit_risk_tutorial_BiasQA', 'id': '4a05154c-9ff4-43eb-b8ce-9d6fbbb87137', 'columnNames': {'name': ['CheckingStatus', 'LoanDuration', 'CreditHistory', 'LoanPurpose', 'LoanAmount', 'ExistingSavings', 'EmploymentDuration', 'InstallmentPercent', 'Sex', 'OthersOnLoan', 'CurrentResidenceDuration', 'OwnsProperty', 'Age', 'InstallmentPlans', 'Housing', 'ExistingCreditsCount', 'Job', 'Dependents', 'Telephone', 'ForeignWorker', '$N-Risk', '$NC-Risk', '$NP-No Risk', '$NP-Risk']}, 'rowValues': [{'value': [{'value': '0_to_200'}, {'value': '13'}, {'value': 'prior_payments_delayed'}, {'value': 'repairs'}, {'value': '1889'}, {'value': 'greater_1000'}, {'value': '4_to_7'}, {'value': '2'}, {'value': 'male'}, {'value': 'none'}, {'value': '2'}, {'value': 'savings_insurance'}, {'value': '34'}, {'value': 'stores'}, {'value': 'own'}, {'value': '1'}, {'value': 'skilled'}, {'value': '2'}, {'value': 'none'}, {'value': 'yes'}, {'value': 'No Risk'}, {'value': '0.7983974913362735'}, {'value': '0.7983974913362735'}, {'value': '0.20160250866372653'}]}, {'value': [{'value': 'greater_200'}, {'value': '4'}, {'value': 'credits_paid_to_date'}, {'value': 'other'}, {'value': '3109'}, {'value': 'greater_1000'}, {'value': 'less_1'}, {'value': '4'}, {'value': 'female'}, {'value': 'none'}, {'value': '3'}, {'value': 'real_estate'}, {'value': '59'}, {'value': 'none'}, {'value': 'free'}, {'value': '1'}, {'value': 'management_self-employed'}, {'value': '1'}, {'value': 'none'}, {'value': 'yes'}, {'value': 'No Risk'}, {'value': '0.8873499973689839'}, {'value': '0.8873499973689839'}, {'value': '0.11265000263101611'}]}]}

# %% [markdown]
# ### Format scoring response for payload logging

# %%
res_values=[]
for i in result['rowValues']:
    d= [j for j in i['value']]
    res_values.append([k['value'] for k in d])

# %%
dtype_idx=[1,4,7,10,12,15,17] # change numeric features values in scoring response from String to Integer
dtype_predictions_idx=[21,22,23] # change prediction, probability column values in scoring response from String to Float

for val in res_values:
    for idx in dtype_idx:
        val[idx]=int(val[idx])
    for idx in dtype_predictions_idx:
        val[idx]=float(val[idx])
# Out:
# [['0_to_200',
#   13,
#   'prior_payments_delayed',
#   'repairs',
#   1889,
#   'greater_1000',
#   '4_to_7',
#   2,
#   'male',
#   'none',
#   2,
#   'savings_insurance',
#   34,
#   'stores',
#   'own',
#   1,
#   'skilled',
#   2,
#   'none',
#   'yes',
#   'No Risk',
#   0.7983974913362735,
#   0.7983974913362735,
#   0.20160250866372653],
#  ['greater_200',
#   4,
#   'credits_paid_to_date',
#   'other',
#   3109,
#   'greater_1000',
#   'less_1',
#   4,
#   'female',
#   'none',
#   3,
#   'real_estate',
#   59,
#   'none',
#   'free',
#   1,
#   'management_self-employed',
#   1,
#   'none',
#   'yes',
#   'No Risk',
#   0.8873499973689839,
#   0.8873499973689839,
#   0.11265000263101611]]

# %%
request = {
            "fields": payload.columns.tolist(),
            "values": payload.values.tolist()
        }
response = {
            "fields": result['columnNames']['name'],
            "values": res_values
        }

# %%
import uuid
from ibm_watson_openscale.supporting_classes.payload_record import PayloadRecord
time.sleep(5)
wos_client.data_sets.store_records(data_set_id=payload_data_set_id, request_body=[PayloadRecord(
               scoring_id=str(uuid.uuid4()),
               request=request,
               response=response,
               response_time=460
           )])
time.sleep(5)
pl_records_count = wos_client.data_sets.get_records_count(payload_data_set_id)
print("Number of records in the payload logging table: {}".format(pl_records_count))
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Number of records in the payload logging table: 4

# %%
wos_client.data_sets.show_records(payload_data_set_id)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <HTML>
#         <body>
#             <h3>Data Set 4af55405-0d25-4d7c-95fe-bf9fb824dd0e Records</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>asset_revision</th><th style='border: 1px solid #dddddd'>LoanAmount</th><th style='border: 1px solid #dddddd'>scoring_id</th><th style='border: 1px solid #dddddd'>InstallmentPercent</th><th style='border: 1px solid #dddddd'>ExistingSavings</th><th style='border: 1px solid #dddddd'>scoring_timestamp</th><th style='border: 1px solid #dddddd'>prediction_probability</th><th style='border: 1px solid #dddddd'>ProbabilityVector</th><th style='border: 1px solid #dddddd'>CheckingStatus</th><th style='border: 1px solid #dddddd'>LoanPurpose</th><th style='border: 1px solid #dddddd'>Job</th><th style='border: 1px solid #dddddd'>$NP-Risk</th><th style='border: 1px solid #dddddd'>InstallmentPlans</th><th style='border: 1px solid #dddddd'>OthersOnLoan</th><th style='border: 1px solid #dddddd'>$NC-Risk</th><th style='border: 1px solid #dddddd'>$NP-No Risk</th><th style='border: 1px solid #dddddd'>LoanDuration</th><th style='border: 1px solid #dddddd'>Age</th><th style='border: 1px solid #dddddd'>CreditHistory</th><th style='border: 1px solid #dddddd'>CurrentResidenceDuration</th><th style='border: 1px solid #dddddd'>ForeignWorker</th><th style='border: 1px solid #dddddd'>Housing</th><th style='border: 1px solid #dddddd'>$N-Risk</th><th style='border: 1px solid #dddddd'>ExistingCreditsCount</th><th style='border: 1px solid #dddddd'>deployment_id</th><th style='border: 1px solid #dddddd'>Telephone</th><th style='border: 1px solid #dddddd'>Sex</th><th style='border: 1px solid #dddddd'>Dependents</th><th style='border: 1px solid #dddddd'>OwnsProperty</th><th style='border: 1px solid #dddddd'>EmploymentDuration</th>
#                 <tr><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>1889</td><td style='border: 1px solid #dddddd'>270a514d-d428-41e5-a862-ccf570d58602-1</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>greater_1000</td><td style='border: 1px solid #dddddd'>2020-11-01T01:19:33.326Z</td><td style='border: 1px solid #dddddd'>0.7983974913362735</td><td style='border: 1px solid #dddddd'>[0.7983974913362735, 0.20160250866372653]</td><td style='border: 1px solid #dddddd'>0_to_200</td><td style='border: 1px solid #dddddd'>repairs</td><td style='border: 1px solid #dddddd'>skilled</td><td style='border: 1px solid #dddddd'>0.20160250866372653</td><td style='border: 1px solid #dddddd'>stores</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>0.7983974913362735</td><td style='border: 1px solid #dddddd'>0.7983974913362735</td><td style='border: 1px solid #dddddd'>13</td><td style='border: 1px solid #dddddd'>34</td><td style='border: 1px solid #dddddd'>prior_payments_delayed</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>yes</td><td style='border: 1px solid #dddddd'>own</td><td style='border: 1px solid #dddddd'>No Risk</td><td style='border: 1px solid #dddddd'>1</td><td style='border: 1px solid #dddddd'>german_credit_risk_tutorial_BiasQA</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>male</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>savings_insurance</td><td style='border: 1px solid #dddddd'>4_to_7</td></tr><tr><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>3109</td><td style='border: 1px solid #dddddd'>270a514d-d428-41e5-a862-ccf570d58602-2</td><td style='border: 1px solid #dddddd'>4</td><td style='border: 1px solid #dddddd'>greater_1000</td><td style='border: 1px solid #dddddd'>2020-11-01T01:19:33.326Z</td><td style='border: 1px solid #dddddd'>0.8873499973689839</td><td style='border: 1px solid #dddddd'>[0.8873499973689839, 0.11265000263101611]</td><td style='border: 1px solid #dddddd'>greater_200</td><td style='border: 1px solid #dddddd'>other</td><td style='border: 1px solid #dddddd'>management_self-employed</td><td style='border: 1px solid #dddddd'>0.11265000263101611</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>0.8873499973689839</td><td style='border: 1px solid #dddddd'>0.8873499973689839</td><td style='border: 1px solid #dddddd'>4</td><td style='border: 1px solid #dddddd'>59</td><td style='border: 1px solid #dddddd'>credits_paid_to_date</td><td style='border: 1px solid #dddddd'>3</td><td style='border: 1px solid #dddddd'>yes</td><td style='border: 1px solid #dddddd'>free</td><td style='border: 1px solid #dddddd'>No Risk</td><td style='border: 1px solid #dddddd'>1</td><td style='border: 1px solid #dddddd'>german_credit_risk_tutorial_BiasQA</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>female</td><td style='border: 1px solid #dddddd'>1</td><td style='border: 1px solid #dddddd'>real_estate</td><td style='border: 1px solid #dddddd'>less_1</td></tr><tr><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>1889</td><td style='border: 1px solid #dddddd'>06f651d2-96a8-43ac-a0b7-26fc86253c99-1</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>greater_1000</td><td style='border: 1px solid #dddddd'>2020-11-01T01:19:14.361Z</td><td style='border: 1px solid #dddddd'>0.7983974913362735</td><td style='border: 1px solid #dddddd'>[0.7983974913362735, 0.20160250866372653]</td><td style='border: 1px solid #dddddd'>0_to_200</td><td style='border: 1px solid #dddddd'>repairs</td><td style='border: 1px solid #dddddd'>skilled</td><td style='border: 1px solid #dddddd'>0.20160250866372653</td>< ...

# %% [markdown]
# ## Quality monitor and feedback logging

# %% [markdown]
# ### Enable quality monitoring

# %%
import time

time.sleep(10)
target = Target(
        target_type=TargetTypes.SUBSCRIPTION,
        target_id=subscription_id
)
parameters = {
    "min_feedback_data_size": 50
}
thresholds = [
                {
                    "metric_id": "area_under_roc",
                    "type": "lower_limit",
                    "value": .80
                }
            ]
quality_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.QUALITY.ID,
    target=target,
    parameters=parameters,
    thresholds=thresholds
).result
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ===================================================================================
#
#  Waiting for end of monitor instance creation 87163786-2bc5-4e6b-a6b4-1019840ff6e7
#
# ===================================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# active
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------

# %%
quality_monitor_instance_id = quality_monitor_details.metadata.id
quality_monitor_instance_id
# Out:
# '87163786-2bc5-4e6b-a6b4-1019840ff6e7'

# %% [markdown]
# ### Feedback records logging

# %% [markdown]
# Feedback records are used to evaluate your model. The predicted values are compared to real values (feedback records).

# %%
feedback_dataset_id = None
feedback_dataset = wos_client.data_sets.list(type=DataSetTypes.FEEDBACK, 
                                                target_target_id=subscription_id, 
                                                target_target_type=TargetTypes.SUBSCRIPTION).result
#print(feedback_dataset)
feedback_dataset_id = feedback_dataset.data_sets[0].metadata.id
if feedback_dataset_id is None:
    print("Feedback data set not found. Please check quality monitor status.")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# #### Store feedback using CSV format from file

# %%
#!wget https://raw.githubusercontent.com/pmservice/wml-sample-models/master/spss/credit-risk/data/credit_risk_feedback.csv
feed_data_load = pd.read_csv('https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/data/credit_risk_spss/feedback_credit_risk.csv')
feedback_data = json.loads(feed_data_load.to_json(orient='records'))
feedback_data
# Out:
# [{'CheckingStatus': 'no_checking',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 4066,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 56,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 20,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 1481,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 58,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3985,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 35,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 19,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2338,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 45,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2478,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 10,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 4496,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 22,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 32,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2732,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 4655,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 23,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 3117,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 34,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1676,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 43,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 37,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2740,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 15,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'education',
#   'LoanAmount': 4190,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 4,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'unknown',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 36,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1388,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 33,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2661,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 21,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 1257,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 55,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 22,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 1735,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 32,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3129,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 46,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2460,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 36,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 2067,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 34,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 4763,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 57,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'no_checking',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 4066,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 56,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 20,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 1481,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 58,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3985,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 35,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 19,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2338,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 45,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2478,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 10,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 4496,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 22,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 32,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2732,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 4655,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 23,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 3117,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 34,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1676,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 43,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 37,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2740,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 15,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'education',
#   'LoanAmount': 4190,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 4,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'unknown',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 36,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1388,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 33,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2661,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 21,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 1257,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 55,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 22,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 1735,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 32,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3129,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 46,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2460,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 36,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 2067,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 34,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 4763,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 57,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'no_checking',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 4066,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 56,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 20,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 1481,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 58,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3985,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 35,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 19,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2338,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 45,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2478,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 10,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 4496,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 22,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 32,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2732,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 4655,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 23,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 3117,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 34,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1676,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 43,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 37,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2740,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 15,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'education',
#   'LoanAmount': 4190,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 4,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'unknown',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 36,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1388,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 33,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2661,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 21,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 1257,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 55,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 22,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 1735,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 32,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3129,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 46,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2460,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 36,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 2067,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 34,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 4763,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 57,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'no_checking',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 4066,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 56,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 20,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 1481,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 58,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3985,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 35,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 19,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2338,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 45,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2478,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 10,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 4496,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 22,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 32,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2732,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 4655,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 23,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 3117,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 34,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1676,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 43,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 37,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2740,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 15,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'education',
#   'LoanAmount': 4190,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 4,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'unknown',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 36,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1388,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 33,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2661,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 21,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 1257,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 55,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 22,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 1735,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 32,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3129,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 46,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2460,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 36,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 2067,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 34,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 4763,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 57,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'no_checking',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 4066,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 56,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 20,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 1481,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 58,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3985,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 35,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 19,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2338,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 45,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2478,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
# ...
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 36,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1388,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 33,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2661,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 21,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 1257,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 55,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 22,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 1735,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 32,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3129,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 46,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2460,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 36,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 2067,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 34,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 4763,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 57,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'no_checking',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 4066,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 56,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 20,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 1481,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 58,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 31,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3985,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 35,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 19,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2338,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 45,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2478,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 10,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 4496,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 22,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 32,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2732,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 4655,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 23,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 3117,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 34,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1676,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 43,
#   'InstallmentPlans': 'stores',
#   'Housing': 'free',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 37,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'other',
#   'LoanAmount': 2740,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 15,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'education',
#   'LoanAmount': 4190,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 4,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'unknown',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 36,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 1388,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 28,
#   'InstallmentPlans': 'none',
#   'Housing': 'free',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 33,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'car_used',
#   'LoanAmount': 2661,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '4_to_7',
#   'InstallmentPercent': 5,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'real_estate',
#   'Age': 21,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 38,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 1257,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'real_estate',
#   'Age': 55,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 22,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'furniture',
#   'LoanAmount': 1735,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 3,
#   'Sex': 'female',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 32,
#   'InstallmentPlans': 'none',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 25,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 3129,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': 'greater_7',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 3,
#   'OwnsProperty': 'savings_insurance',
#   'Age': 46,
#   'InstallmentPlans': 'stores',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'Risk'},
#  {'CheckingStatus': 'less_0',
#   'LoanDuration': 39,
#   'CreditHistory': 'outstanding_credit',
#   'LoanPurpose': 'vacation',
#   'LoanAmount': 2460,
#   'ExistingSavings': '100_to_500',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 44,
#   'InstallmentPlans': 'stores',
#   'Housing': 'own',
#   'ExistingCreditsCount': 1,
#   'Job': 'management_self-employed',
#   'Dependents': 2,
#   'Telephone': 'yes',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': 'greater_200',
#   'LoanDuration': 36,
#   'CreditHistory': 'credits_paid_to_date',
#   'LoanPurpose': 'appliances',
#   'LoanAmount': 2067,
#   'ExistingSavings': 'greater_1000',
#   'EmploymentDuration': '1_to_4',
#   'InstallmentPercent': 3,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 4,
#   'OwnsProperty': 'real_estate',
#   'Age': 50,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 2,
#   'Job': 'skilled',
#   'Dependents': 1,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'},
#  {'CheckingStatus': '0_to_200',
#   'LoanDuration': 34,
#   'CreditHistory': 'prior_payments_delayed',
#   'LoanPurpose': 'repairs',
#   'LoanAmount': 4763,
#   'ExistingSavings': 'less_100',
#   'EmploymentDuration': 'less_1',
#   'InstallmentPercent': 2,
#   'Sex': 'male',
#   'OthersOnLoan': 'none',
#   'CurrentResidenceDuration': 2,
#   'OwnsProperty': 'unknown',
#   'Age': 57,
#   'InstallmentPlans': 'none',
#   'Housing': 'rent',
#   'ExistingCreditsCount': 1,
#   'Job': 'skilled',
#   'Dependents': 2,
#   'Telephone': 'none',
#   'ForeignWorker': 'yes',
#   'Risk': 'No Risk'}]

# %%
wos_client.data_sets.store_records(feedback_dataset_id, request_body=feedback_data, background_mode=False)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ==========================================================================================
#
#  Waiting for end of storing records with request id: 6fc25b95-78bf-4d4d-afb8-34ff697869ab
#
# ==========================================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# active
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ---------------------------------------
#  Successfully finished storing records
# ---------------------------------------

# %%
wos_client.data_sets.show_records(data_set_id=feedback_dataset_id)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <HTML>
#         <body>
#             <h3>Data Set 818066e8-9d4c-4601-abff-1a7db8fdffc6 Records</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>record_id</th><th style='border: 1px solid #dddddd'>record_timestamp</th><th style='border: 1px solid #dddddd'>LoanAmount</th><th style='border: 1px solid #dddddd'>InstallmentPercent</th><th style='border: 1px solid #dddddd'>ExistingSavings</th><th style='border: 1px solid #dddddd'>CheckingStatus</th><th style='border: 1px solid #dddddd'>LoanPurpose</th><th style='border: 1px solid #dddddd'>Job</th><th style='border: 1px solid #dddddd'>InstallmentPlans</th><th style='border: 1px solid #dddddd'>OthersOnLoan</th><th style='border: 1px solid #dddddd'>LoanDuration</th><th style='border: 1px solid #dddddd'>transaction_id</th><th style='border: 1px solid #dddddd'>Age</th><th style='border: 1px solid #dddddd'>CreditHistory</th><th style='border: 1px solid #dddddd'>CurrentResidenceDuration</th><th style='border: 1px solid #dddddd'>ForeignWorker</th><th style='border: 1px solid #dddddd'>Housing</th><th style='border: 1px solid #dddddd'>ExistingCreditsCount</th><th style='border: 1px solid #dddddd'>Telephone</th><th style='border: 1px solid #dddddd'>Sex</th><th style='border: 1px solid #dddddd'>Dependents</th><th style='border: 1px solid #dddddd'>OwnsProperty</th><th style='border: 1px solid #dddddd'>Risk</th><th style='border: 1px solid #dddddd'>EmploymentDuration</th>
#                 <tr><td style='border: 1px solid #dddddd'>01026699-c677-4db5-8c18-c7c0244ece4e</td><td style='border: 1px solid #dddddd'>2020-11-01T00:56:27.980Z</td><td style='border: 1px solid #dddddd'>1676</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>100_to_500</td><td style='border: 1px solid #dddddd'>0_to_200</td><td style='border: 1px solid #dddddd'>appliances</td><td style='border: 1px solid #dddddd'>management_self-employed</td><td style='border: 1px solid #dddddd'>stores</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>39</td><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>43</td><td style='border: 1px solid #dddddd'>outstanding_credit</td><td style='border: 1px solid #dddddd'>4</td><td style='border: 1px solid #dddddd'>yes</td><td style='border: 1px solid #dddddd'>free</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>yes</td><td style='border: 1px solid #dddddd'>female</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>savings_insurance</td><td style='border: 1px solid #dddddd'>No Risk</td><td style='border: 1px solid #dddddd'>less_1</td></tr><tr><td style='border: 1px solid #dddddd'>06e260d6-a2e2-4daf-88a2-db059ed0aeed</td><td style='border: 1px solid #dddddd'>2020-11-01T00:56:27.980Z</td><td style='border: 1px solid #dddddd'>2067</td><td style='border: 1px solid #dddddd'>3</td><td style='border: 1px solid #dddddd'>greater_1000</td><td style='border: 1px solid #dddddd'>greater_200</td><td style='border: 1px solid #dddddd'>appliances</td><td style='border: 1px solid #dddddd'>skilled</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>36</td><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>50</td><td style='border: 1px solid #dddddd'>credits_paid_to_date</td><td style='border: 1px solid #dddddd'>4</td><td style='border: 1px solid #dddddd'>yes</td><td style='border: 1px solid #dddddd'>rent</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>male</td><td style='border: 1px solid #dddddd'>1</td><td style='border: 1px solid #dddddd'>real_estate</td><td style='border: 1px solid #dddddd'>No Risk</td><td style='border: 1px solid #dddddd'>1_to_4</td></tr><tr><td style='border: 1px solid #dddddd'>5d9f8745-0fd1-4d56-9ac1-01e685502937</td><td style='border: 1px solid #dddddd'>2020-11-01T00:56:27.980Z</td><td style='border: 1px solid #dddddd'>2740</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>less_100</td><td style='border: 1px solid #dddddd'>0_to_200</td><td style='border: 1px solid #dddddd'>other</td><td style='border: 1px solid #dddddd'>skilled</td><td style='border: 1px solid #dddddd'>stores</td><td style='border: 1px solid #dddddd'>none</td><td style='border: 1px solid #dddddd'>37</td><td style='border: 1px solid #dddddd'>None</td><td style='border: 1px solid #dddddd'>44</td><td style='border: 1px solid #dddddd'>prior_payments_delayed</td><td style='border: 1px solid #dddddd'>4</td><td style='border: 1px solid #dddddd'>yes</td><td style='border: 1px solid #dddddd'>rent</td><td style='border: 1px solid #dddddd'>2</td><td style='border: 1px solid #dddddd'>yes</td><td style='border: 1px solid #dddddd'>female</td><td style='border: 1px solid #dddddd'>1</td><td style='border: 1px solid #dddddd'>savings_insurance</td><td style='border: 1px solid #dddddd'>No Risk</td><td style='border: 1px solid #dddddd'>greater_7</td></tr><tr><td style='border: 1px solid #dddddd'>64360f01-e70e-4f81-99e0-ae35e45c14c6</td><td style='border: 1px solid #dddddd'>2020-11-01T00:56:27.980Z</td><td style='border: 1px solid #dddddd'>4190</td><td style='border: 1px solid #dddddd'>4</td><td style='border: 1px solid #dddddd'>less_100</td ...

# %% [markdown]
# ### Run quality monitoring on demand

# %% [markdown]
# By default, quality monitoring is run on hourly schedule. You can also trigger it on demand using below code.

# %%
run_details = wos_client.monitor_instances.run(monitor_instance_id=quality_monitor_instance_id, background_mode=False).result
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ========================================================================
#
#  Waiting for end of monitoring run 7928babb-0d52-45f0-a74f-06e792cd3b6a
#
# ========================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# running
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# finished
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ---------------------------
#  Successfully finished run
# ---------------------------

# %%
time.sleep(5)
wos_client.monitor_instances.show_metrics(monitor_instance_id=quality_monitor_instance_id)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <HTML>
#         <body>
#             <h3>87163786-2bc5-4e6b-a6b4-1019840ff6e7 Monitor Runs Metrics from: 2020-10-24 21:20:57.303214  till: 2020-10-31 21:20:57.303235</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>ts</th><th style='border: 1px solid #dddddd'>id</th><th style='border: 1px solid #dddddd'>measurement_id</th><th style='border: 1px solid #dddddd'>value</th><th style='border: 1px solid #dddddd'>lower_limit</th><th style='border: 1px solid #dddddd'>upper_limit</th><th style='border: 1px solid #dddddd'>tags</th><th style='border: 1px solid #dddddd'>monitor_definition_id</th><th style='border: 1px solid #dddddd'>monitor_instance_id</th><th style='border: 1px solid #dddddd'>run_id</th><th style='border: 1px solid #dddddd'>target_type</th><th style='border: 1px solid #dddddd'>target_id</th>
#
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ## Fairness monitoring and explanations

# %% [markdown]
# ### Enable and run fairness monitoring

# %%
target = Target(
    target_type=TargetTypes.SUBSCRIPTION,
    target_id=subscription_id

)
parameters = {
    "features": [
        {"feature": "Sex",
         "majority": ['male'],
         "minority": ['female'],
         "threshold": 0.95
         },
        {"feature": "Age",
         "majority": [[26, 75]],
         "minority": [[18, 25]],
         "threshold": 0.95
         }
    ],
    "favourable_class": ["No Risk"],
    "unfavourable_class": ["Risk"],
    "min_records": 40
}

fairness_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.FAIRNESS.ID,
    target=target,
    parameters=parameters).result
fairness_monitor_instance_id =fairness_monitor_details.metadata.id
fairness_monitor_instance_id
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ===================================================================================
#
#  Waiting for end of monitor instance creation 7cc73e82-b1b4-4c40-9c5b-eb05e46723a0
#
# ===================================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# preparing
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# active
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------
# '7cc73e82-b1b4-4c40-9c5b-eb05e46723a0'

# %% [markdown]
# ### Score, format and store payload records

# %%
payload=df_data.sample(50)

# %%
records_list=[]
for i in payload.to_dict('records'):
    b=[{"name":x,"value":v} for x,v in i.items()]
    records_list.append({'input': b})

# %%
scoring_payload = {'requestInputTable': [{'id': input_table_id, 'requestInputRow': records_list}], 'id': node_id}
resp_score = requests.post(url=scoring_endpoint, json=scoring_payload, auth=HTTPBasicAuth(username=SPSS_CDS_ENGINE_CREDENTIALS['username'], password=SPSS_CDS_ENGINE_CREDENTIALS['password']))
result = resp_score.json()

# %%
res_values=[]
for i in result['rowValues']:
    d= [j for j in i['value']]
    res_values.append([k['value'] for k in d])

# %%
dtype_idx=[1,4,7,10,12,15,17] # change numeric features values in scoring response from String to Integer
dtype_predictions_idx=[21,22,23] # change prediction, probability column values in scoring response from String to Float

for val in res_values:
    for idx in dtype_idx:
        val[idx]=int(val[idx])
    for idx in dtype_predictions_idx:
        val[idx]=float(val[idx])
len(res_values)
# Out:
# 50

# %%
request = {
            "fields": payload.columns.tolist(),
            "values": payload.values.tolist()
        }
response = {
            "fields": result['columnNames']['name'],
            "values": res_values
        }

# %%
import uuid
from ibm_watson_openscale.supporting_classes.payload_record import PayloadRecord
time.sleep(5)
wos_client.data_sets.store_records(data_set_id=payload_data_set_id, request_body=[PayloadRecord(
               scoring_id=str(uuid.uuid4()),
               request=request,
               response=response,
               response_time=460
           )])
time.sleep(10)
pl_records_count = wos_client.data_sets.get_records_count(payload_data_set_id)
print("Number of records in the payload logging table: {}".format(pl_records_count))
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Number of records in the payload logging table: 54

# %%
run_details = wos_client.monitor_instances.run(monitor_instance_id=fairness_monitor_instance_id, background_mode=False)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ========================================================================
#
#  Waiting for end of monitoring run 3ceecad6-bc94-48fe-afd6-bcf9dddba5b6
#
# ========================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# running
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# .
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# .
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# .
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# finished
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ---------------------------
#  Successfully finished run
# ---------------------------

# %%
time.sleep(10)
wos_client.monitor_instances.show_metrics(monitor_instance_id=fairness_monitor_instance_id)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <HTML>
#         <body>
#             <h3>7cc73e82-b1b4-4c40-9c5b-eb05e46723a0 Monitor Runs Metrics from: 2020-10-24 21:23:27.992611  till: 2020-10-31 21:23:27.992626</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>ts</th><th style='border: 1px solid #dddddd'>id</th><th style='border: 1px solid #dddddd'>measurement_id</th><th style='border: 1px solid #dddddd'>value</th><th style='border: 1px solid #dddddd'>lower_limit</th><th style='border: 1px solid #dddddd'>upper_limit</th><th style='border: 1px solid #dddddd'>tags</th><th style='border: 1px solid #dddddd'>monitor_definition_id</th><th style='border: 1px solid #dddddd'>monitor_instance_id</th><th style='border: 1px solid #dddddd'>run_id</th><th style='border: 1px solid #dddddd'>target_type</th><th style='border: 1px solid #dddddd'>target_id</th>
#
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ### Explainability configuration and run

# %% [markdown]
# #### Enable explainability

# %%
target = Target(
    target_type=TargetTypes.SUBSCRIPTION,
    target_id=subscription_id
)
parameters = {
    "enabled": True
}
explainability_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.EXPLAINABILITY.ID,
    target=target,
    parameters=parameters
).result
explainability_monitor_id = explainability_details.metadata.id
explainability_monitor_id
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ===================================================================================
#
#  Waiting for end of monitor instance creation d6e3fb61-910b-43d5-bc0c-defdf4ad0a7a
#
# ===================================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# preparing
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# active
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------
# 'd6e3fb61-910b-43d5-bc0c-defdf4ad0a7a'

# %% [markdown]
# #### Get sample transaction_id from payload logging table (`scoring_id`)

# %%
pl_records_resp = wos_client.data_sets.get_list_of_records(data_set_id=payload_data_set_id, limit=1, offset=0).result
scoring_ids = [pl_records_resp["records"][0]["entity"]["values"]["scoring_id"]]
print("Running explanations on scoring IDs: {}".format(scoring_ids))
explanation_types = ["lime", "contrastive"]
result = wos_client.monitor_instances.explanation_tasks(scoring_ids=scoring_ids, explanation_types=explanation_types).result
print(result)
explanation_task_id=result.to_dict()['metadata']['explanation_task_ids'][0]
explanation_task_id
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Running explanations on scoring IDs: ['d9530502-b301-4eb1-9297-e9eb7fa85b30-1']
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {
#   "metadata": {
#     "explanation_task_ids": [
#       "11280990-24ff-452b-90c6-78c0e1d59404"
#     ],
#     "created_by": "1000330999",
#     "created_at": "2020-11-01T01:24:11.491618Z"
#   }
# }
# '11280990-24ff-452b-90c6-78c0e1d59404'

# %%
wos_client.monitor_instances.get_explanation_tasks(explanation_task_id=explanation_task_id).result.to_dict()
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'metadata': {'explanation_task_id': '11280990-24ff-452b-90c6-78c0e1d59404',
#   'created_by': '1000330999',
#   'created_at': '2020-11-01T01:24:11.491618Z',
#   'updated_at': '2020-11-01T01:24:44.328198Z'},
#  'entity': {'status': {'state': 'in_progress'},
#   'asset': {'id': '091edbc5c4e74be5000001686a7c7110cafe',
#    'name': 'german_credit_risk_tutorial_BiasQA',
#    'input_data_type': 'structured',
#    'problem_type': 'binary',
#    'deployment': {'id': 'german_credit_risk_tutorial_BiasQA',
#     'name': 'german_credit_risk_tutorial_BiasQA'}},
#   'input_features': [{'name': 'CheckingStatus',
#     'value': 'greater_200',
#     'feature_type': 'categorical'},
#    {'name': 'LoanDuration', 'value': '16', 'feature_type': 'numerical'},
#    {'name': 'CreditHistory',
#     'value': 'outstanding_credit',
#     'feature_type': 'categorical'},
#    {'name': 'LoanPurpose', 'value': 'vacation', 'feature_type': 'categorical'},
#    {'name': 'LoanAmount', 'value': '4553', 'feature_type': 'numerical'},
#    {'name': 'ExistingSavings',
#     'value': 'less_100',
#     'feature_type': 'categorical'},
#    {'name': 'EmploymentDuration',
#     'value': 'less_1',
#     'feature_type': 'categorical'},
#    {'name': 'InstallmentPercent', 'value': '5', 'feature_type': 'numerical'},
#    {'name': 'Sex', 'value': 'female', 'feature_type': 'categorical'},
#    {'name': 'OthersOnLoan', 'value': 'none', 'feature_type': 'categorical'},
#    {'name': 'CurrentResidenceDuration',
#     'value': '4',
#     'feature_type': 'numerical'},
#    {'name': 'OwnsProperty',
#     'value': 'savings_insurance',
#     'feature_type': 'categorical'},
#    {'name': 'Age', 'value': '57', 'feature_type': 'numerical'},
#    {'name': 'InstallmentPlans',
#     'value': 'stores',
#     'feature_type': 'categorical'},
#    {'name': 'Housing', 'value': 'own', 'feature_type': 'categorical'},
#    {'name': 'ExistingCreditsCount', 'value': '1', 'feature_type': 'numerical'},
#    {'name': 'Job', 'value': 'skilled', 'feature_type': 'categorical'},
#    {'name': 'Dependents', 'value': '2', 'feature_type': 'numerical'},
#    {'name': 'Telephone', 'value': 'yes', 'feature_type': 'categorical'},
#    {'name': 'ForeignWorker', 'value': 'yes', 'feature_type': 'categorical'}],
#   'perturbed': False,
#   'explanations': [{'explanation_type': 'lime',
#     'predictions': [{'value': 'No Risk',
#       'probability': 0.8353896172631814,
#       'explanation_features': [{'feature_range': {'min_inclusive': False,
#          'min': '4.00'},
#         'weight': 0.14882498270444067,
#         'feature_name': 'InstallmentPercent'},
#        {'feature_value': 'yes',
#         'weight': 0.14531535365832166,
#         'feature_name': 'ForeignWorker'},
#        {'feature_range': {'min_inclusive': False, 'min': '44.00'},
#         'weight': -0.14453976073723163,
#         'feature_name': 'Age'},
#        {'feature_range': {'min_inclusive': False,
#          'max_inclusive': True,
#          'max': '4.00',
#          'min': '3.00'},
#         'weight': -0.11429395529211951,
#         'feature_name': 'CurrentResidenceDuration'},
#        {'feature_value': 'none',
#         'weight': 0.10690814552098336,
#         'feature_name': 'OthersOnLoan'},
#        {'feature_value': 'less_1',
#         'weight': 0.10510875276798388,
#         'feature_name': 'EmploymentDuration'},
#        {'feature_range': {'max_inclusive': True, 'max': '1.00'},
#         'weight': 0.08487322039919123,
#         'feature_name': 'ExistingCreditsCount'},
#        {'feature_range': {'min_inclusive': False,
#          'max_inclusive': True,
#          'max': '21.00',
#          'min': '13.00'},
#         'weight': 0.05235721436490096,
#         'feature_name': 'LoanDuration'},
#        {'feature_value': 'skilled',
#         'weight': -0.049640385038675634,
#         'feature_name': 'Job'},
#        {'feature_value': 'own',
#         'weight': 0.04813822951615142,
#         'feature_name': 'Housing'}]},
#      {'value': 'Risk', 'probability': 0.1646103827368186}]}]}}

# %% [markdown]
# ### Enable and run drift monitoring

# %%
# !rm -rf creditrisk_spss_drift_detection_model.tar.gz
# !wget -O creditrisk_spss_drift_detection_model.tar.gz https://github.com/IBM/watson-openscale-samples/blob/main/assets/models/credit_risk/spss_creditrisk_drift_detection_model.tar.gz?raw=true
# Out:
# --2020-11-04 14:33:50--  https://github.com/IBM/watson-openscale-samples/blob/main/assets/models/credit_risk/spss_creditrisk_drift_detection_model.tar.gz?raw=true
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/IBM/watson-openscale-samples/raw/main/assets/models/credit_risk/spss_creditrisk_drift_detection_model.tar.gz [following]
# --2020-11-04 14:33:51--  https://github.com/IBM/watson-openscale-samples/raw/main/assets/models/credit_risk/spss_creditrisk_drift_detection_model.tar.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/models/credit_risk/spss_creditrisk_drift_detection_model.tar.gz [following]
# --2020-11-04 14:33:51--  https://raw.githubusercontent.com/IBM/watson-openscale-samples/main/assets/models/credit_risk/spss_creditrisk_drift_detection_model.tar.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.128.133, 151.101.192.133, 151.101.0.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.128.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 222311 (217K) [application/octet-stream]
# Saving to: ‘creditrisk_spss_drift_detection_model.tar.gz’
#
# creditrisk_spss_dri 100%[===================>] 217.10K  --.-KB/s    in 0.07s
#
# 2020-11-04 14:33:51 (2.86 MB/s) - ‘creditrisk_spss_drift_detection_model.tar.gz’ saved [222311/222311]

# %%
wos_client.monitor_instances.upload_drift_model(
        model_path='creditrisk_spss_drift_detection_model.tar.gz',
        data_mart_id=data_mart_id,
        subscription_id=subscription_id
     )
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
monitor_instances = wos_client.monitor_instances.list().result.monitor_instances
for monitor_instance in monitor_instances:
    monitor_def_id=monitor_instance.entity.monitor_definition_id
    if monitor_def_id == "drift" and monitor_instance.entity.target.target_id == subscription_id:
        wos_client.monitor_instances.delete(monitor_instance.metadata.id)
        print('Deleted existing drift monitor instance with id: ', monitor_instance.metadata.id)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
target = Target(
    target_type=TargetTypes.SUBSCRIPTION,
    target_id=subscription_id

)
parameters = {
    "min_samples": 40,
    "drift_threshold": 0.1,
    "train_drift_model": False,
    "enable_model_drift": True,
    "enable_data_drift": True
}

drift_monitor_details = wos_client.monitor_instances.create(
    data_mart_id=data_mart_id,
    background_mode=False,
    monitor_definition_id=wos_client.monitor_definitions.MONITORS.DRIFT.ID,
    target=target,
    parameters=parameters
).result

drift_monitor_instance_id = drift_monitor_details.metadata.id
drift_monitor_instance_id
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ===================================================================================
#
#  Waiting for end of monitor instance creation 915ae115-35d6-46b7-8c0a-96921e27bcc2
#
# ===================================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# active
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ---------------------------------------
#  Monitor instance successfully created
# ---------------------------------------
# '915ae115-35d6-46b7-8c0a-96921e27bcc2'

# %%
drift_run_details = wos_client.monitor_instances.run(monitor_instance_id=drift_monitor_instance_id, background_mode=False)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ========================================================================
#
#  Waiting for end of monitoring run bace9cfb-b55c-4685-b4cc-fa4bcd34df2e
#
# ========================================================================
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# running
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# finished
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ---------------------------
#  Successfully finished run
# ---------------------------

# %%
time.sleep(5)
wos_client.monitor_instances.show_metrics(monitor_instance_id=drift_monitor_instance_id)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Applications/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'namespace1-cpd-namespace1.apps.islnov09.os.fyre.ibm.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# <HTML>
#         <body>
#             <h3>915ae115-35d6-46b7-8c0a-96921e27bcc2 Monitor Runs Metrics from: 2020-10-24 21:26:50.868046  till: 2020-10-31 21:26:50.868065</h3>
#             <table style='border: 1px solid #dddddd; font-family: Courier'>
#                 <th style='border: 1px solid #dddddd'>ts</th><th style='border: 1px solid #dddddd'>id</th><th style='border: 1px solid #dddddd'>measurement_id</th><th style='border: 1px solid #dddddd'>value</th><th style='border: 1px solid #dddddd'>lower_limit</th><th style='border: 1px solid #dddddd'>upper_limit</th><th style='border: 1px solid #dddddd'>tags</th><th style='border: 1px solid #dddddd'>monitor_definition_id</th><th style='border: 1px solid #dddddd'>monitor_instance_id</th><th style='border: 1px solid #dddddd'>run_id</th><th style='border: 1px solid #dddddd'>target_type</th><th style='border: 1px solid #dddddd'>target_id</th>
#
#             </table>
#         </body>
#         </HTML>

# %% [markdown]
# ## Congratulations!
#
# You have finished the hands-on lab for IBM Watson OpenScale. You can now view the [OpenScale Dashboard](https://aiopenscale.cloud.ibm.com/). Click on the tile for the German Credit SPSS model to see fairness, accuracy, and performance monitors. Click on the timeseries graph to get detailed information on transactions during a specific time window.

# %% [markdown]
# ---
